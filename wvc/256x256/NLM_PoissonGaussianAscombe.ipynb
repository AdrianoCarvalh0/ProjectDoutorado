# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Dec 15 11:26:44 2019

Implementação do filtro Non-Local Means geodésico

"""
import sys
import warnings
import time
import skimage
import statistics
import networkx as nx
import matplotlib.pyplot as plt
import skimage.io
import skimage.measure
import numpy as np
import sklearn.neighbors as sknn
from scipy.sparse.csgraph import dijkstra
from numpy.matlib import repmat
from scipy.linalg import eigh
from numpy.linalg import inv
from numpy.linalg import cond
from numpy import eye
from sklearn.decomposition import PCA
from skimage.metrics import peak_signal_noise_ratio
from skimage.metrics import structural_similarity
from skimage.transform import rescale, resize, downscale_local_mean
from numba import njit   # just in time compiler (acelera loops)
from joblib import Parallel, delayed
from bm3d import bm3d, BM3DProfile

# Para evitar warning de divisão por zero
warnings.simplefilter(action='ignore')

'''
Espelhamento das bordas da imagem A de maneira simétrica
A função pad do numpy não é supertada pelo numba!
Substitui a função: img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')
f é o parâmetro (largura das bordas)
'''
@njit
def mirror(A, f):
    n = A.shape[0]
    m = A.shape[1]
    nlin = A.shape[0] + 2*f
    ncol = A.shape[1] + 2*f
    # Matriz de saída
    B = np.zeros((nlin, ncol))
    # Preeenche miolo
    B[f:nlin-f, f:ncol-f] = A
    # Preenche cantos
    B[0:f, 0:f] = np.flip(A[0:f, 0:f])                          # 1o quadrante
    B[0:f, ncol-f:ncol] = np.flip(A[0:f, m-f:m])                # 2o quadrante
    B[nlin-f:nlin, 0:f] = np.flip(A[n-f:n, 0:f])                # 3o quadrante
    B[nlin-f:nlin, ncol-f:ncol] = np.flip(A[n-f:n, m-f:m])      # 4o quadrante
    # Preenche bordas
    B[0:f, f:ncol-f] = np.flipud(A[0:f, :])             # cima
    B[nlin-f:nlin, f:ncol-f] = np.flipud(A[n-f:n, :])   # baixo
    B[f:nlin-f, 0:f] = np.fliplr(A[:, 0:f])             # esquerda
    B[f:nlin-f, ncol-f:ncol] = np.fliplr(A[:, m-f:m])   # direita
    return B

'''
Non-Local Means padrão (versão rápida)

Parâmetros:

    img: imagem ruidosa de entrada
    h: parâmetro que controla o grau de suavização (quanto maior, mais suaviza)
    f: tamanho do patch (2f + 1 x 2f + 1) -> se f = 3, então patch é 7 x 7
    t: tamanho da janela de busca (2t + 1 x 2t + 1) -> se t = 10, então janela de busca é 21 x 21

'''
@njit
def NLM_fast(img, h, f, t):
    # Dimenssões espaciais da imagem
    m, n = img.shape
    # Cria imagem de saída
    filtrada = np.zeros((m, n))
    # Problema de valor de contorno: replicar bordas
    img_n = mirror(img, f)
    # Loop principal do NLM
    for i in range(m):
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente
            # Obtém o patch ao redor do pixel corrente
            W1 = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1]
            # Calcula as bordas da janela de busca para o pixel corrente (se pixel próximo das bordas, janela de busca é menor)
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            # Calcula média ponderada
            NL = 0      # valor do pixel corrente filtrado
            Z = 0       # constante normalizadora
            # Loop para todos os pixels da janela de busca
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    W2 = img_n[r-f:(r+f)+1, s-f:(s+f)+1]
                    # Calcula o quadrado da distância Euclidiana
                    d2 = np.sum((W1 - W2)*(W1 - W2))
                    # Calcula a medida de similaridade
                    sij = np.exp(-d2/(h**2))               
                    # Atualiza Z e NL
                    Z = Z + sij
                    NL = NL + sij*img_n[r, s]
            # Normalização do pixel filtrado
            filtrada[i, j] = NL/Z
    return filtrada


'''
Non-Local Means geodésico (versão básica, sem paralelismo e mais lenta)

Parâmetros:

    img: imagem ruidosa de entrada
    h: parâmetro que controla o grau de suavização (quanto maior, mais suaviza)
    f: tamanho do patch (2f + 1 x 2f + 1) -> se f = 3, então patch é 7 x 7
    t: tamanho da janela de busca (2t + 1 x 2t + 1) -> se t = 10, então janela de busca é 21 x 21
    nn: número de vizinhos no grafo KNN

''' 
def GeoNLM(img_noise, h, f, t, nn=10):
    # Dimenssões espaciais da imagem
    m, n = img_noise.shape
    # Cria imagem de saída
    filtrada = np.zeros((m, n))
    # Problema de valor de contorno: replicar bordas
    img_n = np.pad(img_noise, ((f, f), (f, f)), 'symmetric')
    # Loop principal do NLM geodésico
    for i in range(m):
        if i % 10 == 0:
            print(i, end=' ')
            sys.stdout.flush()
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente
            # Obtém o patch ao redor do pixel corrente
            patch_central = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1]
            central = np.reshape(patch_central, [1, patch_central.shape[0]*patch_central.shape[1]])[-1]
            # Calcula as bordas da janela de busca para o pixel corrente
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            # Calcula média ponderada
            NL = 0      # valor do pixel corrente filtrado
            Z = 0       # constante normalizadora
            # Cria dataset com patches da janela de busca como vetores
            num_elem = (rmax - rmin)*(smax - smin)
            tamanho_patch = (2*f + 1)*(2*f + 1)
            dataset = np.zeros((num_elem, tamanho_patch))
            k = 0
            pixels_busca = []
            # Loop para montar o dataset com todos os patches da janela
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    W = img_n[r-f:(r+f)+1, s-f:(s+f)+1] 
                    neighbor = np.reshape(W, [1, W.shape[0]*W.shape[1]])[-1]                    
                    dataset[k, :] = neighbor.copy()
                    if central[0] == neighbor[0]:
                        if (central == neighbor).all():
                            source = k
                    pixels_busca.append(img_n[r, s])
                    k = k + 1
            # Cria grafo knn com patches da janela de busca
            knnGraph = sknn.kneighbors_graph(dataset, n_neighbors=nn, mode='distance')
            A = knnGraph.toarray()
            # Converte matriz de adjacências para grafo
            G = nx.from_numpy_array(A)                      
            # Aplica algoritmo de Dijkstra
            length, path = nx.single_source_dijkstra(G, source)
            points = np.array(list(length.keys()))
            distancias = np.array(list(length.values()))
            # Calcula similaridades
            similaridades = np.exp(-distancias**2/(h**2))
            pixels = np.zeros(len(points))
            pixels_busca = np.array(pixels_busca)
            pixels = pixels_busca[points]
            # Normalização do pixel filtrado
            NL = sum(similaridades*pixels)
            Z = sum(similaridades)
            filtrada[i, j] = NL/Z
    return filtrada


######################################################
# Função auxiliar para paralelizar o GEONLM
######################################################
def process_pixel(i, j, img_n, f, t, h, nn):
    im = i + f
    jn = j + f
    patch_central = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1]
    central = np.reshape(patch_central, [1, patch_central.shape[0]*patch_central.shape[1]])[-1]
    rmin = max(im-t, f)
    rmax = min(im+t, m+f)
    smin = max(jn-t, f)
    smax = min(jn+t, n+f)
    NL, Z = 0, 0
    dataset = np.zeros(((rmax - rmin)*(smax - smin), (2*f + 1)*(2*f + 1)))
    k = 0
    pixels_busca = []
    for r in range(rmin, rmax):
        for s in range(smin, smax):
            W = img_n[r-f:(r+f)+1, s-f:(s+f)+1]
            neighbor = np.reshape(W, [1, W.shape[0]*W.shape[1]])[-1]
            dataset[k, :] = neighbor.copy()
            if central[0] == neighbor[0] and (central == neighbor).all():
                source = k
            pixels_busca.append(img_n[r, s])
            k += 1
    knnGraph = sknn.kneighbors_graph(dataset, n_neighbors=nn, mode='distance')
    A = knnGraph.toarray()
    G = nx.from_numpy_array(A)
    length, path = nx.single_source_dijkstra(G, source)
    points = np.array(list(length.keys()))
    distancias = np.array(list(length.values()))
    similaridades = np.exp(-distancias**2 / (h**2))
    pixels_busca = np.array(pixels_busca)
    pixels = pixels_busca[points]
    NL = sum(similaridades * pixels)
    Z = sum(similaridades)
    return NL / Z

##################################################
# GEONLM paralelo 
##################################################
def Parallel_GEONLM(img_n, f, t, h, nn):
    # Parallelize the loop
    print(f'img_n.shape: {img_n.shape}')
    m = img_n.shape[0] - 2*f
    print(f'M: {m}')
    n = img_n.shape[1] - 2*f
    print(f'N: {n}')
    filtrada = Parallel(n_jobs=-1)(delayed(process_pixel)(i, j, img_n, f, t, h, nn) for i in range(m) for j in range(n))
    #print(f"filtrada Shape: {filtrada.shape}")
    
    filtrada_geo = np.array(filtrada).reshape((m, n))
    #print(f'filtrada_geo.shape: {filtrada_geo.shape}')
    return filtrada_geo

####################################################################
'''
Função que extrai os patches de cada janela de busca no GeoNLM
Retorna uma matriz 4D (m, n, 2t+1 x 2t+1, 2f+1 x 2f+1)

Usa o JIT (just in time) compiler para acelerar loops

'''
####################################################################
@njit
def Extract_patches(img, f, t):
    # Dimenssões espaciais da imagem
    m, n = img.shape
    # Tamanhos do patch e da janela de busca
    tamanho_patch = (2*f + 1)*(2*f + 1)    
    # Patches para cada janela de busca
    patches = []
    centros = []    
    # Problema de valor de contorno: replicar bordas
    img_n = mirror(img, f)
    # Loop principal do NLM geodésico
    for i in range(m):        
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente
            # Obtém o patch ao redor do pixel corrente
            patch_central = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1].copy()
            central = patch_central.reshape((1, patch_central.shape[0]*patch_central.shape[1]))[-1]
            # Calcula as bordas da janela de busca para o pixel corrente
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            num_elem = (rmax - rmin)*(smax - smin)
            # Cria dataset
            dataset = np.zeros((num_elem, tamanho_patch))
            # Loop para montar o dataset com todos os patches da janela
            k = 0
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    W = img_n[r-f:(r+f)+1, s-f:(s+f)+1].copy() 
                    neighbor = W.reshape((1, W.shape[0]*W.shape[1]))[-1]
                    dataset[k, :] = neighbor.copy()
                    if (central == neighbor).all():
                        source = k
                    k = k + 1
            patches.append(dataset)
            centros.append(source)
    return patches, centros

###################################################################
'''
Função que extrai os patches de cada janela de busca no GeoNLM
Retorna uma lista 
'''
###################################################################
def Geodesic_distances(patches, centros, nn=10):
    distancias_geodesicas = []
    pontos = []
    # Percorre a lista de patches
    for i in range(len(patches)):
    # Cria grafo knn com patches da janela de busca
        knnGraph = sknn.kneighbors_graph(patches[i], n_neighbors=nn, mode='distance')
        A = knnGraph.toarray()        
        G = nx.from_numpy_array(A)      # Converte matriz de adjacências para grafo
        # Aplica algoritmo de Dijkstra
        length, path = nx.single_source_dijkstra(G, centros[i])
        points = np.array(list(length.keys()))
        pontos.append(points)
        geodists = np.array(list(length.values()))        
        distancias_geodesicas.append(geodists)
    return distancias_geodesicas, pontos

##################################################################################################
'''
Non-Local Means geodésico (versão com compilador JIT para acelerar loops)

Parâmetros:

    img: imagem ruidosa de entrada
    h: parâmetro que controla o grau de suavização (quanto maior, mais suaviza)
    f: tamanho do patch (2f + 1 x 2f + 1) -> se f = 3, então patch é 7 x 7
    t: tamanho da janela de busca (2t + 1 x 2t + 1) -> se t = 10, então janela de busca é 21 x 21
    nn: número de vizinhos no grafo KNN

''' 
###################################################################################################
@njit
def GeoNLM_fast(img, h, f, t, distancias_geodesicas, pontos):
    # Dimenssões espaciais da imagem
    m, n = img.shape
    # Cria imagem de saída
    filtrada = np.zeros((m, n))
    # Problema de valor de contorno: replicar bordas
    #img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')
    img_n = mirror(img, f)
    # Loop principal do NLM geodésico
    k = 0
    for i in range(m):
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente    
            # Calcula as bordas da janela de busca para o pixel corrente
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            # Calcula média ponderada
            NL = 0      # valor do pixel corrente filtrado
            Z = 0       # constante normalizadora            
            pixels_busca = []
            # Loop para montar o dataset com todos os patches da janela
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    pixels_busca.append(img_n[r, s])
            # Calcula similaridades
            similaridades = np.exp(-distancias_geodesicas[k]**2/(h**2))
            pixels = np.zeros(len(pontos[k]))
            pixels_busca = np.array(pixels_busca)
            pixels = pixels_busca[pontos[k]]
            # Normalização do pixel filtrado
            NL = sum(similaridades*pixels)
            Z = sum(similaridades)
            filtrada[i, j] = NL/Z
            k = k + 1
    return filtrada

#########################################################################
'''
Realiza a filtragem da imagem com o filtro NLM geodésico 

Usa o compilador JIT para acelerar loops
'''
#########################################################################
def GeoNLM_filter(img_noise, h, f, t, nn=10):
    # Fase 1
    print('Início da extração dos patches')
    inicio = time.time()
    patches, centros = Extract_patches(img_noise, f, t)
    fim = time.time()
    print('Elapsed time: %f ' %(fim - inicio))
    print()
    # Fase 2
    print('Início do cálculo das distâncias')
    inicio = time.time()
    distancias_geodesicas, pontos = Geodesic_distances(patches, centros, nn)
    fim = time.time()
    print('Elapsed time: %f ' %(fim - inicio))
    print()
    # Fase 3
    print('Início da filtragem')
    inicio = time.time()
    filtrada = GeoNLM_fast(img_noise, h, f, t, distancias_geodesicas, pontos)
    fim = time.time()
    print('Elapsed time: %f ' %(fim - inicio))
    return filtrada

# %%
import os
import math

def read_directories(directory, img=None, exclude_json=None):
    # Get a list of filenames in the specified directory
    filenames = []
    for filename in os.listdir(directory):
        if img is not None:
            # If 'img' is provided, filter filenames containing it
            if img in filename:   
                filenames.append(filename)
        elif exclude_json is not None:
            filenames.append(filename.replace('.json',''))     
        else:
            filenames.append(filename)    
    return filenames


def add_poisson_noise(img):
    """
    Aplica ruído de Poisson corretamente sem overflow.

    Parâmetros:
        img (np.ndarray): Imagem com valores em [0,255] ou [0,1].

    Retorna:
        np.ndarray: imagem ruidosa, clipada para [0, 255], dtype uint8.
    """
    # Se estiver em [0, 1], escala para 0-255
    if img.max() <= 1.0:
        img = (img * 255).astype(np.float32)
    else:
        img = img.astype(np.float32)

    # Garante que os valores Poisson não causem overflow
    poisson_img = np.random.poisson(img).astype(np.float32)
    poisson_img = np.clip(poisson_img, 0, 255)

    return poisson_img.astype(np.uint8)

def anscombe_transform(img):
    return 2.0 * np.sqrt(img.astype(np.float32) + 3.0 / 8.0)

def inverse_anscombe(transf_img):
    return np.clip((transf_img / 2.0) ** 2 - 3.0 / 8.0, 0, 255)

def compute_adaptive_q(sigma_est):
    q_nlm = 0.8 + 0.5 * math.tanh(0.3 * (sigma_est - 1))
    q_geo = 1.0 + 0.7 * math.tanh(0.25 * (sigma_est - 1.5))

    q_nlm = np.clip(q_nlm, 0.7, 2.2) * 10
    q_geo = np.clip(q_geo, 0.9, 2.7) * 10

    return q_nlm, q_geo

def add_poisson_gaussian_noise(image, gaussian_sigma=25):
    """
    Adds Poisson noise followed by Gaussian noise to an image.

    Parameters:
        image (np.ndarray): Input image (grayscale or RGB), values in [0, 1] or [0, 255].
        gaussian_sigma (float): Standard deviation of the Gaussian noise (in intensity scale 0–255).

    Returns:
        np.ndarray: Noisy image (clipped to [0, 255] and converted to uint8).
    """
    # Convert to float32 and normalize to [0, 255] if necessary
    if image.dtype != np.float32:
        image = image.astype(np.float32)

    if image.max() <= 1.0:
        image *= 255.0

    # Apply Poisson noise
    poisson_image = np.random.poisson(image).astype(np.float32)

    # Apply Gaussian noise
    gaussian_noise = np.random.normal(loc=0.0, scale=gaussian_sigma, size=image.shape)
    noisy_image = poisson_image + gaussian_noise

    # Clip values and convert to uint8
    noisy_image = np.clip(noisy_image, 0, 255).astype(np.uint8)

    return noisy_image

# %%
from pathlib import Path
from skimage.restoration import estimate_sigma
import sys  

sys.path.insert(0, r"c:\Users\adria\Documents\Doutorado\ProjetoDoutorado")
root_dir = Path(r"c:\Users\adria\Documents\Doutorado\ProjetoDoutorado")



dir_images = f'{root_dir}/wvc/images'
dir_out_nlm = f'{root_dir}/wvc/256x256/Anscombe/out_put_NLM_Poisson'
dir_out_geonlm = f'{root_dir}/wvc/256x256/Anscombe/out_put_GEONLM_Poisson'
dir_out_bm3d = f'{root_dir}/wvc/256x256/Anscombe/out_put_BM3D_Poisson'

array_dir = read_directories(dir_images)

array_dicts = []

for file in array_dir:

    file_name = file
    img = skimage.io.imread(f'{dir_images}/{file_name}')
    # Em arquivos de formato GIF precisa desse comando
    img = img[0, :, :]

    # Checa se imagem é monocromática
    if len(img.shape) > 2:
        img = skimage.color.rgb2gray(img)   # valores convertidos ficam entre 0 e 1
        img = 255*img

    # Reescala imagem para (256, 256) - diminuir o tempo de execução
    img = downscale_local_mean(img, (2, 2))

    img = img.astype(np.uint8)              # Converte para uint8    
    m, n = img.shape

    print('Num. linhas = %d' %m)
    print('Num. colunas = %d' %n)
    print()

    # Cria imagem ruidosa
    ruidosa = add_poisson_noise(img)

    # Clipa imagem para intervalo [0, 255]
    ruidosa[np.where(ruidosa > 255)] = 255
    ruidosa[np.where(ruidosa < 0)] = 0
    #ruidosa = ruidosa.astype(np.float32)

    # Listas para métricas


    # Define parâmetros do filtro NLM
    f = 4   # tamanho do patch (2f + 1 x 2f + 1) -> 5 x 5
    t = 7   # tamanho da janela de busca (2t + 1 x 2t + 1) -> 21 x 21
    h_nlm = 16 # parâmetro que controla a suavização no NLM (depende da imagem)
    h_geo = 21 # parâmetro que controla a suavização no GEONLM (depende da imagem)
    nn = 10     # número de vizinhos no grafo k-NN

    # Cria imagem de saída
    filtrada = np.zeros((m, n))

    # Problema de valor de contorno: replicar bordas
    img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')

 
    inicio = time.time()
    #ruidosa_asc = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')      # para versão paralela, precisa espelhar imagem fora da função


    ruidosa_anscombe = anscombe_transform(ruidosa)
    #print(f'ruidosa_asc_nlm.shape: {ruidosa_anscombe.shape}')
    sigma_est = estimate_sigma(ruidosa_anscombe)
    q_nlm, q_geo = compute_adaptive_q(sigma_est)
    h_nlm = q_nlm * sigma_est #* 10
    h_geo = q_geo * sigma_est #* 10

    print('***********************************')
    print('*         Parâmetro H             *')
    print('***********************************')
    print(f"[INFO] σ estimado: {sigma_est:.2f} | q_nlm = {q_nlm:.2f} | h_nlm = {h_nlm:.2f}")
    print(f"[INFO]                 q_geo = {q_geo:.2f} | h_geo = {h_geo:.2f}")
    

    ###################################################
    # Filtra com NLM padrão
    ########T###########################################
    print('***********************************')
    print('*            NLM                  *')
    print('***********************************')
    print()
    filtrada_asc = NLM_fast(ruidosa_anscombe, h_nlm, f, t)
    print(f'filtrada_asc.shape: {filtrada_asc.shape}')
    filtrada_padrao = inverse_anscombe(filtrada_asc).astype(np.uint8)
    print(f'filtrada_padrao.shape: {filtrada_padrao.shape}')

    fim = time.time()    
    # Calcula PSNR
    p1_nlm = peak_signal_noise_ratio(img, filtrada_padrao.astype(np.uint8))
   
    print('PSNR (NLM padrão): %f' %p1_nlm)
    # Calcula SSIM
    s1_nlm = structural_similarity(img, filtrada_padrao.astype(np.uint8))
  
    print('SSIM (NLM padrão): %f' %s1_nlm)
    print('Elapsed time (NLM): %f s' %(fim - inicio))
    print()
    time_nlm = fim - inicio
    # Salva arquivo
    skimage.io.imsave(f'{dir_out_nlm}/{file_name}', filtrada_padrao.astype(np.uint8))

    ###################################################
    # Filtra com NLM geodésico
    ###################################################
    print('***********************************')
    print('*            GEONLM               *')
    print('***********************************')
    print()
    ini = time.time()

    ##3 Versão com JIT compiler
    #filtrada_geo = GeoNLM_filter(ruidosa, h_geo, f, t, nn)   # versão com JIT compiler (não ficou mais rápido pois o Dijkstra não acelera. Ainda está lento...)

    ### Versão com paralelismo (ficou mais rápida)
    img_n_geo = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')      # para versão paralela, precisa espelhar imagem fora da função

    ruidosa_asc_geo = anscombe_transform(img_n_geo)
    filtrada_geo_asc = Parallel_GEONLM(ruidosa_asc_geo, f, t, h_geo, nn)

    filtrada_geo = inverse_anscombe(filtrada_geo_asc).astype(np.uint8)

    end = time.time()
    # Calcula PSNR
    p2_gnlm = peak_signal_noise_ratio(img, filtrada_geo.astype(np.uint8))    
    print('\nPSNR (GEO NLM): %f' %p2_gnlm)
    # Calcula SSIM
    s2_gnlm = structural_similarity(img, filtrada_geo.astype(np.uint8))
   
    print('SSIM (GEO NLM): %f' %s2_gnlm)
    print('Total Elapsed time (GEONLM): %f s' %(end - ini))

    time_geonlm = end - ini
    print()
    # Salva arquivo    
    skimage.io.imsave(f'{dir_out_geonlm}/{file_name}', filtrada_geo.astype(np.uint8))
    
    print('***********************************')
    print('*            BM3D                 *')
    print('***********************************')
    print()


    ini = time.time()

    # 1. Normaliza a imagem ruidosa para intervalo [0, 1]
    #ruidosa_normalizada = ruidosa.astype(np.float32) / 255.0

    #ruidosa_asc_bm3d = anscombe_transform(ruidosa_normalizada)

    #sigma_est = estimate_sigma(ruidosa_asc_bm3d, channel_axis=None)

    # 3. Define o perfil padrão do BM3D
    perfil_bm3d = BM3DProfile()

    # 4. Aplica o BM3D com os argumentos definidos
    denoised = bm3d(
        ruidosa_anscombe,
        sigma_psd=sigma_est,
        profile=perfil_bm3d
    )
    denoised_sq = np.squeeze(denoised)

    filtrada_bm3d = inverse_anscombe(denoised_sq).astype(np.uint8)

    end = time.time()

    time_bm3d = end - ini

    skimage.io.imsave(f'{dir_out_bm3d}/{file_name}', np.clip(filtrada_bm3d, 0, 255).astype(np.uint8))

    p3_bm3d = peak_signal_noise_ratio(img, filtrada_bm3d.astype(np.uint8))
    print('\nPSNR (BM3D): %f' %p3_bm3d)
    s3_bm3d = structural_similarity(img, filtrada_bm3d.astype(np.uint8))
    print('SSIM (BM3D): %f' %s3_bm3d)
    print('Total Elapsed time (BM3D): %f s' %(time_bm3d))

    dict = {
        's1_NLM': s1_nlm,        
        's2_GNLM': s2_gnlm,
        's3_BM3D': s3_bm3d,
        'p1_NLM': p1_nlm,
        'p2_GLM': p2_gnlm,
        'p3_GLM': p3_bm3d,
        'time_nlm':time_nlm,
        'time_geonlm':time_geonlm,
        'time_bm3d':time_bm3d,
        'h_nlm':h_nlm,
        'h_geo':h_geo,
        'sigma':sigma_est,
        'image': file_name   
    }
    array_dicts.append(dict)
# Out:
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.08 | q_nlm = 8.12 | h_nlm = 8.75
# [INFO]                 q_geo = 9.26 | h_geo = 9.99
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 32.447089
# SSIM (NLM padrão): 0.912113
# Elapsed time (NLM): 11.772222 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 32.087157
# SSIM (GEO NLM): 0.867640
# Total Elapsed time (GEONLM): 55.694825 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 34.812273
# SSIM (BM3D): 0.940222
# Total Elapsed time (BM3D): 1.438800 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.22 | q_nlm = 8.34 | h_nlm = 10.20
# [INFO]                 q_geo = 9.52 | h_geo = 11.65
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 31.521686
# SSIM (NLM padrão): 0.913119
# Elapsed time (NLM): 2.067431 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 32.142485
# SSIM (GEO NLM): 0.920318
# Total Elapsed time (GEONLM): 51.082887 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.363202
# SSIM (BM3D): 0.942337
# Total Elapsed time (BM3D): 1.966953 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.06 | q_nlm = 8.10 | h_nlm = 8.62
# [INFO]                 q_geo = 9.24 | h_geo = 9.84
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.577031
# SSIM (NLM padrão): 0.888739
# Elapsed time (NLM): 2.198690 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.091837
# SSIM (GEO NLM): 0.798099
# Total Elapsed time (GEONLM): 54.598527 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.090601
# SSIM (BM3D): 0.929494
# Total Elapsed time (BM3D): 1.870995 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.10 | q_nlm = 8.15 | h_nlm = 8.97
# [INFO]                 q_geo = 9.30 | h_geo = 10.24
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 28.613699
# SSIM (NLM padrão): 0.913317
# Elapsed time (NLM): 2.096485 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 29.074405
# SSIM (GEO NLM): 0.916795
# Total Elapsed time (GEONLM): 52.130617 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.491733
# SSIM (BM3D): 0.956803
# Total Elapsed time (BM3D): 1.374062 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.22 | q_nlm = 8.33 | h_nlm = 10.16
# [INFO]                 q_geo = 9.51 | h_geo = 11.60
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 31.833640
# SSIM (NLM padrão): 0.916298
# Elapsed time (NLM): 2.134284 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 32.175255
# SSIM (GEO NLM): 0.921937
# Total Elapsed time (GEONLM): 52.040281 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.051400
# SSIM (BM3D): 0.930591
# Total Elapsed time (BM3D): 2.222762 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.10 | q_nlm = 8.15 | h_nlm = 8.94
# [INFO]                 q_geo = 9.30 | h_geo = 10.20
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 29.950010
# SSIM (NLM padrão): 0.886319
# Elapsed time (NLM): 2.247806 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 29.916811
# SSIM (GEO NLM): 0.842554
# Total Elapsed time (GEONLM): 54.000696 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.962138
# SSIM (BM3D): 0.920152
# Total Elapsed time (BM3D): 1.421678 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.68 | q_nlm = 9.00 | h_nlm = 15.11
# [INFO]                 q_geo = 10.31 | h_geo = 17.30
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 28.112539
# SSIM (NLM padrão): 0.826203
# Elapsed time (NLM): 2.187469 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 29.318070
# SSIM (GEO NLM): 0.887531
# Total Elapsed time (GEONLM): 54.207962 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 27.480792
# SSIM (BM3D): 0.833996
# Total Elapsed time (BM3D): 1.204966 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.49 | q_nlm = 8.72 | h_nlm = 12.97
# [INFO]                 q_geo = 9.98 | h_geo = 14.83
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.442652
# SSIM (NLM padrão): 0.880006
# Elapsed time (NLM): 2.187533 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 31.066631
# SSIM (GEO NLM): 0.905334
# Total Elapsed time (GEONLM): 53.574193 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 30.052189
# SSIM (BM3D): 0.877209
# Total Elapsed time (BM3D): 1.313665 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.50 | q_nlm = 8.74 | h_nlm = 13.11
# [INFO]                 q_geo = 10.00 | h_geo = 15.00
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 29.986748
# SSIM (NLM padrão): 0.854563
# Elapsed time (NLM): 2.294394 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.836778
# SSIM (GEO NLM): 0.897762
# Total Elapsed time (GEONLM): 52.690885 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 29.891085
# SSIM (BM3D): 0.866601
# Total Elapsed time (BM3D): 1.283165 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.42 | q_nlm = 8.63 | h_nlm = 12.25
# [INFO]                 q_geo = 9.86 | h_geo = 14.00
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.021962
# SSIM (NLM padrão): 0.946023
# Elapsed time (NLM): 2.227444 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.285295
# SSIM (GEO NLM): 0.953757
# Total Elapsed time (GEONLM): 51.192979 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 30.058227
# SSIM (BM3D): 0.944589
# Total Elapsed time (BM3D): 1.440296 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.63 | q_nlm = 8.93 | h_nlm = 14.55
# [INFO]                 q_geo = 10.23 | h_geo = 16.66
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 29.957294
# SSIM (NLM padrão): 0.887498
# Elapsed time (NLM): 2.253796 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.610887
# SSIM (GEO NLM): 0.919181
# Total Elapsed time (GEONLM): 52.102014 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 29.299835
# SSIM (BM3D): 0.886918
# Total Elapsed time (BM3D): 1.254527 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.28 | q_nlm = 8.42 | h_nlm = 10.81
# [INFO]                 q_geo = 9.62 | h_geo = 12.35
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 32.137201
# SSIM (NLM padrão): 0.942208
# Elapsed time (NLM): 2.347845 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 32.507919
# SSIM (GEO NLM): 0.944591
# Total Elapsed time (GEONLM): 50.979580 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.302439
# SSIM (BM3D): 0.952305
# Total Elapsed time (BM3D): 1.245388 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.07 | q_nlm = 8.11 | h_nlm = 8.70
# [INFO]                 q_geo = 9.26 | h_geo = 9.93
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.905453
# SSIM (NLM padrão): 0.872652
# Elapsed time (NLM): 2.321251 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 31.123639
# SSIM (GEO NLM): 0.872625
# Total Elapsed time (GEONLM): 52.362762 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.866538
# SSIM (BM3D): 0.907250
# Total Elapsed time (BM3D): 1.595826 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.40 | q_nlm = 8.60 | h_nlm = 12.07
# [INFO]                 q_geo = 9.83 | h_geo = 13.79
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 31.227158
# SSIM (NLM padrão): 0.895077
# Elapsed time (NLM): 2.436791 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 31.718122
# SSIM (GEO NLM): 0.907246
# Total Elapsed time (GEONLM): 54.250941 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 30.863856
# SSIM (BM3D): 0.893466
# Total Elapsed time (BM3D): 2.227610 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.14 | q_nlm = 8.21 | h_nlm = 9.37
# [INFO]                 q_geo = 9.37 | h_geo = 10.70
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 32.645197
# SSIM (NLM padrão): 0.885678
# Elapsed time (NLM): 2.241011 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 32.695005
# SSIM (GEO NLM): 0.871720
# Total Elapsed time (GEONLM): 52.467799 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.419260
# SSIM (BM3D): 0.897351
# Total Elapsed time (BM3D): 1.182483 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.22 | q_nlm = 8.33 | h_nlm = 10.14
# [INFO]                 q_geo = 9.51 | h_geo = 11.58
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 31.545780
# SSIM (NLM padrão): 0.896159
# Elapsed time (NLM): 2.164453 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 31.544571
# SSIM (GEO NLM): 0.872812
# Total Elapsed time (GEONLM): 53.173582 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.396017
# SSIM (BM3D): 0.889543
# Total Elapsed time (BM3D): 1.694198 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.04 | q_nlm = 8.06 | h_nlm = 8.36
# [INFO]                 q_geo = 9.19 | h_geo = 9.54
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 33.491379
# SSIM (NLM padrão): 0.913940
# Elapsed time (NLM): 2.294157 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 33.330379
# SSIM (GEO NLM): 0.873658
# Total Elapsed time (GEONLM): 51.994050 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 36.264873
# SSIM (BM3D): 0.946006
# Total Elapsed time (BM3D): 0.988535 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.12 | q_nlm = 8.18 | h_nlm = 9.14
# [INFO]                 q_geo = 9.33 | h_geo = 10.43
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 33.114592
# SSIM (NLM padrão): 0.903188
# Elapsed time (NLM): 2.112789 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 32.958584
# SSIM (GEO NLM): 0.871972
# Total Elapsed time (GEONLM): 51.466011 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 34.271619
# SSIM (BM3D): 0.915923
# Total Elapsed time (BM3D): 1.713672 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.08 | q_nlm = 8.12 | h_nlm = 8.80
# [INFO]                 q_geo = 9.27 | h_geo = 10.04
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 35.579209
# SSIM (NLM padrão): 0.911951
# Elapsed time (NLM): 2.097157 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 34.868552
# SSIM (GEO NLM): 0.864933
# Total Elapsed time (GEONLM): 51.495647 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 37.738576
# SSIM (BM3D): 0.939805
# Total Elapsed time (BM3D): 1.488249 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.06 | q_nlm = 8.10 | h_nlm = 8.62
# [INFO]                 q_geo = 9.24 | h_geo = 9.83
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 32.000305
# SSIM (NLM padrão): 0.864919
# Elapsed time (NLM): 2.166710 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 32.223959
# SSIM (GEO NLM): 0.871385
# Total Elapsed time (GEONLM): 50.607877 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.772933
# SSIM (BM3D): 0.902563
# Total Elapsed time (BM3D): 1.501947 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.05 | q_nlm = 8.07 | h_nlm = 8.47
# [INFO]                 q_geo = 9.21 | h_geo = 9.66
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 33.887944
# SSIM (NLM padrão): 0.933306
# Elapsed time (NLM): 2.177068 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 33.576286
# SSIM (GEO NLM): 0.894510
# Total Elapsed time (GEONLM): 51.691419 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 36.059741
# SSIM (BM3D): 0.956091
# Total Elapsed time (BM3D): 1.186121 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.05 | q_nlm = 8.08 | h_nlm = 8.49
# [INFO]                 q_geo = 9.22 | h_geo = 9.69
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 33.209092
# SSIM (NLM padrão): 0.889943
# Elapsed time (NLM): 2.085066 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 32.881994
# SSIM (GEO NLM): 0.859045
# Total Elapsed time (GEONLM): 50.681405 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 35.474466
# SSIM (BM3D): 0.933784
# Total Elapsed time (BM3D): 0.971167 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.49 | q_nlm = 8.73 | h_nlm = 13.04
# [INFO]                 q_geo = 9.99 | h_geo = 14.91
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 29.639669
# SSIM (NLM padrão): 0.886372
# Elapsed time (NLM): 2.116368 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.538230
# SSIM (GEO NLM): 0.920517
# Total Elapsed time (GEONLM): 50.896833 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 29.741278
# SSIM (BM3D): 0.893962
# Total Elapsed time (BM3D): 0.954269 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.16 | q_nlm = 8.23 | h_nlm = 9.52
# [INFO]                 q_geo = 9.40 | h_geo = 10.87
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 33.174665
# SSIM (NLM padrão): 0.904044
# Elapsed time (NLM): 2.107013 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 33.509846
# SSIM (GEO NLM): 0.904042
# Total Elapsed time (GEONLM): 51.388327 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 34.549342
# SSIM (BM3D): 0.926212
# Total Elapsed time (BM3D): 0.979290 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.22 | q_nlm = 8.33 | h_nlm = 10.19
# [INFO]                 q_geo = 9.52 | h_geo = 11.64
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 31.147531
# SSIM (NLM padrão): 0.870180
# Elapsed time (NLM): 2.119570 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 31.614670
# SSIM (GEO NLM): 0.893507
# Total Elapsed time (GEONLM): 50.833570 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.673124
# SSIM (BM3D): 0.886205
# Total Elapsed time (BM3D): 0.924470 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.81 | q_nlm = 9.19 | h_nlm = 16.64
# [INFO]                 q_geo = 10.54 | h_geo = 19.08
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 29.390610
# SSIM (NLM padrão): 0.891221
# Elapsed time (NLM): 2.109694 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 29.873060
# SSIM (GEO NLM): 0.917924
# Total Elapsed time (GEONLM): 51.019044 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 27.805938
# SSIM (BM3D): 0.877234
# Total Elapsed time (BM3D): 0.935683 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.16 | q_nlm = 8.24 | h_nlm = 9.53
# [INFO]                 q_geo = 9.40 | h_geo = 10.88
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.471270
# SSIM (NLM padrão): 0.904135
# Elapsed time (NLM): 2.112203 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.677002
# SSIM (GEO NLM): 0.912725
# Total Elapsed time (GEONLM): 48.586924 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.505104
# SSIM (BM3D): 0.909088
# Total Elapsed time (BM3D): 1.001115 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.17 | q_nlm = 8.25 | h_nlm = 9.61
# [INFO]                 q_geo = 9.42 | h_geo = 10.97
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.822196
# SSIM (NLM padrão): 0.874014
# Elapsed time (NLM): 2.101803 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 31.311349
# SSIM (GEO NLM): 0.896867
# Total Elapsed time (GEONLM): 50.329038 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.761678
# SSIM (BM3D): 0.898678
# Total Elapsed time (BM3D): 0.943473 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.25 | q_nlm = 8.37 | h_nlm = 10.42
# [INFO]                 q_geo = 9.55 | h_geo = 11.90
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.181537
# SSIM (NLM padrão): 0.915019
# Elapsed time (NLM): 2.105918 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.733943
# SSIM (GEO NLM): 0.929064
# Total Elapsed time (GEONLM): 50.400070 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.161195
# SSIM (BM3D): 0.926637
# Total Elapsed time (BM3D): 1.204072 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.10 | q_nlm = 8.15 | h_nlm = 8.96
# [INFO]                 q_geo = 9.30 | h_geo = 10.23
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.759881
# SSIM (NLM padrão): 0.907288
# Elapsed time (NLM): 2.085310 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.899754
# SSIM (GEO NLM): 0.900956
# Total Elapsed time (GEONLM): 50.309885 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.024499
# SSIM (BM3D): 0.938504
# Total Elapsed time (BM3D): 0.922769 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.22 | q_nlm = 8.33 | h_nlm = 10.20
# [INFO]                 q_geo = 9.52 | h_geo = 11.64
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 31.728626
# SSIM (NLM padrão): 0.938689
# Elapsed time (NLM): 2.130010 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 32.174809
# SSIM (GEO NLM): 0.940565
# Total Elapsed time (GEONLM): 49.414138 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.728374
# SSIM (BM3D): 0.947969
# Total Elapsed time (BM3D): 0.919665 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.24 | q_nlm = 8.35 | h_nlm = 10.33
# [INFO]                 q_geo = 9.54 | h_geo = 11.79
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.807314
# SSIM (NLM padrão): 0.798900
# Elapsed time (NLM): 2.122208 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 31.548644
# SSIM (GEO NLM): 0.850087
# Total Elapsed time (GEONLM): 51.393074 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 30.754947
# SSIM (BM3D): 0.799542
# Total Elapsed time (BM3D): 0.929354 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.11 | q_nlm = 8.16 | h_nlm = 9.05
# [INFO]                 q_geo = 9.32 | h_geo = 10.33
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 31.751263
# SSIM (NLM padrão): 0.906576
# Elapsed time (NLM): 2.121223 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 31.670215
# SSIM (GEO NLM): 0.869196
# Total Elapsed time (GEONLM): 50.600774 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.158177
# SSIM (BM3D): 0.925480
# Total Elapsed time (BM3D): 0.981275 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.05 | q_nlm = 8.08 | h_nlm = 8.51
# [INFO]                 q_geo = 9.22 | h_geo = 9.71
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 33.277989
# SSIM (NLM padrão): 0.907854
# Elapsed time (NLM): 2.144749 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 32.745699
# SSIM (GEO NLM): 0.857779
# Total Elapsed time (GEONLM): 51.080274 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 35.221404
# SSIM (BM3D): 0.930723
# Total Elapsed time (BM3D): 1.236413 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.12 | q_nlm = 8.19 | h_nlm = 9.20
# [INFO]                 q_geo = 9.34 | h_geo = 10.50
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 31.631635
# SSIM (NLM padrão): 0.872387
# Elapsed time (NLM): 2.092204 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 31.992481
# SSIM (GEO NLM): 0.882747
# Total Elapsed time (GEONLM): 51.101570 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.882546
# SSIM (BM3D): 0.895539
# Total Elapsed time (BM3D): 0.967571 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.03 | q_nlm = 8.05 | h_nlm = 8.30
# [INFO]                 q_geo = 9.18 | h_geo = 9.47
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 31.591191
# SSIM (NLM padrão): 0.828167
# Elapsed time (NLM): 2.114586 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 31.455013
# SSIM (GEO NLM): 0.816755
# Total Elapsed time (GEONLM): 51.107245 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.304295
# SSIM (BM3D): 0.870905
# Total Elapsed time (BM3D): 0.927338 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.09 | q_nlm = 8.14 | h_nlm = 8.90
# [INFO]                 q_geo = 9.29 | h_geo = 10.16
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.423379
# SSIM (NLM padrão): 0.873912
# Elapsed time (NLM): 2.109309 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.734253
# SSIM (GEO NLM): 0.879148
# Total Elapsed time (GEONLM): 50.184737 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.804645
# SSIM (BM3D): 0.919266
# Total Elapsed time (BM3D): 0.923337 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.11 | q_nlm = 8.17 | h_nlm = 9.08
# [INFO]                 q_geo = 9.32 | h_geo = 10.36
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.628486
# SSIM (NLM padrão): 0.885763
# Elapsed time (NLM): 2.105785 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.915786
# SSIM (GEO NLM): 0.886866
# Total Elapsed time (GEONLM): 51.075133 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.831746
# SSIM (BM3D): 0.928476
# Total Elapsed time (BM3D): 0.929161 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.12 | q_nlm = 8.19 | h_nlm = 9.20
# [INFO]                 q_geo = 9.34 | h_geo = 10.50
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.250763
# SSIM (NLM padrão): 0.917633
# Elapsed time (NLM): 2.116681 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.607988
# SSIM (GEO NLM): 0.922400
# Total Elapsed time (GEONLM): 50.467139 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.198518
# SSIM (BM3D): 0.944912
# Total Elapsed time (BM3D): 0.975366 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 2.03 | q_nlm = 9.50 | h_nlm = 19.34
# [INFO]                 q_geo = 10.93 | h_geo = 22.24
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 22.641835
# SSIM (NLM padrão): 0.615103
# Elapsed time (NLM): 2.120038 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 24.521466
# SSIM (GEO NLM): 0.783777
# Total Elapsed time (GEONLM): 51.202948 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 22.845182
# SSIM (BM3D): 0.664554
# Total Elapsed time (BM3D): 0.953079 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.10 | q_nlm = 8.15 | h_nlm = 8.96
# [INFO]                 q_geo = 9.30 | h_geo = 10.22
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.395525
# SSIM (NLM padrão): 0.895615
# Elapsed time (NLM): 2.119232 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.358306
# SSIM (GEO NLM): 0.867755
# Total Elapsed time (GEONLM): 50.919355 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.348177
# SSIM (BM3D): 0.932514
# Total Elapsed time (BM3D): 0.897937 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.26 | q_nlm = 8.38 | h_nlm = 10.53
# [INFO]                 q_geo = 9.57 | h_geo = 12.02
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 29.155899
# SSIM (NLM padrão): 0.879540
# Elapsed time (NLM): 2.098791 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 29.791334
# SSIM (GEO NLM): 0.909033
# Total Elapsed time (GEONLM): 50.412583 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 29.818417
# SSIM (BM3D): 0.897055
# Total Elapsed time (BM3D): 0.930398 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.38 | q_nlm = 8.57 | h_nlm = 11.81
# [INFO]                 q_geo = 9.79 | h_geo = 13.50
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 28.503959
# SSIM (NLM padrão): 0.815271
# Elapsed time (NLM): 2.103990 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 29.517894
# SSIM (GEO NLM): 0.879814
# Total Elapsed time (GEONLM): 50.931591 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 28.824479
# SSIM (BM3D): 0.848435
# Total Elapsed time (BM3D): 0.923399 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.08 | q_nlm = 8.12 | h_nlm = 8.78
# [INFO]                 q_geo = 9.27 | h_geo = 10.02
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.711121
# SSIM (NLM padrão): 0.890184
# Elapsed time (NLM): 2.110332 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.711227
# SSIM (GEO NLM): 0.851109
# Total Elapsed time (GEONLM): 50.792855 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.057509
# SSIM (BM3D): 0.928039
# Total Elapsed time (BM3D): 0.950309 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.44 | q_nlm = 8.65 | h_nlm = 12.45
# [INFO]                 q_geo = 9.89 | h_geo = 14.23
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 29.357227
# SSIM (NLM padrão): 0.913991
# Elapsed time (NLM): 2.116871 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 29.678104
# SSIM (GEO NLM): 0.921932
# Total Elapsed time (GEONLM): 52.052903 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 30.090993
# SSIM (BM3D): 0.953834
# Total Elapsed time (BM3D): 0.893744 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.07 | q_nlm = 8.10 | h_nlm = 8.63
# [INFO]                 q_geo = 9.24 | h_geo = 9.84
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.374516
# SSIM (NLM padrão): 0.886659
# Elapsed time (NLM): 2.124136 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.857196
# SSIM (GEO NLM): 0.898102
# Total Elapsed time (GEONLM): 50.101432 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.630001
# SSIM (BM3D): 0.928088
# Total Elapsed time (BM3D): 1.134218 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.26 | q_nlm = 8.39 | h_nlm = 10.60
# [INFO]                 q_geo = 9.59 | h_geo = 12.10
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 32.281182
# SSIM (NLM padrão): 0.930516
# Elapsed time (NLM): 2.095412 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 32.483798
# SSIM (GEO NLM): 0.925221
# Total Elapsed time (GEONLM): 51.098896 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.045882
# SSIM (BM3D): 0.941156
# Total Elapsed time (BM3D): 0.962569 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.22 | q_nlm = 8.34 | h_nlm = 10.20
# [INFO]                 q_geo = 9.52 | h_geo = 11.65
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 28.424424
# SSIM (NLM padrão): 0.900458
# Elapsed time (NLM): 2.107543 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 28.977823
# SSIM (GEO NLM): 0.912433
# Total Elapsed time (GEONLM): 50.203726 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 30.398645
# SSIM (BM3D): 0.932129
# Total Elapsed time (BM3D): 0.937366 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.13 | q_nlm = 8.20 | h_nlm = 9.30
# [INFO]                 q_geo = 9.36 | h_geo = 10.61
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 31.740511
# SSIM (NLM padrão): 0.914569
# Elapsed time (NLM): 2.176126 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 32.124912
# SSIM (GEO NLM): 0.920602
# Total Elapsed time (GEONLM): 51.205992 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.864336
# SSIM (BM3D): 0.926299
# Total Elapsed time (BM3D): 0.957484 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.16 | q_nlm = 8.25 | h_nlm = 9.61
# [INFO]                 q_geo = 9.41 | h_geo = 10.97
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.138396
# SSIM (NLM padrão): 0.916634
# Elapsed time (NLM): 2.110940 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.505398
# SSIM (GEO NLM): 0.911488
# Total Elapsed time (GEONLM): 50.864216 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.095830
# SSIM (BM3D): 0.929648
# Total Elapsed time (BM3D): 0.924579 s

# %%
array_dicts
# Out:
# [{'s1_NLM': np.float64(0.912634723754207),
#   'p1_NLM': np.float64(32.46842995819691),
#   's2_GNLM': np.float64(0.8651431371933848),
#   'p2_GLM': np.float64(32.057281062400456),
#   's3_BM3D': np.float64(0.9408981699441976),
#   'p3_GLM': np.float64(34.876175523324314),
#   'time_nlm': 2.0467700958251953,
#   'time_geonlm': 59.160722970962524,
#   'time_bm3d': 1.473651647567749,
#   'h_nlm': np.float64(8.680539305427711),
#   'h_geo': np.float64(9.907294769664562),
#   'sigma': np.float64(1.070845042794323),
#   'image': '0.gif'},
#  {'s1_NLM': np.float64(0.9107669749740401),
#   'p1_NLM': np.float64(31.531467893383702),
#   's2_GNLM': np.float64(0.921019323677976),
#   'p2_GLM': np.float64(32.241838750107924),
#   's3_BM3D': np.float64(0.9400335218049957),
#   'p3_GLM': np.float64(33.23723729342227),
#   'time_nlm': 2.155344247817993,
#   'time_geonlm': 55.00483989715576,
#   'time_bm3d': 1.3140075206756592,
#   'h_nlm': np.float64(10.327743032812084),
#   'h_geo': np.float64(11.793153435148277),
#   'sigma': np.float64(1.2362871632976247),
#   'image': '1.gif'},
#  {'s1_NLM': np.float64(0.8852886624657339),
#   'p1_NLM': np.float64(30.52698905766206),
#   's2_GNLM': np.float64(0.7866256103266197),
#   'p2_GLM': np.float64(29.948943306421146),
#   's3_BM3D': np.float64(0.9272073526376124),
#   'p3_GLM': np.float64(33.03428924875882),
#   'time_nlm': 2.1142451763153076,
#   'time_geonlm': 54.83390974998474,
#   'time_bm3d': 1.0951378345489502,
#   'h_nlm': np.float64(8.480143264628826),
#   'h_geo': np.float64(9.678195164585945),
#   'sigma': np.float64(1.0501449939024565),
#   'image': '10.gif'},
#  {'s1_NLM': np.float64(0.9142377488114263),
#   'p1_NLM': np.float64(28.653856540934623),
#   's2_GNLM': np.float64(0.9177605148153104),
#   'p2_GLM': np.float64(29.094445851675545),
#   's3_BM3D': np.float64(0.9565312463667984),
#   'p3_GLM': np.float64(31.45931777724838),
#   'time_nlm': 2.165710926055908,
#   'time_geonlm': 53.85787868499756,
#   'time_bm3d': 1.0416221618652344,
#   'h_nlm': np.float64(9.043377029262375),
#   'h_geo': np.float64(10.322271704091737),
#   'sigma': np.float64(1.1079942794985558),
#   'image': '11.gif'},
#  {'s1_NLM': np.float64(0.9154423144307885),
#   'p1_NLM': np.float64(31.834577916745616),
#   's2_GNLM': np.float64(0.9226587573325521),
#   'p2_GLM': np.float64(32.20648199042105),
#   's3_BM3D': np.float64(0.9297609498898581),
#   'p3_GLM': np.float64(32.9964055533151),
#   'time_nlm': 2.1267991065979004,
#   'time_geonlm': 54.48424673080444,
#   'time_bm3d': 1.469520092010498,
#   'h_nlm': np.float64(10.345773248341374),
#   'h_geo': np.float64(11.813825714940425),
#   'sigma': np.float64(1.2380545628691693),
#   'image': '12.gif'},
#  {'s1_NLM': np.float64(0.8866805224196589),
#   'p1_NLM': np.float64(30.015140272028695),
#   's2_GNLM': np.float64(0.8437367111669002),
#   'p2_GLM': np.float64(30.001514060189074),
#   's3_BM3D': np.float64(0.9203153612847207),
#   'p3_GLM': np.float64(31.995686504309333),
#   'time_nlm': 2.148918628692627,
#   'time_geonlm': 61.42265295982361,
#   'time_bm3d': 1.422612190246582,
#   'h_nlm': np.float64(8.990568283756263),
#   'h_geo': np.float64(10.261860466905157),
#   'sigma': np.float64(1.102613431502988),
#   'image': '13.gif'},
#  {'s1_NLM': np.float64(0.8283105487663783),
#   'p1_NLM': np.float64(28.15557954874685),
#   's2_GNLM': np.float64(0.8880758074641636),
#   'p2_GLM': np.float64(29.337847776172758),
#   's3_BM3D': np.float64(0.8342354369793967),
#   'p3_GLM': np.float64(27.481451039219664),
#   'time_nlm': 2.312169313430786,
#   'time_geonlm': 60.75702738761902,
#   'time_bm3d': 1.3729422092437744,
#   'h_nlm': np.float64(15.095181766452146),
#   'h_geo': np.float64(17.288212333544703),
#   'sigma': np.float64(1.6769320431559078),
#   'image': '14.gif'},
#  {'s1_NLM': np.float64(0.8857389793384687),
#   'p1_NLM': np.float64(30.606070669038637),
#   's2_GNLM': np.float64(0.9081640569087628),
#   'p2_GLM': np.float64(31.1483766094652),
#   's3_BM3D': np.float64(0.8821539737104764),
#   'p3_GLM': np.float64(30.18764858223601),
#   'time_nlm': 2.4061527252197266,
#   'time_geonlm': 59.53622555732727,
#   'time_bm3d': 1.343526840209961,
#   'h_nlm': np.float64(12.647485405178397),
#   'h_geo': np.float64(14.459124021372428),
#   'sigma': np.float64(1.4569005171962426),
#   'image': '15.gif'},
#  {'s1_NLM': np.float64(0.8504385190710476),
#   'p1_NLM': np.float64(29.923225058300073),
#   's2_GNLM': np.float64(0.8958775310333752),
#   'p2_GLM': np.float64(30.810759163756714),
#   's3_BM3D': np.float64(0.8650665520830743),
#   'p3_GLM': np.float64(29.860471141021698),
#   'time_nlm': 2.4739279747009277,
#   'time_geonlm': 57.87128281593323,
#   'time_bm3d': 1.593400001525879,
#   'h_nlm': np.float64(13.202869879411908),
#   'h_geo': np.float64(15.099483060033783),
#   'sigma': np.float64(1.5078712603998472),
#   'image': '16.gif'},
#  {'s1_NLM': np.float64(0.9461130467601361),
#   'p1_NLM': np.float64(29.947719723383486),
#   's2_GNLM': np.float64(0.953423132777467),
#   'p2_GLM': np.float64(30.198526816779385),
#   's3_BM3D': np.float64(0.9458982503906516),
#   'p3_GLM': np.float64(30.094838128926437),
#   'time_nlm': 2.2458913326263428,
#   'time_geonlm': 58.167680740356445,
#   'time_bm3d': 1.4103267192840576,
#   'h_nlm': np.float64(12.090437581576625),
#   'h_geo': np.float64(13.817700232819421),
#   'sigma': np.float64(1.4051006868536262),
#   'image': '17.gif'},
#  {'s1_NLM': np.float64(0.8861701516293163),
#   'p1_NLM': np.float64(29.91671774596987),
#   's2_GNLM': np.float64(0.9188163127861243),
#   'p2_GLM': np.float64(30.55478648525697),
#   's3_BM3D': np.float64(0.8862683530164842),
#   'p3_GLM': np.float64(29.239122411477638),
#   'time_nlm': 2.3040411472320557,
#   'time_geonlm': 55.01263904571533,
#   'time_bm3d': 1.4477922916412354,
#   'h_nlm': np.float64(14.70492699005753),
#   'h_geo': np.float64(16.835912882473707),
#   'sigma': np.float64(1.6426133852354825),
#   'image': '18.gif'},
#  {'s1_NLM': np.float64(0.9415239684603836),
#   'p1_NLM': np.float64(32.12914459502667),
#   's2_GNLM': np.float64(0.9441899066289484),
#   'p2_GLM': np.float64(32.494067785915355),
#   's3_BM3D': np.float64(0.9520299635217835),
#   'p3_GLM': np.float64(33.31287462050832),
#   'time_nlm': 2.346552848815918,
#   'time_geonlm': 56.09883975982666,
#   'time_bm3d': 1.0850443840026855,
#   'h_nlm': np.float64(10.752162011946016),
#   'h_geo': np.float64(12.279953550495438),
#   'sigma': np.float64(1.2776577455085132),
#   'image': '19.gif'},
#  {'s1_NLM': np.float64(0.8731111053355741),
#   'p1_NLM': np.float64(30.95749608281961),
#   's2_GNLM': np.float64(0.8746521357356497),
#   'p2_GLM': np.float64(31.19567346864993),
#   's3_BM3D': np.float64(0.9071984181255643),
#   'p3_GLM': np.float64(32.8890205682261),
#   'time_nlm': 2.1551105976104736,
#   'time_geonlm': 55.12981367111206,
#   'time_bm3d': 1.3779363632202148,
#   'h_nlm': np.float64(8.795554581976207),
#   'h_geo': np.float64(10.038813566542583),
#   'sigma': np.float64(1.0826664715685566),
#   'image': '2.gif'},
#  {'s1_NLM': np.float64(0.8966436226811463),
#   'p1_NLM': np.float64(31.29634137852381),
#   's2_GNLM': np.float64(0.906846403034205),
#   'p2_GLM': np.float64(31.747302129854333),
#   's3_BM3D': np.float64(0.8941427689541024),
#   'p3_GLM': np.float64(30.938639706135604),
#   'time_nlm': 2.2231149673461914,
#   'time_geonlm': 58.04662847518921,
#   'time_bm3d': 1.3800530433654785,
#   'h_nlm': np.float64(12.01691963502437),
#   'h_geo': np.float64(13.73310816674525),
#   'sigma': np.float64(1.3982117168036594),
#   'image': '20.gif'},
#  {'s1_NLM': np.float64(0.8846799219618221),
#   'p1_NLM': np.float64(32.66273684299128),
#   's2_GNLM': np.float64(0.8731362931072222),
#   'p2_GLM': np.float64(32.75194426615204),
#   's3_BM3D': np.float64(0.8967357749663412),
#   'p3_GLM': np.float64(33.422461852545894),
#   'time_nlm': 2.485167980194092,
#   'time_geonlm': 58.87575817108154,
#   'time_bm3d': 1.4432849884033203,
#   'h_nlm': np.float64(9.45103023390475),
#   'h_geo': np.float64(10.788779661818536),
#   'sigma': np.float64(1.1492413204793934),
#   'image': '21.gif'},
#  {'s1_NLM': np.float64(0.8964632560520569),
#   'p1_NLM': np.float64(31.526720258645696),
#   's2_GNLM': np.float64(0.8721850917823373),
#   'p2_GLM': np.float64(31.522495809429515),
#   's3_BM3D': np.float64(0.8895127653895722),
#   'p3_GLM': np.float64(31.46935784321284),
#   'time_nlm': 2.25162935256958,
#   'time_geonlm': 58.75887608528137,
#   'time_bm3d': 1.5818912982940674,
#   'h_nlm': np.float64(10.086218546783844),
#   'h_geo': np.float64(11.516303656460677),
#   'sigma': np.float64(1.2125253597579926),
#   'image': '22.gif'},
#  {'s1_NLM': np.float64(0.9157596531032419),
#   'p1_NLM': np.float64(33.61529041616908),
#   's2_GNLM': np.float64(0.8776852874333367),
#   'p2_GLM': np.float64(33.45930977737275),
#   's3_BM3D': np.float64(0.9465888412961799),
#   'p3_GLM': np.float64(36.26961879067659),
#   'time_nlm': 2.2511212825775146,
#   'time_geonlm': 57.89762353897095,
#   'time_bm3d': 1.422746181488037,
#   'h_nlm': np.float64(8.424881209354345),
#   'h_geo': np.float64(9.61502884832185),
#   'sigma': np.float64(1.0444133170919372),
#   'image': '23.gif'},
#  {'s1_NLM': np.float64(0.9044408867113553),
#   'p1_NLM': np.float64(33.13611136765519),
#   's2_GNLM': np.float64(0.8710993081691382),
#   'p2_GLM': np.float64(32.91574206216971),
#   's3_BM3D': np.float64(0.9177621819520267),
#   'p3_GLM': np.float64(34.36806950844131),
#   'time_nlm': 2.244750499725342,
#   'time_geonlm': 56.53134107589722,
#   'time_bm3d': 1.6415936946868896,
#   'h_nlm': np.float64(9.073626500866583),
#   'h_geo': np.float64(10.356878168532262),
#   'sigma': np.float64(1.1110725593323152),
#   'image': '24.gif'},
#  {'s1_NLM': np.float64(0.9100720791833864),
#   'p1_NLM': np.float64(35.505089913151934),
#   's2_GNLM': np.float64(0.8607226386243411),
#   'p2_GLM': np.float64(34.75025856674803),
#   's3_BM3D': np.float64(0.9391210498183458),
#   'p3_GLM': np.float64(37.62210084869881),
#   'time_nlm': 2.2616326808929443,
#   'time_geonlm': 57.52526235580444,
#   'time_bm3d': 1.246114730834961,
#   'h_nlm': np.float64(8.742403384824348),
#   'h_geo': np.float64(9.978033000963524),
#   'sigma': np.float64(1.0772088300616054),
#   'image': '25.gif'},
#  {'s1_NLM': np.float64(0.8651140436007837),
#   'p1_NLM': np.float64(31.98242050214096),
#   's2_GNLM': np.float64(0.8713813310157175),
#   'p2_GLM': np.float64(32.202826530089716),
#   's3_BM3D': np.float64(0.90125544906928),
#   'p3_GLM': np.float64(33.743227726307545),
#   'time_nlm': 2.202873706817627,
#   'time_geonlm': 56.31260085105896,
#   'time_bm3d': 1.159005880355835,
#   'h_nlm': np.float64(8.644130071523856),
#   'h_geo': np.float64(9.86566570059762),
#   'sigma': np.float64(1.0670939139436768),
#   'image': '26.gif'},
#  {'s1_NLM': np.float64(0.9315902521667723),
#   'p1_NLM': np.float64(33.82794421192388),
#   's2_GNLM': np.float64(0.8908186152664966),
#   'p2_GLM': np.float64(33.49980260654879),
#   's3_BM3D': np.float64(0.9569001927709742),
#   'p3_GLM': np.float64(36.12913395608547),
#   'time_nlm': 2.1831064224243164,
#   'time_geonlm': 56.5358624458313,
#   'time_bm3d': 1.2182271480560303,
#   'h_nlm': np.float64(8.353513378539903),
#   'h_geo': np.float64(9.533460076707836),
#   'sigma': np.float64(1.0369960713100357),
#   'image': '27.gif'},
#  {'s1_NLM': np.float64(0.889751642053723),
#   'p1_NLM': np.float64(33.36077963165897),
#   's2_GNLM': np.float64(0.8651000710913753),
#   'p2_GLM': np.float64(33.131309275256925),
#   's3_BM3D': np.float64(0.9330091024828145),
#   'p3_GLM': np.float64(35.49368677414745),
#   'time_nlm': 2.223965883255005,
#   'time_geonlm': 56.43779540061951,
#   'time_bm3d': 1.1960670948028564,
#   'h_nlm': np.float64(8.725350877386978),
#   'h_geo': np.float64(9.95853375278591),
#   'sigma': np.float64(1.0754559231665475),
#   'image': '28.gif'},
#  {'s1_NLM': np.float64(0.8826040231287674),
#   'p1_NLM': np.float64(29.592724957621577),
#   's2_GNLM': np.float64(0.9192847039739417),
#   'p2_GLM': np.float64(30.54309386039477),
#   's3_BM3D': np.float64(0.8918174285342512),
#   'p3_GLM': np.float64(29.68576109909948),
#   'time_nlm': 2.7950751781463623,
#   'time_geonlm': 57.96709227561951,
#   'time_bm3d': 1.1299891471862793,
#   'h_nlm': np.float64(13.198321293520904),
#   'h_geo': np.float64(15.094234977862174),
#   'sigma': np.float64(1.5074564517204057),
#   'image': '29.gif'},
#  {'s1_NLM': np.float64(0.9057459086169487),
#   'p1_NLM': np.float64(33.25972033715492),
#   's2_GNLM': np.float64(0.9043802065112473),
#   'p2_GLM': np.float64(33.57151453560513),
#   's3_BM3D': np.float64(0.9285269267274813),
#   'p3_GLM': np.float64(34.616191435873525),
#   'time_nlm': 2.458165168762207,
#   'time_geonlm': 59.95980739593506,
#   'time_bm3d': 1.8746812343597412,
#   'h_nlm': np.float64(9.4116830472913),
#   'h_geo': np.float64(10.743738455233375),
#   'sigma': np.float64(1.1452821686991763),
#   'image': '3.gif'},
#  {'s1_NLM': np.float64(0.8737570261098965),
#   'p1_NLM': np.float64(31.244361001721256),
#   's2_GNLM': np.float64(0.8943901049395373),
#   'p2_GLM': np.float64(31.66118695845227),
#   's3_BM3D': np.float64(0.8880034925623127),
#   'p3_GLM': np.float64(31.76219625611971),
#   'time_nlm': 2.3652379512786865,
#   'time_geonlm': 57.076130390167236,
#   'time_bm3d': 1.2753651142120361,
#   'h_nlm': np.float64(10.075640151991788),
#   'h_geo': np.float64(11.50418086647045),
#   'sigma': np.float64(1.2114809149811883),
#   'image': '30.gif'},
#  {'s1_NLM': np.float64(0.8900461835945601),
#   'p1_NLM': np.float64(29.348986818072934),
#   's2_GNLM': np.float64(0.9178309985562639),
#   'p2_GLM': np.float64(29.86311386396142),
#   's3_BM3D': np.float64(0.8772018841785092),
#   'p3_GLM': np.float64(27.816636363017512),
#   'time_nlm': 2.1900129318237305,
#   'time_geonlm': 56.681750774383545,
#   'time_bm3d': 1.3233215808868408,
#   'h_nlm': np.float64(16.6814606141492),
#   'h_geo': np.float64(19.131917845968193),
#   'sigma': np.float64(1.8137932800778251),
#   'image': '31.gif'},
#  {'s1_NLM': np.float64(0.9046575351999159),
#   'p1_NLM': np.float64(30.330039884777907),
#   's2_GNLM': np.float64(0.9126492005139144),
#   'p2_GLM': np.float64(30.52689586037195),
#   's3_BM3D': np.float64(0.9117794751651215),
#   'p3_GLM': np.float64(31.5623714338287),
#   'time_nlm': 2.1908528804779053,
#   'time_geonlm': 54.7604501247406,
#   'time_bm3d': 1.2649924755096436,
#   'h_nlm': np.float64(9.214866302177033),
#   'h_geo': np.float64(10.518482956712214),
#   'sigma': np.float64(1.1254079372571137),
#   'image': '32.gif'},
#  {'s1_NLM': np.float64(0.8770222890138204),
#   'p1_NLM': np.float64(30.803701022448905),
#   's2_GNLM': np.float64(0.8959292030158267),
#   'p2_GLM': np.float64(31.236730458579554),
#   's3_BM3D': np.float64(0.9007984092502106),
#   'p3_GLM': np.float64(31.8767388850706),
#   'time_nlm': 2.2047629356384277,
#   'time_geonlm': 56.02499079704285,
#   'time_bm3d': 1.5647854804992676,
#   'h_nlm': np.float64(9.425624309040622),
#   'h_geo': np.float64(10.759696856448402),
#   'sigma': np.float64(1.1466854839589826),
#   'image': '33.gif'},
#  {'s1_NLM': np.float64(0.915047436795749),
#   'p1_NLM': np.float64(30.289691767105094),
#   's2_GNLM': np.float64(0.929741601583182),
#   'p2_GLM': np.float64(30.852250521200514),
#   's3_BM3D': np.float64(0.9261715781765338),
#   'p3_GLM': np.float64(31.159613192300757),
#   'time_nlm': 2.221400737762451,
#   'time_geonlm': 55.88510775566101,
#   'time_bm3d': 1.2674548625946045,
#   'h_nlm': np.float64(10.459143430150611),
#   'h_geo': np.float64(11.9438247309653),
#   'sigma': np.float64(1.2491472928000549),
#   'image': '34.gif'},
#  {'s1_NLM': np.float64(0.906940040207402),
#   'p1_NLM': np.float64(30.818104387937275),
#   's2_GNLM': np.float64(0.9027438315652211),
#   'p2_GLM': np.float64(30.990838347724278),
#   's3_BM3D': np.float64(0.9386538009006682),
#   'p3_GLM': np.float64(33.076548361886076),
#   'time_nlm': 2.207019090652466,
#   'time_geonlm': 56.0554986000061,
#   'time_bm3d': 1.3234272003173828,
#   'h_nlm': np.float64(9.14433229513474),
#   'h_geo': np.float64(10.437774394283169),
#   'sigma': np.float64(1.1182566851107298),
#   'image': '35.gif'},
#  {'s1_NLM': np.float64(0.9389653054396818),
#   'p1_NLM': np.float64(31.678247232311634),
#   's2_GNLM': np.float64(0.9406461279861618),
#   'p2_GLM': np.float64(32.12498174112194),
#   's3_BM3D': np.float64(0.9491248182372721),
#   'p3_GLM': np.float64(32.775996097427125),
#   'time_nlm': 2.198953628540039,
#   'time_geonlm': 55.02091574668884,
#   'time_bm3d': 1.0962529182434082,
#   'h_nlm': np.float64(9.955216011554304),
#   'h_geo': np.float64(11.366191633428075),
#   'sigma': np.float64(1.199568730238956),
#   'image': '36.gif'},
#  {'s1_NLM': np.float64(0.7983226904486689),
#   'p1_NLM': np.float64(30.79529067227952),
#   's2_GNLM': np.float64(0.8503276849460701),
#   'p2_GLM': np.float64(31.55182581492385),
#   's3_BM3D': np.float64(0.798328611782748),
#   'p3_GLM': np.float64(30.745160497734894),
#   'time_nlm': 2.216095209121704,
#   'time_geonlm': 57.22981405258179,
#   'time_bm3d': 1.5326926708221436,
#   'h_nlm': np.float64(10.389528791653134),
#   'h_geo': np.float64(11.863995904331123),
#   'sigma': np.float64(1.2423399766102936),
#   'image': '37.gif'},
#  {'s1_NLM': np.float64(0.9073957180014837),
#   'p1_NLM': np.float64(31.81347431072458),
#   's2_GNLM': np.float64(0.8735005766466015),
#   'p2_GLM': np.float64(31.790525315822382),
#   's3_BM3D': np.float64(0.9261573134288554),
#   'p3_GLM': np.float64(33.20977098034499),
#   'time_nlm': 2.205500602722168,
#   'time_geonlm': 55.92804312705994,
#   'time_bm3d': 1.210155963897705,
#   'h_nlm': np.float64(9.080475041247306),
#   'h_geo': np.float64(10.36471336404252),
#   'sigma': np.float64(1.1117690915034608),
#   'image': '38.gif'},
#  {'s1_NLM': np.float64(0.9061545946992193),
#   'p1_NLM': np.float64(33.373469869525174),
#   's2_GNLM': np.float64(0.8580352010049385),
#   'p2_GLM': np.float64(32.851184992679364),
#   's3_BM3D': np.float64(0.9286066921710924),
#   'p3_GLM': np.float64(35.17190261250769),
#   'time_nlm': 2.238218069076538,
#   'time_geonlm': 56.70869326591492,
#   'time_bm3d': 1.2591807842254639,
#   'h_nlm': np.float64(8.6639720587764),
#   'h_geo': np.float64(9.88835208114246),
#   'sigma': np.float64(1.0691387068779754),
#   'image': '39.gif'},
#  {'s1_NLM': np.float64(0.8699098099955997),
#   'p1_NLM': np.float64(31.635937658504297),
#   's2_GNLM': np.float64(0.8819757775780676),
#   'p2_GLM': np.float64(32.026879188589376),
#   's3_BM3D': np.float64(0.8929647905651844),
#   'p3_GLM': np.float64(32.795473210877866),
#   'time_nlm': 2.204793691635132,
#   'time_geonlm': 56.50620222091675,
#   'time_bm3d': 1.1548116207122803,
#   'h_nlm': np.float64(9.31197980676972),
#   'h_geo': np.float64(10.629619843164576),
#   'sigma': np.float64(1.1352290231962732),
#   'image': '4.gif'},
#  {'s1_NLM': np.float64(0.8259516823292058),
#   'p1_NLM': np.float64(31.62221576411474),
#   's2_GNLM': np.float64(0.8180042473673087),
#   'p2_GLM': np.float64(31.555030549437326),
#   's3_BM3D': np.float64(0.8696473793167031),
#   'p3_GLM': np.float64(33.254833589653444),
#   'time_nlm': 2.211310625076294,
#   'time_geonlm': 56.734503746032715,
#   'time_bm3d': 1.2391703128814697,
#   'h_nlm': np.float64(8.515233418135173),
#   'h_geo': np.float64(9.718306818246733),
#   'sigma': np.float64(1.053779209271445),
#   'image': '40.gif'},
#  {'s1_NLM': np.float64(0.8740996701205378),
#   'p1_NLM': np.float64(30.3920672744988),
#   's2_GNLM': np.float64(0.8772166716810866),
#   'p2_GLM': np.float64(30.656233175933657),
#   's3_BM3D': np.float64(0.9174891881323343),
#   'p3_GLM': np.float64(32.70750119033047),
#   'time_nlm': 2.1972906589508057,
#   'time_geonlm': 55.82400107383728,
#   'time_bm3d': 1.212146282196045,
#   'h_nlm': np.float64(8.805711394962469),
#   'h_geo': np.float64(10.050428832224872),
#   'sigma': np.float64(1.0837083536159822),
#   'image': '41.gif'},
#  {'s1_NLM': np.float64(0.8815936459902799),
#   'p1_NLM': np.float64(30.61190398909046),
#   's2_GNLM': np.float64(0.8857817196090508),
#   'p2_GLM': np.float64(30.982254819366204),
#   's3_BM3D': np.float64(0.9247674728516694),
#   'p3_GLM': np.float64(32.69459951332142),
#   'time_nlm': 2.1781606674194336,
#   'time_geonlm': 56.958075284957886,
#   'time_bm3d': 1.1258549690246582,
#   'h_nlm': np.float64(9.316322377290975),
#   'h_geo': np.float64(10.634589891952336),
#   'sigma': np.float64(1.1356675150299733),
#   'image': '42.gif'},
#  {'s1_NLM': np.float64(0.916356165597),
#   'p1_NLM': np.float64(30.277528072232286),
#   's2_GNLM': np.float64(0.9213654290426535),
#   'p2_GLM': np.float64(30.62556405655837),
#   's3_BM3D': np.float64(0.9457040853270376),
#   'p3_GLM': np.float64(32.3145059369114),
#   'time_nlm': 2.2027456760406494,
#   'time_geonlm': 56.66829705238342,
#   'time_bm3d': 1.4370381832122803,
#   'h_nlm': np.float64(9.090351564694416),
#   'h_geo': np.float64(10.3760129235199),
#   'sigma': np.float64(1.1127733279400125),
#   'image': '43.gif'},
#  {'s1_NLM': np.float64(0.6077834632399911),
#   'p1_NLM': np.float64(22.53643909427208),
#   's2_GNLM': np.float64(0.7777410325906176),
#   'p2_GLM': np.float64(24.416569115204467),
#   's3_BM3D': np.float64(0.6556453196631756),
#   'p3_GLM': np.float64(22.74933640930655),
#   'time_nlm': 2.2333626747131348,
#   'time_geonlm': 57.79617786407471,
#   'time_bm3d': 1.3903892040252686,
#   'h_nlm': np.float64(19.423122504932003),
#   'h_geo': np.float64(22.3398148852816),
#   'sigma': np.float64(2.0416363586638036),
#   'image': '44.gif'},
#  {'s1_NLM': np.float64(0.8956571010756225),
#   'p1_NLM': np.float64(30.39557327695727),
#   's2_GNLM': np.float64(0.8712672006075316),
#   'p2_GLM': np.float64(30.42207795375812),
#   's3_BM3D': np.float64(0.9305603839564521),
#   'p3_GLM': np.float64(32.26085269821554),
#   'time_nlm': 2.1864640712738037,
#   'time_geonlm': 56.23528027534485,
#   'time_bm3d': 1.3379569053649902,
#   'h_nlm': np.float64(9.323193585225217),
#   'h_geo': np.float64(10.64245402360237),
#   'sigma': np.float64(1.1363612193618047),
#   'image': '45.gif'},
#  {'s1_NLM': np.float64(0.8780833249795695),
#   'p1_NLM': np.float64(29.167926898675113),
#   's2_GNLM': np.float64(0.9087885842435109),
#   'p2_GLM': np.float64(29.809062309633084),
#   's3_BM3D': np.float64(0.8965776815644196),
#   'p3_GLM': np.float64(29.793270031119455),
#   'time_nlm': 2.2553579807281494,
#   'time_geonlm': 55.85527682304382,
#   'time_bm3d': 2.3219101428985596,
#   'h_nlm': np.float64(10.690362613724995),
#   'h_geo': np.float64(12.209045981107604),
#   'sigma': np.float64(1.271663698231598),
#   'image': '46.gif'},
#  {'s1_NLM': np.float64(0.8160829551844622),
#   'p1_NLM': np.float64(28.51034334281636),
#   's2_GNLM': np.float64(0.8786637696488708),
#   'p2_GLM': np.float64(29.498435669993597),
#   's3_BM3D': np.float64(0.84831432345191),
#   'p3_GLM': np.float64(28.823928138331354),
#   'time_nlm': 2.2529969215393066,
#   'time_geonlm': 57.486485958099365,
#   'time_bm3d': 1.2986834049224854,
#   'h_nlm': np.float64(11.722310172207477),
#   'h_geo': np.float64(13.394261300920606),
#   'sigma': np.float64(1.3704788315367022),
#   'image': '47.gif'},
#  {'s1_NLM': np.float64(0.8894432016337078),
#   'p1_NLM': np.float64(30.73627098011782),
#   's2_GNLM': np.float64(0.8500475437495474),
#   'p2_GLM': np.float64(30.722654766240115),
#   's3_BM3D': np.float64(0.9281415233786088),
#   'p3_GLM': np.float64(33.05724091996406),
#   'time_nlm': 2.201923131942749,
#   'time_geonlm': 57.08111906051636,
#   'time_bm3d': 1.0327479839324951,
#   'h_nlm': np.float64(8.712295165793767),
#   'h_geo': np.float64(9.943605095237356),
#   'sigma': np.float64(1.0741132297120448),
#   'image': '48.gif'},
#  {'s1_NLM': np.float64(0.9150163083669292),
#   'p1_NLM': np.float64(29.387511369626655),
#   's2_GNLM': np.float64(0.9209612550739514),
#   'p2_GLM': np.float64(29.669762123556232),
#   's3_BM3D': np.float64(0.9544397282486933),
#   'p3_GLM': np.float64(30.079160965786652),
#   'time_nlm': 2.1896533966064453,
#   'time_geonlm': 56.824362993240356,
#   'time_bm3d': 1.2417445182800293,
#   'h_nlm': np.float64(12.194521866371229),
#   'h_geo': np.float64(13.937487127609183),
#   'sigma': np.float64(1.414832607484401),
#   'image': '49.gif'},
#  {'s1_NLM': np.float64(0.8866958771722061),
#   'p1_NLM': np.float64(30.435403027675317),
#   's2_GNLM': np.float64(0.89916156210945),
#   'p2_GLM': np.float64(30.954111527610742),
#   's3_BM3D': np.float64(0.9270981927835433),
#   'p3_GLM': np.float64(32.6512393499386),
#   'time_nlm': 2.1711456775665283,
#   'time_geonlm': 54.94659924507141,
#   'time_bm3d': 1.4055402278900146,
#   'h_nlm': np.float64(8.745129401120293),
#   'h_geo': np.float64(9.981150198058694),
#   'sigma': np.float64(1.0774889628936952),
#   'image': '5.gif'},
#  {'s1_NLM': np.float64(0.9305100566174951),
#   'p1_NLM': np.float64(32.278927072539226),
#   's2_GNLM': np.float64(0.9232174005941146),
#   'p2_GLM': np.float64(32.45383283696649),
#   's3_BM3D': np.float64(0.9418623576493729),
#   'p3_GLM': np.float64(33.06807969010001),
#   'time_nlm': 2.2481017112731934,
#   'time_geonlm': 58.366803884506226,
#   'time_bm3d': 1.4868319034576416,
#   'h_nlm': np.float64(10.473789790603192),
#   'h_geo': np.float64(11.960621418986248),
#   'sigma': np.float64(1.2505778260132632),
#   'image': '6.gif'},
#  {'s1_NLM': np.float64(0.9025758366627554),
#   'p1_NLM': np.float64(28.515068407598317),
#   's2_GNLM': np.float64(0.9141180217574648),
#   'p2_GLM': np.float64(29.05523759504437),
#   's3_BM3D': np.float64(0.9330739510773667),
#   'p3_GLM': np.float64(30.448789452700137),
#   'time_nlm': 2.3561718463897705,
#   'time_geonlm': 58.252052545547485,
#   'time_bm3d': 1.7710840702056885,
#   'h_nlm': np.float64(10.220841575672909),
#   'h_geo': np.float64(11.670601407250476),
#   'sigma': np.float64(1.2257898702823924),
#   'image': '7.gif'},
#  {'s1_NLM': np.float64(0.9147781607336153),
#   'p1_NLM': np.float64(31.79369246989607),
#   's2_GNLM': np.float64(0.9212221077139319),
#   'p2_GLM': np.float64(32.19392678658443),
#   's3_BM3D': np.float64(0.9274734641704689),
#   'p3_GLM': np.float64(32.95586741337813),
#   'time_nlm': 2.260744333267212,
#   'time_geonlm': 56.0429310798645,
#   'time_bm3d': 1.785311222076416,
#   'h_nlm': np.float64(9.286615743580642),
#   'h_geo': np.float64(10.600591499440027),
#   'sigma': np.float64(1.1326667356674263),
#   'image': '8.gif'},
#  {'s1_NLM': np.float64(0.9145007253210198),
#   'p1_NLM': np.float64(30.118193443340743),
#   's2_GNLM': np.float64(0.9091259263302963),
#   'p2_GLM': np.float64(30.51995311157654),
#   's3_BM3D': np.float64(0.9276195037931136),
#   'p3_GLM': np.float64(31.041734987989752),
#   'time_nlm': 2.1782453060150146,
#   'time_geonlm': 52.76233124732971,
#   'time_bm3d': 1.3072099685668945,
#   'h_nlm': np.float64(9.702277466520044),
#   'h_geo': np.float64(11.076454919834138),
#   'sigma': np.float64(1.1744134205071395),
#   'image': '9.gif'}]

# %%
import pandas as pd
import numpy as np

def salvar_resultados_em_xlsx(lista_dicionarios, caminho_arquivo='resultados.xlsx'):
    # Converte os dicionários para DataFrame
    df = pd.DataFrame(lista_dicionarios)
    
    # Converte todos os np.float64 para float padrão do Python
    df = df.applymap(lambda x: float(x) if isinstance(x, np.float64) else x)
    
    # Salva como arquivo Excel
    df.to_excel(caminho_arquivo, index=False)
    print(f'Arquivo salvo em: {caminho_arquivo}')

# %%
# Suponha que você tenha a lista chamada `resultados`
salvar_resultados_em_xlsx(array_dicts, 'saidaPoissonGaussianAnscombe.xlsx')
# Out:
# Arquivo salvo em: saidaPoissonGaussianAnscombe.xlsx
