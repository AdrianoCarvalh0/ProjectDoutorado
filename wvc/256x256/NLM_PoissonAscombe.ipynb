# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Dec 15 11:26:44 2019

Implementação do filtro Non-Local Means geodésico

"""
import sys
import warnings
import time
import skimage
import statistics
import networkx as nx
import matplotlib.pyplot as plt
import skimage.io
import skimage.measure
import numpy as np
import sklearn.neighbors as sknn
from scipy.sparse.csgraph import dijkstra
from numpy.matlib import repmat
from scipy.linalg import eigh
from numpy.linalg import inv
from numpy.linalg import cond
from numpy import eye
from sklearn.decomposition import PCA
from skimage.metrics import peak_signal_noise_ratio
from skimage.metrics import structural_similarity
from skimage.transform import rescale, resize, downscale_local_mean
from numba import njit   # just in time compiler (acelera loops)
from joblib import Parallel, delayed
from bm3d import bm3d, BM3DProfile

# Para evitar warning de divisão por zero
warnings.simplefilter(action='ignore')

'''
Espelhamento das bordas da imagem A de maneira simétrica
A função pad do numpy não é supertada pelo numba!
Substitui a função: img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')
f é o parâmetro (largura das bordas)
'''
@njit
def mirror(A, f):
    n = A.shape[0]
    m = A.shape[1]
    nlin = A.shape[0] + 2*f
    ncol = A.shape[1] + 2*f
    # Matriz de saída
    B = np.zeros((nlin, ncol))
    # Preeenche miolo
    B[f:nlin-f, f:ncol-f] = A
    # Preenche cantos
    B[0:f, 0:f] = np.flip(A[0:f, 0:f])                          # 1o quadrante
    B[0:f, ncol-f:ncol] = np.flip(A[0:f, m-f:m])                # 2o quadrante
    B[nlin-f:nlin, 0:f] = np.flip(A[n-f:n, 0:f])                # 3o quadrante
    B[nlin-f:nlin, ncol-f:ncol] = np.flip(A[n-f:n, m-f:m])      # 4o quadrante
    # Preenche bordas
    B[0:f, f:ncol-f] = np.flipud(A[0:f, :])             # cima
    B[nlin-f:nlin, f:ncol-f] = np.flipud(A[n-f:n, :])   # baixo
    B[f:nlin-f, 0:f] = np.fliplr(A[:, 0:f])             # esquerda
    B[f:nlin-f, ncol-f:ncol] = np.fliplr(A[:, m-f:m])   # direita
    return B

'''
Non-Local Means padrão (versão rápida)

Parâmetros:

    img: imagem ruidosa de entrada
    h: parâmetro que controla o grau de suavização (quanto maior, mais suaviza)
    f: tamanho do patch (2f + 1 x 2f + 1) -> se f = 3, então patch é 7 x 7
    t: tamanho da janela de busca (2t + 1 x 2t + 1) -> se t = 10, então janela de busca é 21 x 21

'''
@njit
def NLM_fast(img, h, f, t):
    # Dimenssões espaciais da imagem
    m, n = img.shape
    # Cria imagem de saída
    filtrada = np.zeros((m, n))
    # Problema de valor de contorno: replicar bordas
    img_n = mirror(img, f)
    # Loop principal do NLM
    for i in range(m):
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente
            # Obtém o patch ao redor do pixel corrente
            W1 = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1]
            # Calcula as bordas da janela de busca para o pixel corrente (se pixel próximo das bordas, janela de busca é menor)
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            # Calcula média ponderada
            NL = 0      # valor do pixel corrente filtrado
            Z = 0       # constante normalizadora
            # Loop para todos os pixels da janela de busca
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    W2 = img_n[r-f:(r+f)+1, s-f:(s+f)+1]
                    # Calcula o quadrado da distância Euclidiana
                    d2 = np.sum((W1 - W2)*(W1 - W2))
                    # Calcula a medida de similaridade
                    sij = np.exp(-d2/(h**2))               
                    # Atualiza Z e NL
                    Z = Z + sij
                    NL = NL + sij*img_n[r, s]
            # Normalização do pixel filtrado
            filtrada[i, j] = NL/Z
    return filtrada


'''
Non-Local Means geodésico (versão básica, sem paralelismo e mais lenta)

Parâmetros:

    img: imagem ruidosa de entrada
    h: parâmetro que controla o grau de suavização (quanto maior, mais suaviza)
    f: tamanho do patch (2f + 1 x 2f + 1) -> se f = 3, então patch é 7 x 7
    t: tamanho da janela de busca (2t + 1 x 2t + 1) -> se t = 10, então janela de busca é 21 x 21
    nn: número de vizinhos no grafo KNN

''' 
def GeoNLM(img_noise, h, f, t, nn=10):
    # Dimenssões espaciais da imagem
    m, n = img_noise.shape
    # Cria imagem de saída
    filtrada = np.zeros((m, n))
    # Problema de valor de contorno: replicar bordas
    img_n = np.pad(img_noise, ((f, f), (f, f)), 'symmetric')
    # Loop principal do NLM geodésico
    for i in range(m):
        if i % 10 == 0:
            print(i, end=' ')
            sys.stdout.flush()
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente
            # Obtém o patch ao redor do pixel corrente
            patch_central = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1]
            central = np.reshape(patch_central, [1, patch_central.shape[0]*patch_central.shape[1]])[-1]
            # Calcula as bordas da janela de busca para o pixel corrente
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            # Calcula média ponderada
            NL = 0      # valor do pixel corrente filtrado
            Z = 0       # constante normalizadora
            # Cria dataset com patches da janela de busca como vetores
            num_elem = (rmax - rmin)*(smax - smin)
            tamanho_patch = (2*f + 1)*(2*f + 1)
            dataset = np.zeros((num_elem, tamanho_patch))
            k = 0
            pixels_busca = []
            # Loop para montar o dataset com todos os patches da janela
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    W = img_n[r-f:(r+f)+1, s-f:(s+f)+1] 
                    neighbor = np.reshape(W, [1, W.shape[0]*W.shape[1]])[-1]                    
                    dataset[k, :] = neighbor.copy()
                    if central[0] == neighbor[0]:
                        if (central == neighbor).all():
                            source = k
                    pixels_busca.append(img_n[r, s])
                    k = k + 1
            # Cria grafo knn com patches da janela de busca
            knnGraph = sknn.kneighbors_graph(dataset, n_neighbors=nn, mode='distance')
            A = knnGraph.toarray()
            # Converte matriz de adjacências para grafo
            G = nx.from_numpy_array(A)                      
            # Aplica algoritmo de Dijkstra
            length, path = nx.single_source_dijkstra(G, source)
            points = np.array(list(length.keys()))
            distancias = np.array(list(length.values()))
            # Calcula similaridades
            similaridades = np.exp(-distancias**2/(h**2))
            pixels = np.zeros(len(points))
            pixels_busca = np.array(pixels_busca)
            pixels = pixels_busca[points]
            # Normalização do pixel filtrado
            NL = sum(similaridades*pixels)
            Z = sum(similaridades)
            filtrada[i, j] = NL/Z
    return filtrada


######################################################
# Função auxiliar para paralelizar o GEONLM
######################################################
def process_pixel(i, j, img_n, f, t, h, nn):
    im = i + f
    jn = j + f
    patch_central = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1]
    central = np.reshape(patch_central, [1, patch_central.shape[0]*patch_central.shape[1]])[-1]
    rmin = max(im-t, f)
    rmax = min(im+t, m+f)
    smin = max(jn-t, f)
    smax = min(jn+t, n+f)
    NL, Z = 0, 0
    dataset = np.zeros(((rmax - rmin)*(smax - smin), (2*f + 1)*(2*f + 1)))
    k = 0
    pixels_busca = []
    for r in range(rmin, rmax):
        for s in range(smin, smax):
            W = img_n[r-f:(r+f)+1, s-f:(s+f)+1]
            neighbor = np.reshape(W, [1, W.shape[0]*W.shape[1]])[-1]
            dataset[k, :] = neighbor.copy()
            if central[0] == neighbor[0] and (central == neighbor).all():
                source = k
            pixels_busca.append(img_n[r, s])
            k += 1
    knnGraph = sknn.kneighbors_graph(dataset, n_neighbors=nn, mode='distance')
    A = knnGraph.toarray()
    G = nx.from_numpy_array(A)
    length, path = nx.single_source_dijkstra(G, source)
    points = np.array(list(length.keys()))
    distancias = np.array(list(length.values()))
    similaridades = np.exp(-distancias**2 / (h**2))
    pixels_busca = np.array(pixels_busca)
    pixels = pixels_busca[points]
    NL = sum(similaridades * pixels)
    Z = sum(similaridades)
    return NL / Z

##################################################
# GEONLM paralelo 
##################################################
def Parallel_GEONLM(img_n, f, t, h, nn):
    # Parallelize the loop
    print(f'img_n.shape: {img_n.shape}')
    m = img_n.shape[0] - 2*f
    print(f'M: {m}')
    n = img_n.shape[1] - 2*f
    print(f'N: {n}')
    filtrada = Parallel(n_jobs=-1)(delayed(process_pixel)(i, j, img_n, f, t, h, nn) for i in range(m) for j in range(n))
    #print(f"filtrada Shape: {filtrada.shape}")
    
    filtrada_geo = np.array(filtrada).reshape((m, n))
    #print(f'filtrada_geo.shape: {filtrada_geo.shape}')
    return filtrada_geo

####################################################################
'''
Função que extrai os patches de cada janela de busca no GeoNLM
Retorna uma matriz 4D (m, n, 2t+1 x 2t+1, 2f+1 x 2f+1)

Usa o JIT (just in time) compiler para acelerar loops

'''
####################################################################
@njit
def Extract_patches(img, f, t):
    # Dimenssões espaciais da imagem
    m, n = img.shape
    # Tamanhos do patch e da janela de busca
    tamanho_patch = (2*f + 1)*(2*f + 1)    
    # Patches para cada janela de busca
    patches = []
    centros = []    
    # Problema de valor de contorno: replicar bordas
    img_n = mirror(img, f)
    # Loop principal do NLM geodésico
    for i in range(m):        
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente
            # Obtém o patch ao redor do pixel corrente
            patch_central = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1].copy()
            central = patch_central.reshape((1, patch_central.shape[0]*patch_central.shape[1]))[-1]
            # Calcula as bordas da janela de busca para o pixel corrente
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            num_elem = (rmax - rmin)*(smax - smin)
            # Cria dataset
            dataset = np.zeros((num_elem, tamanho_patch))
            # Loop para montar o dataset com todos os patches da janela
            k = 0
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    W = img_n[r-f:(r+f)+1, s-f:(s+f)+1].copy() 
                    neighbor = W.reshape((1, W.shape[0]*W.shape[1]))[-1]
                    dataset[k, :] = neighbor.copy()
                    if (central == neighbor).all():
                        source = k
                    k = k + 1
            patches.append(dataset)
            centros.append(source)
    return patches, centros

###################################################################
'''
Função que extrai os patches de cada janela de busca no GeoNLM
Retorna uma lista 
'''
###################################################################
def Geodesic_distances(patches, centros, nn=10):
    distancias_geodesicas = []
    pontos = []
    # Percorre a lista de patches
    for i in range(len(patches)):
    # Cria grafo knn com patches da janela de busca
        knnGraph = sknn.kneighbors_graph(patches[i], n_neighbors=nn, mode='distance')
        A = knnGraph.toarray()        
        G = nx.from_numpy_array(A)      # Converte matriz de adjacências para grafo
        # Aplica algoritmo de Dijkstra
        length, path = nx.single_source_dijkstra(G, centros[i])
        points = np.array(list(length.keys()))
        pontos.append(points)
        geodists = np.array(list(length.values()))        
        distancias_geodesicas.append(geodists)
    return distancias_geodesicas, pontos

##################################################################################################
'''
Non-Local Means geodésico (versão com compilador JIT para acelerar loops)

Parâmetros:

    img: imagem ruidosa de entrada
    h: parâmetro que controla o grau de suavização (quanto maior, mais suaviza)
    f: tamanho do patch (2f + 1 x 2f + 1) -> se f = 3, então patch é 7 x 7
    t: tamanho da janela de busca (2t + 1 x 2t + 1) -> se t = 10, então janela de busca é 21 x 21
    nn: número de vizinhos no grafo KNN

''' 
###################################################################################################
@njit
def GeoNLM_fast(img, h, f, t, distancias_geodesicas, pontos):
    # Dimenssões espaciais da imagem
    m, n = img.shape
    # Cria imagem de saída
    filtrada = np.zeros((m, n))
    # Problema de valor de contorno: replicar bordas
    #img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')
    img_n = mirror(img, f)
    # Loop principal do NLM geodésico
    k = 0
    for i in range(m):
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente    
            # Calcula as bordas da janela de busca para o pixel corrente
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            # Calcula média ponderada
            NL = 0      # valor do pixel corrente filtrado
            Z = 0       # constante normalizadora            
            pixels_busca = []
            # Loop para montar o dataset com todos os patches da janela
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    pixels_busca.append(img_n[r, s])
            # Calcula similaridades
            similaridades = np.exp(-distancias_geodesicas[k]**2/(h**2))
            pixels = np.zeros(len(pontos[k]))
            pixels_busca = np.array(pixels_busca)
            pixels = pixels_busca[pontos[k]]
            # Normalização do pixel filtrado
            NL = sum(similaridades*pixels)
            Z = sum(similaridades)
            filtrada[i, j] = NL/Z
            k = k + 1
    return filtrada

#########################################################################
'''
Realiza a filtragem da imagem com o filtro NLM geodésico 

Usa o compilador JIT para acelerar loops
'''
#########################################################################
def GeoNLM_filter(img_noise, h, f, t, nn=10):
    # Fase 1
    print('Início da extração dos patches')
    inicio = time.time()
    patches, centros = Extract_patches(img_noise, f, t)
    fim = time.time()
    print('Elapsed time: %f ' %(fim - inicio))
    print()
    # Fase 2
    print('Início do cálculo das distâncias')
    inicio = time.time()
    distancias_geodesicas, pontos = Geodesic_distances(patches, centros, nn)
    fim = time.time()
    print('Elapsed time: %f ' %(fim - inicio))
    print()
    # Fase 3
    print('Início da filtragem')
    inicio = time.time()
    filtrada = GeoNLM_fast(img_noise, h, f, t, distancias_geodesicas, pontos)
    fim = time.time()
    print('Elapsed time: %f ' %(fim - inicio))
    return filtrada

# %%
import os
import math

def read_directories(directory, img=None, exclude_json=None):
    # Get a list of filenames in the specified directory
    filenames = []
    for filename in os.listdir(directory):
        if img is not None:
            # If 'img' is provided, filter filenames containing it
            if img in filename:   
                filenames.append(filename)
        elif exclude_json is not None:
            filenames.append(filename.replace('.json',''))     
        else:
            filenames.append(filename)    
    return filenames


def add_poisson_noise(img):
    """
    Aplica ruído de Poisson corretamente sem overflow.

    Parâmetros:
        img (np.ndarray): Imagem com valores em [0,255] ou [0,1].

    Retorna:
        np.ndarray: imagem ruidosa, clipada para [0, 255], dtype uint8.
    """
    # Se estiver em [0, 1], escala para 0-255
    if img.max() <= 1.0:
        img = (img * 255).astype(np.float32)
    else:
        img = img.astype(np.float32)

    # Garante que os valores Poisson não causem overflow
    poisson_img = np.random.poisson(img).astype(np.float32)
    poisson_img = np.clip(poisson_img, 0, 255)

    return poisson_img.astype(np.uint8)

def anscombe_transform(img):
    return 2.0 * np.sqrt(img.astype(np.float32) + 3.0 / 8.0)

def inverse_anscombe(transf_img):
    return np.clip((transf_img / 2.0) ** 2 - 3.0 / 8.0, 0, 255)

def compute_adaptive_q(sigma_est):
    q_nlm = 0.8 + 0.5 * math.tanh(0.3 * (sigma_est - 1))
    q_geo = 1.0 + 0.7 * math.tanh(0.25 * (sigma_est - 1.5))

    q_nlm = np.clip(q_nlm, 0.7, 2.2) * 10
    q_geo = np.clip(q_geo, 0.9, 2.7) * 10

    return q_nlm, q_geo

# %%
from pathlib import Path
from skimage.restoration import estimate_sigma

sys.path.insert(0, r"c:\Users\adria\Documents\Doutorado\ProjetoDoutorado")
root_dir = Path(r"c:\Users\adria\Documents\Doutorado\ProjetoDoutorado")



dir_images = f'{root_dir}/wvc/images'
dir_out_nlm = f'{root_dir}/wvc/256x256/Anscombe/out_put_NLM_Poisson'
dir_out_geonlm = f'{root_dir}/wvc/256x256/Anscombe/out_put_GEONLM_Poisson'
dir_out_bm3d = f'{root_dir}/wvc/256x256/Anscombe/out_put_GEONLM_Bm3d'

array_dir = read_directories(dir_images)

array_dicts = []

for file in array_dir:

    file_name = file
    img = skimage.io.imread(f'{dir_images}/{file_name}')
    # Em arquivos de formato GIF precisa desse comando
    img = img[0, :, :]

    # Checa se imagem é monocromática
    if len(img.shape) > 2:
        img = skimage.color.rgb2gray(img)   # valores convertidos ficam entre 0 e 1
        img = 255*img

    # Reescala imagem para (256, 256) - diminuir o tempo de execução
    img = downscale_local_mean(img, (2, 2))

    img = img.astype(np.uint8)              # Converte para uint8    
    m, n = img.shape

    print('Num. linhas = %d' %m)
    print('Num. colunas = %d' %n)
    print()

    # Cria imagem ruidosa
    ruidosa = add_poisson_noise(img)

    # Clipa imagem para intervalo [0, 255]
    ruidosa[np.where(ruidosa > 255)] = 255
    ruidosa[np.where(ruidosa < 0)] = 0
    #ruidosa = ruidosa.astype(np.float32)

    # Listas para métricas


    # Define parâmetros do filtro NLM
    f = 4   # tamanho do patch (2f + 1 x 2f + 1) -> 5 x 5
    t = 7   # tamanho da janela de busca (2t + 1 x 2t + 1) -> 21 x 21
    h_nlm = 16 # parâmetro que controla a suavização no NLM (depende da imagem)
    h_geo = 21 # parâmetro que controla a suavização no GEONLM (depende da imagem)
    nn = 10     # número de vizinhos no grafo k-NN

    # Cria imagem de saída
    filtrada = np.zeros((m, n))

    # Problema de valor de contorno: replicar bordas
    img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')

 
    inicio = time.time()
    #ruidosa_asc = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')      # para versão paralela, precisa espelhar imagem fora da função


    ruidosa_anscombe = anscombe_transform(ruidosa)
    #print(f'ruidosa_asc_nlm.shape: {ruidosa_anscombe.shape}')
    sigma_est = estimate_sigma(ruidosa_anscombe)
    q_nlm, q_geo = compute_adaptive_q(sigma_est)
    h_nlm = q_nlm * sigma_est #* 10
    h_geo = q_geo * sigma_est #* 10

    print('***********************************')
    print('*         Parâmetro H             *')
    print('***********************************')
    print(f"[INFO] σ estimado: {sigma_est:.2f} | q_nlm = {q_nlm:.2f} | h_nlm = {h_nlm:.2f}")
    print(f"[INFO]                 q_geo = {q_geo:.2f} | h_geo = {h_geo:.2f}")
    

    ###################################################
    # Filtra com NLM padrão
    ###################################################
    print('***********************************')
    print('*            NLM                  *')
    print('***********************************')
    print()
    filtrada_asc = NLM_fast(ruidosa_anscombe, h_nlm, f, t)
    print(f'filtrada_asc.shape: {filtrada_asc.shape}')
    filtrada_padrao = inverse_anscombe(filtrada_asc).astype(np.uint8)
    print(f'filtrada_padrao.shape: {filtrada_padrao.shape}')

    fim = time.time()    
    # Calcula PSNR
    p1_nlm = peak_signal_noise_ratio(img, filtrada_padrao.astype(np.uint8))
   
    print('PSNR (NLM padrão): %f' %p1_nlm)
    # Calcula SSIM
    s1_nlm = structural_similarity(img, filtrada_padrao.astype(np.uint8))
  
    print('SSIM (NLM padrão): %f' %s1_nlm)
    print('Elapsed time (NLM): %f s' %(fim - inicio))
    print()
    time_nlm = fim - inicio
    # Salva arquivo
    skimage.io.imsave(f'{dir_out_nlm}/{file_name}', filtrada_padrao.astype(np.uint8))

    ###################################################
    # Filtra com NLM geodésico
    ###################################################
    print('***********************************')
    print('*            GEONLM               *')
    print('***********************************')
    print()
    ini = time.time()

    ##3 Versão com JIT compiler
    #filtrada_geo = GeoNLM_filter(ruidosa, h_geo, f, t, nn)   # versão com JIT compiler (não ficou mais rápido pois o Dijkstra não acelera. Ainda está lento...)

    ### Versão com paralelismo (ficou mais rápida)
    img_n_geo = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')      # para versão paralela, precisa espelhar imagem fora da função

    ruidosa_asc_geo = anscombe_transform(img_n_geo)
    filtrada_geo_asc = Parallel_GEONLM(ruidosa_asc_geo, f, t, h_geo, nn)

    filtrada_geo = inverse_anscombe(filtrada_geo_asc).astype(np.uint8)

    end = time.time()
    # Calcula PSNR
    p2_gnlm = peak_signal_noise_ratio(img, filtrada_geo.astype(np.uint8))    
    print('\nPSNR (GEO NLM): %f' %p2_gnlm)
    # Calcula SSIM
    s2_gnlm = structural_similarity(img, filtrada_geo.astype(np.uint8))
   
    print('SSIM (GEO NLM): %f' %s2_gnlm)
    print('Total Elapsed time (GEONLM): %f s' %(end - ini))

    time_geonlm = end - ini
    print()
    # Salva arquivo    
    skimage.io.imsave(f'{dir_out_geonlm}/{file_name}', filtrada_geo.astype(np.uint8))
    
    print('***********************************')
    print('*            BM3D                 *')
    print('***********************************')
    print()


    ini = time.time()

    # 1. Normaliza a imagem ruidosa para intervalo [0, 1]
    #ruidosa_normalizada = ruidosa.astype(np.float32) / 255.0

    #ruidosa_asc_bm3d = anscombe_transform(ruidosa_normalizada)

    #sigma_est = estimate_sigma(ruidosa_asc_bm3d, channel_axis=None)

    # 3. Define o perfil padrão do BM3D
    perfil_bm3d = BM3DProfile()

    # 4. Aplica o BM3D com os argumentos definidos
    denoised = bm3d(
        ruidosa_anscombe,
        sigma_psd=sigma_est,
        profile=perfil_bm3d
    )
    denoised_sq = np.squeeze(denoised)

    filtrada_bm3d = inverse_anscombe(denoised_sq).astype(np.uint8)

    end = time.time()

    time_bm3d = end - ini

    skimage.io.imsave(f'{dir_out_bm3d}/{file_name}', np.clip(filtrada_bm3d, 0, 255).astype(np.uint8))

    p3_bm3d = peak_signal_noise_ratio(img, filtrada_bm3d.astype(np.uint8))
    print('\nPSNR (BM3D): %f' %p3_bm3d)
    s3_bm3d = structural_similarity(img, filtrada_bm3d.astype(np.uint8))
    print('SSIM (BM3D): %f' %s3_bm3d)
    print('Total Elapsed time (BM3D): %f s' %(time_bm3d))

    dict = {
        's1_NLM': s1_nlm,
        'p1_NLM': p1_nlm,
        's2_GNLM': s2_gnlm,
        'p2_GLM': p2_gnlm,
        's3_BM3D': s3_bm3d,
        'p3_GLM': p3_bm3d,
        'time_nlm':time_nlm,
        'time_geonlm':time_geonlm,
        'time_bm3d':time_bm3d,
        'h_nlm':h_nlm,
        'h_geo':h_geo,
        'sigma':sigma_est,
        'image': file_name   
    }
    array_dicts.append(dict)
# Out:
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.07 | q_nlm = 8.11 | h_nlm = 8.68
# [INFO]                 q_geo = 9.25 | h_geo = 9.91
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 32.468430
# SSIM (NLM padrão): 0.912635
# Elapsed time (NLM): 2.046770 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 32.057281
# SSIM (GEO NLM): 0.865143
# Total Elapsed time (GEONLM): 59.160723 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 34.876176
# SSIM (BM3D): 0.940898
# Total Elapsed time (BM3D): 1.473652 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.24 | q_nlm = 8.35 | h_nlm = 10.33
# [INFO]                 q_geo = 9.54 | h_geo = 11.79
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 31.531468
# SSIM (NLM padrão): 0.910767
# Elapsed time (NLM): 2.155344 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 32.241839
# SSIM (GEO NLM): 0.921019
# Total Elapsed time (GEONLM): 55.004840 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.237237
# SSIM (BM3D): 0.940034
# Total Elapsed time (BM3D): 1.314008 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.05 | q_nlm = 8.08 | h_nlm = 8.48
# [INFO]                 q_geo = 9.22 | h_geo = 9.68
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.526989
# SSIM (NLM padrão): 0.885289
# Elapsed time (NLM): 2.114245 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 29.948943
# SSIM (GEO NLM): 0.786626
# Total Elapsed time (GEONLM): 54.833910 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.034289
# SSIM (BM3D): 0.927207
# Total Elapsed time (BM3D): 1.095138 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.11 | q_nlm = 8.16 | h_nlm = 9.04
# [INFO]                 q_geo = 9.32 | h_geo = 10.32
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 28.653857
# SSIM (NLM padrão): 0.914238
# Elapsed time (NLM): 2.165711 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 29.094446
# SSIM (GEO NLM): 0.917761
# Total Elapsed time (GEONLM): 53.857879 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.459318
# SSIM (BM3D): 0.956531
# Total Elapsed time (BM3D): 1.041622 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.24 | q_nlm = 8.36 | h_nlm = 10.35
# [INFO]                 q_geo = 9.54 | h_geo = 11.81
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 31.834578
# SSIM (NLM padrão): 0.915442
# Elapsed time (NLM): 2.126799 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 32.206482
# SSIM (GEO NLM): 0.922659
# Total Elapsed time (GEONLM): 54.484247 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.996406
# SSIM (BM3D): 0.929761
# Total Elapsed time (BM3D): 1.469520 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.10 | q_nlm = 8.15 | h_nlm = 8.99
# [INFO]                 q_geo = 9.31 | h_geo = 10.26
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.015140
# SSIM (NLM padrão): 0.886681
# Elapsed time (NLM): 2.148919 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.001514
# SSIM (GEO NLM): 0.843737
# Total Elapsed time (GEONLM): 61.422653 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.995687
# SSIM (BM3D): 0.920315
# Total Elapsed time (BM3D): 1.422612 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.68 | q_nlm = 9.00 | h_nlm = 15.10
# [INFO]                 q_geo = 10.31 | h_geo = 17.29
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 28.155580
# SSIM (NLM padrão): 0.828311
# Elapsed time (NLM): 2.312169 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 29.337848
# SSIM (GEO NLM): 0.888076
# Total Elapsed time (GEONLM): 60.757027 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 27.481451
# SSIM (BM3D): 0.834235
# Total Elapsed time (BM3D): 1.372942 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.46 | q_nlm = 8.68 | h_nlm = 12.65
# [INFO]                 q_geo = 9.92 | h_geo = 14.46
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.606071
# SSIM (NLM padrão): 0.885739
# Elapsed time (NLM): 2.406153 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 31.148377
# SSIM (GEO NLM): 0.908164
# Total Elapsed time (GEONLM): 59.536226 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 30.187649
# SSIM (BM3D): 0.882154
# Total Elapsed time (BM3D): 1.343527 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.51 | q_nlm = 8.76 | h_nlm = 13.20
# [INFO]                 q_geo = 10.01 | h_geo = 15.10
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 29.923225
# SSIM (NLM padrão): 0.850439
# Elapsed time (NLM): 2.473928 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.810759
# SSIM (GEO NLM): 0.895878
# Total Elapsed time (GEONLM): 57.871283 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 29.860471
# SSIM (BM3D): 0.865067
# Total Elapsed time (BM3D): 1.593400 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.41 | q_nlm = 8.60 | h_nlm = 12.09
# [INFO]                 q_geo = 9.83 | h_geo = 13.82
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 29.947720
# SSIM (NLM padrão): 0.946113
# Elapsed time (NLM): 2.245891 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.198527
# SSIM (GEO NLM): 0.953423
# Total Elapsed time (GEONLM): 58.167681 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 30.094838
# SSIM (BM3D): 0.945898
# Total Elapsed time (BM3D): 1.410327 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.64 | q_nlm = 8.95 | h_nlm = 14.70
# [INFO]                 q_geo = 10.25 | h_geo = 16.84
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 29.916718
# SSIM (NLM padrão): 0.886170
# Elapsed time (NLM): 2.304041 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.554786
# SSIM (GEO NLM): 0.918816
# Total Elapsed time (GEONLM): 55.012639 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 29.239122
# SSIM (BM3D): 0.886268
# Total Elapsed time (BM3D): 1.447792 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.28 | q_nlm = 8.42 | h_nlm = 10.75
# [INFO]                 q_geo = 9.61 | h_geo = 12.28
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 32.129145
# SSIM (NLM padrão): 0.941524
# Elapsed time (NLM): 2.346553 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 32.494068
# SSIM (GEO NLM): 0.944190
# Total Elapsed time (GEONLM): 56.098840 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.312875
# SSIM (BM3D): 0.952030
# Total Elapsed time (BM3D): 1.085044 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.08 | q_nlm = 8.12 | h_nlm = 8.80
# [INFO]                 q_geo = 9.27 | h_geo = 10.04
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.957496
# SSIM (NLM padrão): 0.873111
# Elapsed time (NLM): 2.155111 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 31.195673
# SSIM (GEO NLM): 0.874652
# Total Elapsed time (GEONLM): 55.129814 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.889021
# SSIM (BM3D): 0.907198
# Total Elapsed time (BM3D): 1.377936 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.40 | q_nlm = 8.59 | h_nlm = 12.02
# [INFO]                 q_geo = 9.82 | h_geo = 13.73
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 31.296341
# SSIM (NLM padrão): 0.896644
# Elapsed time (NLM): 2.223115 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 31.747302
# SSIM (GEO NLM): 0.906846
# Total Elapsed time (GEONLM): 58.046628 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 30.938640
# SSIM (BM3D): 0.894143
# Total Elapsed time (BM3D): 1.380053 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.15 | q_nlm = 8.22 | h_nlm = 9.45
# [INFO]                 q_geo = 9.39 | h_geo = 10.79
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 32.662737
# SSIM (NLM padrão): 0.884680
# Elapsed time (NLM): 2.485168 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 32.751944
# SSIM (GEO NLM): 0.873136
# Total Elapsed time (GEONLM): 58.875758 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.422462
# SSIM (BM3D): 0.896736
# Total Elapsed time (BM3D): 1.443285 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.21 | q_nlm = 8.32 | h_nlm = 10.09
# [INFO]                 q_geo = 9.50 | h_geo = 11.52
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 31.526720
# SSIM (NLM padrão): 0.896463
# Elapsed time (NLM): 2.251629 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 31.522496
# SSIM (GEO NLM): 0.872185
# Total Elapsed time (GEONLM): 58.758876 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.469358
# SSIM (BM3D): 0.889513
# Total Elapsed time (BM3D): 1.581891 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.04 | q_nlm = 8.07 | h_nlm = 8.42
# [INFO]                 q_geo = 9.21 | h_geo = 9.62
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 33.615290
# SSIM (NLM padrão): 0.915760
# Elapsed time (NLM): 2.251121 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 33.459310
# SSIM (GEO NLM): 0.877685
# Total Elapsed time (GEONLM): 57.897624 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 36.269619
# SSIM (BM3D): 0.946589
# Total Elapsed time (BM3D): 1.422746 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.11 | q_nlm = 8.17 | h_nlm = 9.07
# [INFO]                 q_geo = 9.32 | h_geo = 10.36
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 33.136111
# SSIM (NLM padrão): 0.904441
# Elapsed time (NLM): 2.244750 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 32.915742
# SSIM (GEO NLM): 0.871099
# Total Elapsed time (GEONLM): 56.531341 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 34.368070
# SSIM (BM3D): 0.917762
# Total Elapsed time (BM3D): 1.641594 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.08 | q_nlm = 8.12 | h_nlm = 8.74
# [INFO]                 q_geo = 9.26 | h_geo = 9.98
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 35.505090
# SSIM (NLM padrão): 0.910072
# Elapsed time (NLM): 2.261633 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 34.750259
# SSIM (GEO NLM): 0.860723
# Total Elapsed time (GEONLM): 57.525262 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 37.622101
# SSIM (BM3D): 0.939121
# Total Elapsed time (BM3D): 1.246115 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.07 | q_nlm = 8.10 | h_nlm = 8.64
# [INFO]                 q_geo = 9.25 | h_geo = 9.87
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 31.982421
# SSIM (NLM padrão): 0.865114
# Elapsed time (NLM): 2.202874 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 32.202827
# SSIM (GEO NLM): 0.871381
# Total Elapsed time (GEONLM): 56.312601 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.743228
# SSIM (BM3D): 0.901255
# Total Elapsed time (BM3D): 1.159006 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.04 | q_nlm = 8.06 | h_nlm = 8.35
# [INFO]                 q_geo = 9.19 | h_geo = 9.53
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 33.827944
# SSIM (NLM padrão): 0.931590
# Elapsed time (NLM): 2.183106 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 33.499803
# SSIM (GEO NLM): 0.890819
# Total Elapsed time (GEONLM): 56.535862 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 36.129134
# SSIM (BM3D): 0.956900
# Total Elapsed time (BM3D): 1.218227 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.08 | q_nlm = 8.11 | h_nlm = 8.73
# [INFO]                 q_geo = 9.26 | h_geo = 9.96
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 33.360780
# SSIM (NLM padrão): 0.889752
# Elapsed time (NLM): 2.223966 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 33.131309
# SSIM (GEO NLM): 0.865100
# Total Elapsed time (GEONLM): 56.437795 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 35.493687
# SSIM (BM3D): 0.933009
# Total Elapsed time (BM3D): 1.196067 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.51 | q_nlm = 8.76 | h_nlm = 13.20
# [INFO]                 q_geo = 10.01 | h_geo = 15.09
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 29.592725
# SSIM (NLM padrão): 0.882604
# Elapsed time (NLM): 2.795075 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.543094
# SSIM (GEO NLM): 0.919285
# Total Elapsed time (GEONLM): 57.967092 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 29.685761
# SSIM (BM3D): 0.891817
# Total Elapsed time (BM3D): 1.129989 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.15 | q_nlm = 8.22 | h_nlm = 9.41
# [INFO]                 q_geo = 9.38 | h_geo = 10.74
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 33.259720
# SSIM (NLM padrão): 0.905746
# Elapsed time (NLM): 2.458165 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 33.571515
# SSIM (GEO NLM): 0.904380
# Total Elapsed time (GEONLM): 59.959807 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 34.616191
# SSIM (BM3D): 0.928527
# Total Elapsed time (BM3D): 1.874681 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.21 | q_nlm = 8.32 | h_nlm = 10.08
# [INFO]                 q_geo = 9.50 | h_geo = 11.50
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 31.244361
# SSIM (NLM padrão): 0.873757
# Elapsed time (NLM): 2.365238 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 31.661187
# SSIM (GEO NLM): 0.894390
# Total Elapsed time (GEONLM): 57.076130 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.762196
# SSIM (BM3D): 0.888003
# Total Elapsed time (BM3D): 1.275365 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.81 | q_nlm = 9.20 | h_nlm = 16.68
# [INFO]                 q_geo = 10.55 | h_geo = 19.13
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 29.348987
# SSIM (NLM padrão): 0.890046
# Elapsed time (NLM): 2.190013 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 29.863114
# SSIM (GEO NLM): 0.917831
# Total Elapsed time (GEONLM): 56.681751 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 27.816636
# SSIM (BM3D): 0.877202
# Total Elapsed time (BM3D): 1.323322 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.13 | q_nlm = 8.19 | h_nlm = 9.21
# [INFO]                 q_geo = 9.35 | h_geo = 10.52
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.330040
# SSIM (NLM padrão): 0.904658
# Elapsed time (NLM): 2.190853 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.526896
# SSIM (GEO NLM): 0.912649
# Total Elapsed time (GEONLM): 54.760450 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.562371
# SSIM (BM3D): 0.911779
# Total Elapsed time (BM3D): 1.264992 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.15 | q_nlm = 8.22 | h_nlm = 9.43
# [INFO]                 q_geo = 9.38 | h_geo = 10.76
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.803701
# SSIM (NLM padrão): 0.877022
# Elapsed time (NLM): 2.204763 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 31.236730
# SSIM (GEO NLM): 0.895929
# Total Elapsed time (GEONLM): 56.024991 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.876739
# SSIM (BM3D): 0.900798
# Total Elapsed time (BM3D): 1.564785 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.25 | q_nlm = 8.37 | h_nlm = 10.46
# [INFO]                 q_geo = 9.56 | h_geo = 11.94
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.289692
# SSIM (NLM padrão): 0.915047
# Elapsed time (NLM): 2.221401 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.852251
# SSIM (GEO NLM): 0.929742
# Total Elapsed time (GEONLM): 55.885108 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.159613
# SSIM (BM3D): 0.926172
# Total Elapsed time (BM3D): 1.267455 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.12 | q_nlm = 8.18 | h_nlm = 9.14
# [INFO]                 q_geo = 9.33 | h_geo = 10.44
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.818104
# SSIM (NLM padrão): 0.906940
# Elapsed time (NLM): 2.207019 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.990838
# SSIM (GEO NLM): 0.902744
# Total Elapsed time (GEONLM): 56.055499 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.076548
# SSIM (BM3D): 0.938654
# Total Elapsed time (BM3D): 1.323427 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.20 | q_nlm = 8.30 | h_nlm = 9.96
# [INFO]                 q_geo = 9.48 | h_geo = 11.37
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 31.678247
# SSIM (NLM padrão): 0.938965
# Elapsed time (NLM): 2.198954 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 32.124982
# SSIM (GEO NLM): 0.940646
# Total Elapsed time (GEONLM): 55.020916 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.775996
# SSIM (BM3D): 0.949125
# Total Elapsed time (BM3D): 1.096253 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.24 | q_nlm = 8.36 | h_nlm = 10.39
# [INFO]                 q_geo = 9.55 | h_geo = 11.86
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.795291
# SSIM (NLM padrão): 0.798323
# Elapsed time (NLM): 2.216095 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 31.551826
# SSIM (GEO NLM): 0.850328
# Total Elapsed time (GEONLM): 57.229814 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 30.745160
# SSIM (BM3D): 0.798329
# Total Elapsed time (BM3D): 1.532693 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.11 | q_nlm = 8.17 | h_nlm = 9.08
# [INFO]                 q_geo = 9.32 | h_geo = 10.36
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 31.813474
# SSIM (NLM padrão): 0.907396
# Elapsed time (NLM): 2.205501 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 31.790525
# SSIM (GEO NLM): 0.873501
# Total Elapsed time (GEONLM): 55.928043 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.209771
# SSIM (BM3D): 0.926157
# Total Elapsed time (BM3D): 1.210156 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.07 | q_nlm = 8.10 | h_nlm = 8.66
# [INFO]                 q_geo = 9.25 | h_geo = 9.89
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 33.373470
# SSIM (NLM padrão): 0.906155
# Elapsed time (NLM): 2.238218 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 32.851185
# SSIM (GEO NLM): 0.858035
# Total Elapsed time (GEONLM): 56.708693 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 35.171903
# SSIM (BM3D): 0.928607
# Total Elapsed time (BM3D): 1.259181 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.14 | q_nlm = 8.20 | h_nlm = 9.31
# [INFO]                 q_geo = 9.36 | h_geo = 10.63
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 31.635938
# SSIM (NLM padrão): 0.869910
# Elapsed time (NLM): 2.204794 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 32.026879
# SSIM (GEO NLM): 0.881976
# Total Elapsed time (GEONLM): 56.506202 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.795473
# SSIM (BM3D): 0.892965
# Total Elapsed time (BM3D): 1.154812 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.05 | q_nlm = 8.08 | h_nlm = 8.52
# [INFO]                 q_geo = 9.22 | h_geo = 9.72
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 31.622216
# SSIM (NLM padrão): 0.825952
# Elapsed time (NLM): 2.211311 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 31.555031
# SSIM (GEO NLM): 0.818004
# Total Elapsed time (GEONLM): 56.734504 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.254834
# SSIM (BM3D): 0.869647
# Total Elapsed time (BM3D): 1.239170 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.08 | q_nlm = 8.13 | h_nlm = 8.81
# [INFO]                 q_geo = 9.27 | h_geo = 10.05
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.392067
# SSIM (NLM padrão): 0.874100
# Elapsed time (NLM): 2.197291 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.656233
# SSIM (GEO NLM): 0.877217
# Total Elapsed time (GEONLM): 55.824001 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.707501
# SSIM (BM3D): 0.917489
# Total Elapsed time (BM3D): 1.212146 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.14 | q_nlm = 8.20 | h_nlm = 9.32
# [INFO]                 q_geo = 9.36 | h_geo = 10.63
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.611904
# SSIM (NLM padrão): 0.881594
# Elapsed time (NLM): 2.178161 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.982255
# SSIM (GEO NLM): 0.885782
# Total Elapsed time (GEONLM): 56.958075 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.694600
# SSIM (BM3D): 0.924767
# Total Elapsed time (BM3D): 1.125855 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.11 | q_nlm = 8.17 | h_nlm = 9.09
# [INFO]                 q_geo = 9.32 | h_geo = 10.38
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.277528
# SSIM (NLM padrão): 0.916356
# Elapsed time (NLM): 2.202746 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.625564
# SSIM (GEO NLM): 0.921365
# Total Elapsed time (GEONLM): 56.668297 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.314506
# SSIM (BM3D): 0.945704
# Total Elapsed time (BM3D): 1.437038 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 2.04 | q_nlm = 9.51 | h_nlm = 19.42
# [INFO]                 q_geo = 10.94 | h_geo = 22.34
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 22.536439
# SSIM (NLM padrão): 0.607783
# Elapsed time (NLM): 2.233363 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 24.416569
# SSIM (GEO NLM): 0.777741
# Total Elapsed time (GEONLM): 57.796178 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 22.749336
# SSIM (BM3D): 0.655645
# Total Elapsed time (BM3D): 1.390389 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.14 | q_nlm = 8.20 | h_nlm = 9.32
# [INFO]                 q_geo = 9.37 | h_geo = 10.64
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.395573
# SSIM (NLM padrão): 0.895657
# Elapsed time (NLM): 2.186464 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.422078
# SSIM (GEO NLM): 0.871267
# Total Elapsed time (GEONLM): 56.235280 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.260853
# SSIM (BM3D): 0.930560
# Total Elapsed time (BM3D): 1.337957 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.27 | q_nlm = 8.41 | h_nlm = 10.69
# [INFO]                 q_geo = 9.60 | h_geo = 12.21
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 29.167927
# SSIM (NLM padrão): 0.878083
# Elapsed time (NLM): 2.255358 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 29.809062
# SSIM (GEO NLM): 0.908789
# Total Elapsed time (GEONLM): 55.855277 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 29.793270
# SSIM (BM3D): 0.896578
# Total Elapsed time (BM3D): 2.321910 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.37 | q_nlm = 8.55 | h_nlm = 11.72
# [INFO]                 q_geo = 9.77 | h_geo = 13.39
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 28.510343
# SSIM (NLM padrão): 0.816083
# Elapsed time (NLM): 2.252997 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 29.498436
# SSIM (GEO NLM): 0.878664
# Total Elapsed time (GEONLM): 57.486486 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 28.823928
# SSIM (BM3D): 0.848314
# Total Elapsed time (BM3D): 1.298683 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.07 | q_nlm = 8.11 | h_nlm = 8.71
# [INFO]                 q_geo = 9.26 | h_geo = 9.94
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.736271
# SSIM (NLM padrão): 0.889443
# Elapsed time (NLM): 2.201923 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.722655
# SSIM (GEO NLM): 0.850048
# Total Elapsed time (GEONLM): 57.081119 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.057241
# SSIM (BM3D): 0.928142
# Total Elapsed time (BM3D): 1.032748 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.41 | q_nlm = 8.62 | h_nlm = 12.19
# [INFO]                 q_geo = 9.85 | h_geo = 13.94
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 29.387511
# SSIM (NLM padrão): 0.915016
# Elapsed time (NLM): 2.189653 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 29.669762
# SSIM (GEO NLM): 0.920961
# Total Elapsed time (GEONLM): 56.824363 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 30.079161
# SSIM (BM3D): 0.954440
# Total Elapsed time (BM3D): 1.241745 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.08 | q_nlm = 8.12 | h_nlm = 8.75
# [INFO]                 q_geo = 9.26 | h_geo = 9.98
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.435403
# SSIM (NLM padrão): 0.886696
# Elapsed time (NLM): 2.171146 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.954112
# SSIM (GEO NLM): 0.899162
# Total Elapsed time (GEONLM): 54.946599 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.651239
# SSIM (BM3D): 0.927098
# Total Elapsed time (BM3D): 1.405540 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.25 | q_nlm = 8.38 | h_nlm = 10.47
# [INFO]                 q_geo = 9.56 | h_geo = 11.96
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 32.278927
# SSIM (NLM padrão): 0.930510
# Elapsed time (NLM): 2.248102 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 32.453833
# SSIM (GEO NLM): 0.923217
# Total Elapsed time (GEONLM): 58.366804 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.068080
# SSIM (BM3D): 0.941862
# Total Elapsed time (BM3D): 1.486832 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.23 | q_nlm = 8.34 | h_nlm = 10.22
# [INFO]                 q_geo = 9.52 | h_geo = 11.67
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 28.515068
# SSIM (NLM padrão): 0.902576
# Elapsed time (NLM): 2.356172 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 29.055238
# SSIM (GEO NLM): 0.914118
# Total Elapsed time (GEONLM): 58.252053 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 30.448789
# SSIM (BM3D): 0.933074
# Total Elapsed time (BM3D): 1.771084 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.13 | q_nlm = 8.20 | h_nlm = 9.29
# [INFO]                 q_geo = 9.36 | h_geo = 10.60
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 31.793692
# SSIM (NLM padrão): 0.914778
# Elapsed time (NLM): 2.260744 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 32.193927
# SSIM (GEO NLM): 0.921222
# Total Elapsed time (GEONLM): 56.042931 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.955867
# SSIM (BM3D): 0.927473
# Total Elapsed time (BM3D): 1.785311 s
# Num. linhas = 256
# Num. colunas = 256
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.17 | q_nlm = 8.26 | h_nlm = 9.70
# [INFO]                 q_geo = 9.43 | h_geo = 11.08
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (256, 256)
# filtrada_padrao.shape: (256, 256)
# PSNR (NLM padrão): 30.118193
# SSIM (NLM padrão): 0.914501
# Elapsed time (NLM): 2.178245 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (264, 264)
# M: 256
# N: 256
#
# PSNR (GEO NLM): 30.519953
# SSIM (GEO NLM): 0.909126
# Total Elapsed time (GEONLM): 52.762331 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.041735
# SSIM (BM3D): 0.927620
# Total Elapsed time (BM3D): 1.307210 s

# %%
array_dicts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 array_dicts
#
# NameError: name 'array_dicts' is not defined

# %%
import pandas as pd
import numpy as np

def salvar_resultados_em_xlsx(lista_dicionarios, caminho_arquivo='resultados.xlsx'):
    # Converte os dicionários para DataFrame
    df = pd.DataFrame(lista_dicionarios)
    
    # Converte todos os np.float64 para float padrão do Python
    df = df.applymap(lambda x: float(x) if isinstance(x, np.float64) else x)
    
    # Salva como arquivo Excel
    df.to_excel(caminho_arquivo, index=False)
    print(f'Arquivo salvo em: {caminho_arquivo}')

# %%
# Suponha que você tenha a lista chamada `resultados`
salvar_resultados_em_xlsx(array_dicts, 'saidaPoissonAnscombe.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Suponha que você tenha a lista chamada `resultados`
# ----> 2 salvar_resultados_em_xlsx(array_dicts, 'saidaPoissonAnscombe.xlsx')
#
# NameError: name 'array_dicts' is not defined
