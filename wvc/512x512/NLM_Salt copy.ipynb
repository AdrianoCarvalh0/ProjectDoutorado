# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Dec 15 11:26:44 2019

Implementação do filtro Non-Local Means geodésico

"""
import sys
import warnings
import time
import skimage
import statistics
import networkx as nx
import matplotlib.pyplot as plt
import skimage.io
import skimage.measure
import numpy as np
import sklearn.neighbors as sknn
from scipy.sparse.csgraph import dijkstra
from numpy.matlib import repmat
from scipy.linalg import eigh
from numpy.linalg import inv
from numpy.linalg import cond
from numpy import eye
from sklearn.decomposition import PCA
from skimage.metrics import peak_signal_noise_ratio
from skimage.metrics import structural_similarity
from skimage.transform import rescale, resize, downscale_local_mean
from numba import njit   # just in time compiler (acelera loops)
from joblib import Parallel, delayed

# Para evitar warning de divisão por zero
warnings.simplefilter(action='ignore')

'''
Espelhamento das bordas da imagem A de maneira simétrica
A função pad do numpy não é supertada pelo numba!
Substitui a função: img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')
f é o parâmetro (largura das bordas)
'''
@njit
def mirror(A, f):
    n = A.shape[0]
    m = A.shape[1]
    nlin = A.shape[0] + 2*f
    ncol = A.shape[1] + 2*f
    # Matriz de saída
    B = np.zeros((nlin, ncol))
    # Preeenche miolo
    B[f:nlin-f, f:ncol-f] = A
    # Preenche cantos
    B[0:f, 0:f] = np.flip(A[0:f, 0:f])                          # 1o quadrante
    B[0:f, ncol-f:ncol] = np.flip(A[0:f, m-f:m])                # 2o quadrante
    B[nlin-f:nlin, 0:f] = np.flip(A[n-f:n, 0:f])                # 3o quadrante
    B[nlin-f:nlin, ncol-f:ncol] = np.flip(A[n-f:n, m-f:m])      # 4o quadrante
    # Preenche bordas
    B[0:f, f:ncol-f] = np.flipud(A[0:f, :])             # cima
    B[nlin-f:nlin, f:ncol-f] = np.flipud(A[n-f:n, :])   # baixo
    B[f:nlin-f, 0:f] = np.fliplr(A[:, 0:f])             # esquerda
    B[f:nlin-f, ncol-f:ncol] = np.fliplr(A[:, m-f:m])   # direita
    return B

'''
Non-Local Means padrão (versão rápida)

Parâmetros:

    img: imagem ruidosa de entrada
    h: parâmetro que controla o grau de suavização (quanto maior, mais suaviza)
    f: tamanho do patch (2f + 1 x 2f + 1) -> se f = 3, então patch é 7 x 7
    t: tamanho da janela de busca (2t + 1 x 2t + 1) -> se t = 10, então janela de busca é 21 x 21

'''
@njit
def NLM_fast(img, h, f, t):
    # Dimenssões espaciais da imagem
    m, n = img.shape
    # Cria imagem de saída
    filtrada = np.zeros((m, n))
    # Problema de valor de contorno: replicar bordas
    img_n = mirror(img, f)
    # Loop principal do NLM
    for i in range(m):
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente
            # Obtém o patch ao redor do pixel corrente
            W1 = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1]
            # Calcula as bordas da janela de busca para o pixel corrente (se pixel próximo das bordas, janela de busca é menor)
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            # Calcula média ponderada
            NL = 0      # valor do pixel corrente filtrado
            Z = 0       # constante normalizadora
            # Loop para todos os pixels da janela de busca
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    W2 = img_n[r-f:(r+f)+1, s-f:(s+f)+1]
                    # Calcula o quadrado da distância Euclidiana
                    d2 = np.sum((W1 - W2)*(W1 - W2))
                    # Calcula a medida de similaridade
                    sij = np.exp(-d2/(h**2))               
                    # Atualiza Z e NL
                    Z = Z + sij
                    NL = NL + sij*img_n[r, s]
            # Normalização do pixel filtrado
            filtrada[i, j] = NL/Z
    return filtrada


'''
Non-Local Means geodésico (versão básica, sem paralelismo e mais lenta)

Parâmetros:

    img: imagem ruidosa de entrada
    h: parâmetro que controla o grau de suavização (quanto maior, mais suaviza)
    f: tamanho do patch (2f + 1 x 2f + 1) -> se f = 3, então patch é 7 x 7
    t: tamanho da janela de busca (2t + 1 x 2t + 1) -> se t = 10, então janela de busca é 21 x 21
    nn: número de vizinhos no grafo KNN

''' 
def GeoNLM(img_noise, h, f, t, nn=10):
    # Dimenssões espaciais da imagem
    m, n = img_noise.shape
    # Cria imagem de saída
    filtrada = np.zeros((m, n))
    # Problema de valor de contorno: replicar bordas
    img_n = np.pad(img_noise, ((f, f), (f, f)), 'symmetric')
    # Loop principal do NLM geodésico
    for i in range(m):
        if i % 10 == 0:
            print(i, end=' ')
            sys.stdout.flush()
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente
            # Obtém o patch ao redor do pixel corrente
            patch_central = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1]
            central = np.reshape(patch_central, [1, patch_central.shape[0]*patch_central.shape[1]])[-1]
            # Calcula as bordas da janela de busca para o pixel corrente
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            # Calcula média ponderada
            NL = 0      # valor do pixel corrente filtrado
            Z = 0       # constante normalizadora
            # Cria dataset com patches da janela de busca como vetores
            num_elem = (rmax - rmin)*(smax - smin)
            tamanho_patch = (2*f + 1)*(2*f + 1)
            dataset = np.zeros((num_elem, tamanho_patch))
            k = 0
            pixels_busca = []
            # Loop para montar o dataset com todos os patches da janela
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    W = img_n[r-f:(r+f)+1, s-f:(s+f)+1] 
                    neighbor = np.reshape(W, [1, W.shape[0]*W.shape[1]])[-1]                    
                    dataset[k, :] = neighbor.copy()
                    if central[0] == neighbor[0]:
                        if (central == neighbor).all():
                            source = k
                    pixels_busca.append(img_n[r, s])
                    k = k + 1
            # Cria grafo knn com patches da janela de busca
            knnGraph = sknn.kneighbors_graph(dataset, n_neighbors=nn, mode='distance')
            A = knnGraph.toarray()
            # Converte matriz de adjacências para grafo
            G = nx.from_numpy_array(A)                      
            # Aplica algoritmo de Dijkstra
            length, path = nx.single_source_dijkstra(G, source)
            points = np.array(list(length.keys()))
            distancias = np.array(list(length.values()))
            # Calcula similaridades
            similaridades = np.exp(-distancias**2/(h**2))
            pixels = np.zeros(len(points))
            pixels_busca = np.array(pixels_busca)
            pixels = pixels_busca[points]
            # Normalização do pixel filtrado
            NL = sum(similaridades*pixels)
            Z = sum(similaridades)
            filtrada[i, j] = NL/Z
    return filtrada


######################################################
# Função auxiliar para paralelizar o GEONLM
######################################################
def process_pixel(i, j, img_n, f, t, h, nn):
    im = i + f
    jn = j + f
    patch_central = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1]
    central = np.reshape(patch_central, [1, patch_central.shape[0]*patch_central.shape[1]])[-1]
    rmin = max(im-t, f)
    rmax = min(im+t, m+f)
    smin = max(jn-t, f)
    smax = min(jn+t, n+f)
    NL, Z = 0, 0
    dataset = np.zeros(((rmax - rmin)*(smax - smin), (2*f + 1)*(2*f + 1)))
    k = 0
    pixels_busca = []
    for r in range(rmin, rmax):
        for s in range(smin, smax):
            W = img_n[r-f:(r+f)+1, s-f:(s+f)+1]
            neighbor = np.reshape(W, [1, W.shape[0]*W.shape[1]])[-1]
            dataset[k, :] = neighbor.copy()
            if central[0] == neighbor[0] and (central == neighbor).all():
                source = k
            pixels_busca.append(img_n[r, s])
            k += 1
    knnGraph = sknn.kneighbors_graph(dataset, n_neighbors=nn, mode='distance')
    A = knnGraph.toarray()
    G = nx.from_numpy_array(A)
    length, path = nx.single_source_dijkstra(G, source)
    points = np.array(list(length.keys()))
    distancias = np.array(list(length.values()))
    similaridades = np.exp(-distancias**2 / (h**2))
    pixels_busca = np.array(pixels_busca)
    pixels = pixels_busca[points]
    NL = sum(similaridades * pixels)
    Z = sum(similaridades)
    return NL / Z

##################################################
# GEONLM paralelo 
##################################################
def Parallel_GEONLM(img_n, f, t, h, nn):
    # Parallelize the loop
    m = img_n.shape[0] - 2*f
    n = img_n.shape[1] - 2*f
    filtrada = Parallel(n_jobs=-1)(delayed(process_pixel)(i, j, img_n, f, t, h, nn) for i in range(m) for j in range(n))
    filtrada_geo = np.array(filtrada).reshape((m, n))
    return filtrada_geo

####################################################################
'''
Função que extrai os patches de cada janela de busca no GeoNLM
Retorna uma matriz 4D (m, n, 2t+1 x 2t+1, 2f+1 x 2f+1)

Usa o JIT (just in time) compiler para acelerar loops

'''
####################################################################
@njit
def Extract_patches(img, f, t):
    # Dimenssões espaciais da imagem
    m, n = img.shape
    # Tamanhos do patch e da janela de busca
    tamanho_patch = (2*f + 1)*(2*f + 1)    
    # Patches para cada janela de busca
    patches = []
    centros = []    
    # Problema de valor de contorno: replicar bordas
    img_n = mirror(img, f)
    # Loop principal do NLM geodésico
    for i in range(m):        
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente
            # Obtém o patch ao redor do pixel corrente
            patch_central = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1].copy()
            central = patch_central.reshape((1, patch_central.shape[0]*patch_central.shape[1]))[-1]
            # Calcula as bordas da janela de busca para o pixel corrente
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            num_elem = (rmax - rmin)*(smax - smin)
            # Cria dataset
            dataset = np.zeros((num_elem, tamanho_patch))
            # Loop para montar o dataset com todos os patches da janela
            k = 0
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    W = img_n[r-f:(r+f)+1, s-f:(s+f)+1].copy() 
                    neighbor = W.reshape((1, W.shape[0]*W.shape[1]))[-1]
                    dataset[k, :] = neighbor.copy()
                    if (central == neighbor).all():
                        source = k
                    k = k + 1
            patches.append(dataset)
            centros.append(source)
    return patches, centros

###################################################################
'''
Função que extrai os patches de cada janela de busca no GeoNLM
Retorna uma lista 
'''
###################################################################
def Geodesic_distances(patches, centros, nn=10):
    distancias_geodesicas = []
    pontos = []
    # Percorre a lista de patches
    for i in range(len(patches)):
    # Cria grafo knn com patches da janela de busca
        knnGraph = sknn.kneighbors_graph(patches[i], n_neighbors=nn, mode='distance')
        A = knnGraph.toarray()        
        G = nx.from_numpy_array(A)      # Converte matriz de adjacências para grafo
        # Aplica algoritmo de Dijkstra
        length, path = nx.single_source_dijkstra(G, centros[i])
        points = np.array(list(length.keys()))
        pontos.append(points)
        geodists = np.array(list(length.values()))        
        distancias_geodesicas.append(geodists)
    return distancias_geodesicas, pontos

##################################################################################################
'''
Non-Local Means geodésico (versão com compilador JIT para acelerar loops)

Parâmetros:

    img: imagem ruidosa de entrada
    h: parâmetro que controla o grau de suavização (quanto maior, mais suaviza)
    f: tamanho do patch (2f + 1 x 2f + 1) -> se f = 3, então patch é 7 x 7
    t: tamanho da janela de busca (2t + 1 x 2t + 1) -> se t = 10, então janela de busca é 21 x 21
    nn: número de vizinhos no grafo KNN

''' 
###################################################################################################
@njit
def GeoNLM_fast(img, h, f, t, distancias_geodesicas, pontos):
    # Dimenssões espaciais da imagem
    m, n = img.shape
    # Cria imagem de saída
    filtrada = np.zeros((m, n))
    # Problema de valor de contorno: replicar bordas
    #img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')
    img_n = mirror(img, f)
    # Loop principal do NLM geodésico
    k = 0
    for i in range(m):
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente    
            # Calcula as bordas da janela de busca para o pixel corrente
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            # Calcula média ponderada
            NL = 0      # valor do pixel corrente filtrado
            Z = 0       # constante normalizadora            
            pixels_busca = []
            # Loop para montar o dataset com todos os patches da janela
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    pixels_busca.append(img_n[r, s])
            # Calcula similaridades
            similaridades = np.exp(-distancias_geodesicas[k]**2/(h**2))
            pixels = np.zeros(len(pontos[k]))
            pixels_busca = np.array(pixels_busca)
            pixels = pixels_busca[pontos[k]]
            # Normalização do pixel filtrado
            NL = sum(similaridades*pixels)
            Z = sum(similaridades)
            filtrada[i, j] = NL/Z
            k = k + 1
    return filtrada

#########################################################################
'''
Realiza a filtragem da imagem com o filtro NLM geodésico 

Usa o compilador JIT para acelerar loops
'''
#########################################################################
def GeoNLM_filter(img_noise, h, f, t, nn=10):
    # Fase 1
    print('Início da extração dos patches')
    inicio = time.time()
    patches, centros = Extract_patches(img_noise, f, t)
    fim = time.time()
    print('Elapsed time: %f ' %(fim - inicio))
    print()
    # Fase 2
    print('Início do cálculo das distâncias')
    inicio = time.time()
    distancias_geodesicas, pontos = Geodesic_distances(patches, centros, nn)
    fim = time.time()
    print('Elapsed time: %f ' %(fim - inicio))
    print()
    # Fase 3
    print('Início da filtragem')
    inicio = time.time()
    filtrada = GeoNLM_fast(img_noise, h, f, t, distancias_geodesicas, pontos)
    fim = time.time()
    print('Elapsed time: %f ' %(fim - inicio))
    return filtrada

# %%
import os
def read_directories(directory, img=None, exclude_json=None):
    # Get a list of filenames in the specified directory
    filenames = []
    for filename in os.listdir(directory):
        if img is not None:
            # If 'img' is provided, filter filenames containing it
            if img in filename:   
                filenames.append(filename)
        elif exclude_json is not None:
            filenames.append(filename.replace('.json',''))     
        else:
            filenames.append(filename)    
    return filenames


import numpy as np

def add_salt_and_pepper_noise(image, salt_prob=0.01, pepper_prob=0.01):   
    """
    Adds salt and pepper noise to an image.

    Parameters:
    - image: input image (numpy array).
    - salt_prob: probability of salt pixels (white).
    - pepper_prob: probability of pepper pixels (black).

    Returns:
    - Image with salt and pepper noise.
    """
    
    row, col = image.shape
    noisy = np.copy(image)

    # Adds salt noise
    salt_pixels = np.random.rand(row, col) < salt_prob
    noisy[salt_pixels] = 255

    # Adds pepper noise
    pepper_pixels = np.random.rand(row, col) < pepper_prob
    noisy[pepper_pixels] = 0

    return noisy.astype(np.uint8)

# %%
from pathlib import Path

sys.path.insert(0, r"c:\Users\adria\Documents\Doutorado\ProjetoDoutorado")
root_dir = Path(r"c:\Users\adria\Documents\Doutorado\ProjetoDoutorado")



dir_images = f'{root_dir}/wvc/images'
dir_out_nlm = f'{root_dir}/wvc/512x512/out_put_NLM_Salt_2'
dir_out_geonlm = f'{root_dir}/wvc/512x512/out_put_GEONLM_Salt_2'

array_dir = read_directories(dir_images)

psnrs_nlm = []
ssims_nlm = []

psnrs_geonlm = []
ssims_geonlm = []
array_dicts = []

for file in array_dir:

    file_name = file
    img = skimage.io.imread(f'{dir_images}/{file_name}')
    # Em arquivos de formato GIF precisa desse comando
    img = img[0, :, :]

    # Checa se imagem é monocromática
    if len(img.shape) > 2:
        img = skimage.color.rgb2gray(img)   # valores convertidos ficam entre 0 e 1
        img = 255*img

    # Reescala imagem para (256, 256) - diminuir o tempo de execução
    #img = downscale_local_mean(img, (2, 2))

    img = img.astype(np.uint8)              # Converte para uint8    
    m, n = img.shape

    print('Num. linhas = %d' %m)
    print('Num. colunas = %d' %n)
    print()

    # Cria imagem ruidosa
    ruidosa = add_salt_and_pepper_noise(img)

    # Clipa imagem para intervalo [0, 255]
    ruidosa[np.where(ruidosa > 255)] = 255
    ruidosa[np.where(ruidosa < 0)] = 0
    #ruidosa = ruidosa.astype(np.float32)

    # Listas para métricas


    # Define parâmetros do filtro NLM
    f = 4   # tamanho do patch (2f + 1 x 2f + 1) -> 5 x 5
    t = 7   # tamanho da janela de busca (2t + 1 x 2t + 1) -> 21 x 21
    h_nlm = 110 # parâmetro que controla a suavização no NLM (depende da imagem)
    h_geo = 150 # parâmetro que controla a suavização no GEONLM (depende da imagem)
    nn = 10     # número de vizinhos no grafo k-NN

    # Cria imagem de saída
    filtrada = np.zeros((m, n))

    # Problema de valor de contorno: replicar bordas
    img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')

    ###################################################
    # Filtra com NLM padrão
    ###################################################
    print('***********************************')
    print('*            NLM                  *')
    print('***********************************')
    print()
    inicio = time.time()
    filtrada_padrao = NLM_fast(ruidosa, h_nlm, f, t)
    fim = time.time()    
    # Calcula PSNR
    p1 = peak_signal_noise_ratio(img, filtrada_padrao.astype(np.uint8))
    psnrs_nlm.append(p1)
    print('PSNR (NLM padrão): %f' %p1)
    # Calcula SSIM
    s1 = structural_similarity(img, filtrada_padrao.astype(np.uint8))
    ssims_nlm.append(s1)
    print('SSIM (NLM padrão): %f' %s1)
    print('Elapsed time (NLM): %f s' %(fim - inicio))
    print()
    time_nlm = fim - inicio
    # Salva arquivo
    skimage.io.imsave(f'{dir_out_nlm}/{file_name}', filtrada_padrao.astype(np.uint8))

    ###################################################
    # Filtra com NLM geodésico
    ###################################################
    print('***********************************')
    print('*            GEONLM               *')
    print('***********************************')
    print()
    ini = time.time()

    ##3 Versão com JIT compiler
    #filtrada_geo = GeoNLM_filter(ruidosa, h_geo, f, t, nn)   # versão com JIT compiler (não ficou mais rápido pois o Dijkstra não acelera. Ainda está lento...)

    ### Versão com paralelismo (ficou mais rápida)
    img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')      # para versão paralela, precisa espelhar imagem fora da função
    filtrada_geo = Parallel_GEONLM(img_n, f, t, h_geo, nn)

    end = time.time()
    # Calcula PSNR
    p2 = peak_signal_noise_ratio(img, filtrada_geo.astype(np.uint8))
    psnrs_nlm.append(p2)
    print('\nPSNR (GEO NLM): %f' %p2)
    # Calcula SSIM
    s2 = structural_similarity(img, filtrada_geo.astype(np.uint8))
    ssims_nlm.append(s2)
    print('SSIM (GEO NLM): %f' %s2)
    print('Total Elapsed time (GEONLM): %f s' %(end - ini))

    time_geonlm = end - ini
    print()
    # Salva arquivo    
    skimage.io.imsave(f'{dir_out_geonlm}/{file_name}', filtrada_geo.astype(np.uint8))

    dict = {
        's1': s1,
        'p1': p1,
        's2': s2,
        'p2': p2,
        'time_nlm':time_nlm,
        'time_geonlm':time_geonlm,
        'image': file_name   
    }
    array_dicts.append(dict)
# Out:
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 24.159535
# SSIM (NLM padrão): 0.673184
# Elapsed time (NLM): 16.829467 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.798864
# SSIM (GEO NLM): 0.718832
# Total Elapsed time (GEONLM): 225.186154 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.329446
# SSIM (NLM padrão): 0.726258
# Elapsed time (NLM): 8.589363 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.701198
# SSIM (GEO NLM): 0.765299
# Total Elapsed time (GEONLM): 224.974441 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.055547
# SSIM (NLM padrão): 0.669738
# Elapsed time (NLM): 9.310343 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.504997
# SSIM (GEO NLM): 0.711735
# Total Elapsed time (GEONLM): 209.856117 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 21.485966
# SSIM (NLM padrão): 0.734502
# Elapsed time (NLM): 8.391479 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.280212
# SSIM (GEO NLM): 0.750325
# Total Elapsed time (GEONLM): 208.743193 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.290826
# SSIM (NLM padrão): 0.669877
# Elapsed time (NLM): 8.719952 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.260858
# SSIM (GEO NLM): 0.697327
# Total Elapsed time (GEONLM): 207.193211 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.291616
# SSIM (NLM padrão): 0.695305
# Elapsed time (NLM): 8.264993 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.580430
# SSIM (GEO NLM): 0.733855
# Total Elapsed time (GEONLM): 207.131976 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.558443
# SSIM (NLM padrão): 0.778973
# Elapsed time (NLM): 8.560968 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.897054
# SSIM (GEO NLM): 0.783047
# Total Elapsed time (GEONLM): 208.517173 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.847134
# SSIM (NLM padrão): 0.720518
# Elapsed time (NLM): 8.163105 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.496579
# SSIM (GEO NLM): 0.736045
# Total Elapsed time (GEONLM): 208.381433 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.036060
# SSIM (NLM padrão): 0.719948
# Elapsed time (NLM): 8.869663 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.497356
# SSIM (GEO NLM): 0.724813
# Total Elapsed time (GEONLM): 208.686821 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 21.742958
# SSIM (NLM padrão): 0.743799
# Elapsed time (NLM): 8.204299 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.391750
# SSIM (GEO NLM): 0.756783
# Total Elapsed time (GEONLM): 203.000742 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 21.763474
# SSIM (NLM padrão): 0.742289
# Elapsed time (NLM): 8.109205 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.253465
# SSIM (GEO NLM): 0.751277
# Total Elapsed time (GEONLM): 205.830110 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.000215
# SSIM (NLM padrão): 0.690637
# Elapsed time (NLM): 8.330784 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.870686
# SSIM (GEO NLM): 0.715670
# Total Elapsed time (GEONLM): 208.166924 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.304668
# SSIM (NLM padrão): 0.644988
# Elapsed time (NLM): 8.254464 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.629353
# SSIM (GEO NLM): 0.680750
# Total Elapsed time (GEONLM): 208.649788 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.647200
# SSIM (NLM padrão): 0.693044
# Elapsed time (NLM): 9.009030 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.310138
# SSIM (GEO NLM): 0.710180
# Total Elapsed time (GEONLM): 208.834689 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.576699
# SSIM (NLM padrão): 0.651151
# Elapsed time (NLM): 8.162849 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.811735
# SSIM (GEO NLM): 0.687287
# Total Elapsed time (GEONLM): 209.510276 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.944605
# SSIM (NLM padrão): 0.676109
# Elapsed time (NLM): 8.107096 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.949452
# SSIM (GEO NLM): 0.707452
# Total Elapsed time (GEONLM): 214.029956 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.797884
# SSIM (NLM padrão): 0.637534
# Elapsed time (NLM): 8.765983 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.583836
# SSIM (GEO NLM): 0.692011
# Total Elapsed time (GEONLM): 214.247885 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.826241
# SSIM (NLM padrão): 0.648714
# Elapsed time (NLM): 8.145939 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.258907
# SSIM (GEO NLM): 0.691699
# Total Elapsed time (GEONLM): 214.427764 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 24.181403
# SSIM (NLM padrão): 0.639413
# Elapsed time (NLM): 8.163359 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.912140
# SSIM (GEO NLM): 0.690293
# Total Elapsed time (GEONLM): 215.406891 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.621301
# SSIM (NLM padrão): 0.612385
# Elapsed time (NLM): 8.215500 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.022266
# SSIM (GEO NLM): 0.651755
# Total Elapsed time (GEONLM): 211.032945 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.345192
# SSIM (NLM padrão): 0.651165
# Elapsed time (NLM): 8.679706 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.915430
# SSIM (GEO NLM): 0.696792
# Total Elapsed time (GEONLM): 213.526929 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.899786
# SSIM (NLM padrão): 0.638794
# Elapsed time (NLM): 8.817138 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.286742
# SSIM (GEO NLM): 0.680254
# Total Elapsed time (GEONLM): 212.920532 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 21.831734
# SSIM (NLM padrão): 0.720861
# Elapsed time (NLM): 8.150841 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.335166
# SSIM (GEO NLM): 0.728678
# Total Elapsed time (GEONLM): 207.753955 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.932805
# SSIM (NLM padrão): 0.654430
# Elapsed time (NLM): 9.086681 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.222227
# SSIM (GEO NLM): 0.695520
# Total Elapsed time (GEONLM): 212.733596 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.415138
# SSIM (NLM padrão): 0.655141
# Elapsed time (NLM): 8.225956 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.375021
# SSIM (GEO NLM): 0.678637
# Total Elapsed time (GEONLM): 210.105777 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 21.990073
# SSIM (NLM padrão): 0.765404
# Elapsed time (NLM): 8.309552 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.316809
# SSIM (GEO NLM): 0.765991
# Total Elapsed time (GEONLM): 208.042867 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.188327
# SSIM (NLM padrão): 0.712837
# Elapsed time (NLM): 8.660940 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.907978
# SSIM (GEO NLM): 0.726014
# Total Elapsed time (GEONLM): 202.656839 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.925270
# SSIM (NLM padrão): 0.649953
# Elapsed time (NLM): 8.287606 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.976262
# SSIM (GEO NLM): 0.678936
# Total Elapsed time (GEONLM): 208.483070 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.313972
# SSIM (NLM padrão): 0.694065
# Elapsed time (NLM): 8.410939 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.170203
# SSIM (GEO NLM): 0.715699
# Total Elapsed time (GEONLM): 206.584502 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.961836
# SSIM (NLM padrão): 0.683746
# Elapsed time (NLM): 8.207607 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.295879
# SSIM (GEO NLM): 0.719878
# Total Elapsed time (GEONLM): 210.415690 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 21.865383
# SSIM (NLM padrão): 0.700515
# Elapsed time (NLM): 8.205270 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.688679
# SSIM (GEO NLM): 0.725068
# Total Elapsed time (GEONLM): 206.479236 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.093289
# SSIM (NLM padrão): 0.614057
# Elapsed time (NLM): 8.919670 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.156498
# SSIM (GEO NLM): 0.640230
# Total Elapsed time (GEONLM): 211.121473 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.708613
# SSIM (NLM padrão): 0.661468
# Elapsed time (NLM): 8.645203 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.073139
# SSIM (GEO NLM): 0.701264
# Total Elapsed time (GEONLM): 211.883843 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 24.039440
# SSIM (NLM padrão): 0.654983
# Elapsed time (NLM): 8.371292 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.717497
# SSIM (GEO NLM): 0.701710
# Total Elapsed time (GEONLM): 214.685574 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.396585
# SSIM (NLM padrão): 0.641462
# Elapsed time (NLM): 8.208623 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.683987
# SSIM (GEO NLM): 0.677698
# Total Elapsed time (GEONLM): 211.267205 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 24.911904
# SSIM (NLM padrão): 0.620455
# Elapsed time (NLM): 8.430986 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 26.638154
# SSIM (GEO NLM): 0.663563
# Total Elapsed time (GEONLM): 210.966097 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.725325
# SSIM (NLM padrão): 0.686287
# Elapsed time (NLM): 8.461057 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.927469
# SSIM (GEO NLM): 0.720933
# Total Elapsed time (GEONLM): 206.970276 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.904697
# SSIM (NLM padrão): 0.677416
# Elapsed time (NLM): 8.155105 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.159181
# SSIM (GEO NLM): 0.713327
# Total Elapsed time (GEONLM): 207.931196 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.833919
# SSIM (NLM padrão): 0.695326
# Elapsed time (NLM): 8.712635 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.024722
# SSIM (GEO NLM): 0.731171
# Total Elapsed time (GEONLM): 207.231845 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.399194
# SSIM (NLM padrão): 0.891194
# Elapsed time (NLM): 8.365233 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.425510
# SSIM (GEO NLM): 0.890338
# Total Elapsed time (GEONLM): 203.800307 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.867103
# SSIM (NLM padrão): 0.673458
# Elapsed time (NLM): 8.339693 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.919945
# SSIM (GEO NLM): 0.701478
# Total Elapsed time (GEONLM): 207.372450 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.751153
# SSIM (NLM padrão): 0.734401
# Elapsed time (NLM): 8.224967 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.447735
# SSIM (GEO NLM): 0.749477
# Total Elapsed time (GEONLM): 205.940917 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.179798
# SSIM (NLM padrão): 0.747127
# Elapsed time (NLM): 8.326255 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.802784
# SSIM (GEO NLM): 0.762801
# Total Elapsed time (GEONLM): 205.033912 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.535734
# SSIM (NLM padrão): 0.688438
# Elapsed time (NLM): 8.126591 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.887580
# SSIM (GEO NLM): 0.729078
# Total Elapsed time (GEONLM): 208.901773 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.544026
# SSIM (NLM padrão): 0.767227
# Elapsed time (NLM): 8.210323 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.201237
# SSIM (GEO NLM): 0.791969
# Total Elapsed time (GEONLM): 198.743694 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.347036
# SSIM (NLM padrão): 0.660659
# Elapsed time (NLM): 8.191916 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.672338
# SSIM (GEO NLM): 0.698397
# Total Elapsed time (GEONLM): 210.993463 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.701496
# SSIM (NLM padrão): 0.699768
# Elapsed time (NLM): 8.150001 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.546411
# SSIM (GEO NLM): 0.725455
# Total Elapsed time (GEONLM): 210.858891 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 21.902027
# SSIM (NLM padrão): 0.738159
# Elapsed time (NLM): 8.744696 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.566923
# SSIM (GEO NLM): 0.752971
# Total Elapsed time (GEONLM): 208.211295 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.116842
# SSIM (NLM padrão): 0.644123
# Elapsed time (NLM): 8.183206 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.459590
# SSIM (GEO NLM): 0.680880
# Total Elapsed time (GEONLM): 208.011077 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.344865
# SSIM (NLM padrão): 0.722823
# Elapsed time (NLM): 8.218776 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.330596
# SSIM (GEO NLM): 0.755419
# Total Elapsed time (GEONLM): 211.058398 s

# %%
import pandas as pd
import numpy as np

def salvar_resultados_em_xlsx(lista_dicionarios, caminho_arquivo='resultados.xlsx'):
    # Converte os dicionários para DataFrame
    df = pd.DataFrame(lista_dicionarios)
    
    # Converte todos os np.float64 para float padrão do Python
    df = df.applymap(lambda x: float(x) if isinstance(x, np.float64) else x)
    
    # Salva como arquivo Excel
    df.to_excel(caminho_arquivo, index=False)
    print(f'Arquivo salvo em: {caminho_arquivo}')

# %%
# Suponha que você tenha a lista chamada `resultados`
salvar_resultados_em_xlsx(array_dicts, 'saidaSalt_2.xlsx')
# Out:
# Arquivo salvo em: saidaSalt_2.xlsx
