# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Dec 15 11:26:44 2019

Implementação do filtro Non-Local Means geodésico

"""
import sys
import warnings
import time
import skimage
import statistics
import networkx as nx
import matplotlib.pyplot as plt
import skimage.io
import skimage.measure
import numpy as np
import sklearn.neighbors as sknn
from scipy.sparse.csgraph import dijkstra
from numpy.matlib import repmat
from scipy.linalg import eigh
from numpy.linalg import inv
from numpy.linalg import cond
from numpy import eye
from sklearn.decomposition import PCA
from skimage.metrics import peak_signal_noise_ratio
from skimage.metrics import structural_similarity
from skimage.transform import rescale, resize, downscale_local_mean
from numba import njit   # just in time compiler (acelera loops)
from joblib import Parallel, delayed

# Para evitar warning de divisão por zero
warnings.simplefilter(action='ignore')

'''
Espelhamento das bordas da imagem A de maneira simétrica
A função pad do numpy não é supertada pelo numba!
Substitui a função: img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')
f é o parâmetro (largura das bordas)
'''
@njit
def mirror(A, f):
    n = A.shape[0]
    m = A.shape[1]
    nlin = A.shape[0] + 2*f
    ncol = A.shape[1] + 2*f
    # Matriz de saída
    B = np.zeros((nlin, ncol))
    # Preeenche miolo
    B[f:nlin-f, f:ncol-f] = A
    # Preenche cantos
    B[0:f, 0:f] = np.flip(A[0:f, 0:f])                          # 1o quadrante
    B[0:f, ncol-f:ncol] = np.flip(A[0:f, m-f:m])                # 2o quadrante
    B[nlin-f:nlin, 0:f] = np.flip(A[n-f:n, 0:f])                # 3o quadrante
    B[nlin-f:nlin, ncol-f:ncol] = np.flip(A[n-f:n, m-f:m])      # 4o quadrante
    # Preenche bordas
    B[0:f, f:ncol-f] = np.flipud(A[0:f, :])             # cima
    B[nlin-f:nlin, f:ncol-f] = np.flipud(A[n-f:n, :])   # baixo
    B[f:nlin-f, 0:f] = np.fliplr(A[:, 0:f])             # esquerda
    B[f:nlin-f, ncol-f:ncol] = np.fliplr(A[:, m-f:m])   # direita
    return B

'''
Non-Local Means padrão (versão rápida)

Parâmetros:

    img: imagem ruidosa de entrada
    h: parâmetro que controla o grau de suavização (quanto maior, mais suaviza)
    f: tamanho do patch (2f + 1 x 2f + 1) -> se f = 3, então patch é 7 x 7
    t: tamanho da janela de busca (2t + 1 x 2t + 1) -> se t = 10, então janela de busca é 21 x 21

'''
@njit
def NLM_fast(img, h, f, t):
    # Dimenssões espaciais da imagem
    m, n = img.shape
    # Cria imagem de saída
    filtrada = np.zeros((m, n))
    # Problema de valor de contorno: replicar bordas
    img_n = mirror(img, f)
    # Loop principal do NLM
    for i in range(m):
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente
            # Obtém o patch ao redor do pixel corrente
            W1 = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1]
            # Calcula as bordas da janela de busca para o pixel corrente (se pixel próximo das bordas, janela de busca é menor)
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            # Calcula média ponderada
            NL = 0      # valor do pixel corrente filtrado
            Z = 0       # constante normalizadora
            # Loop para todos os pixels da janela de busca
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    W2 = img_n[r-f:(r+f)+1, s-f:(s+f)+1]
                    # Calcula o quadrado da distância Euclidiana
                    d2 = np.sum((W1 - W2)*(W1 - W2))
                    # Calcula a medida de similaridade
                    sij = np.exp(-d2/(h**2))               
                    # Atualiza Z e NL
                    Z = Z + sij
                    NL = NL + sij*img_n[r, s]
            # Normalização do pixel filtrado
            filtrada[i, j] = NL/Z
    return filtrada


'''
Non-Local Means geodésico (versão básica, sem paralelismo e mais lenta)

Parâmetros:

    img: imagem ruidosa de entrada
    h: parâmetro que controla o grau de suavização (quanto maior, mais suaviza)
    f: tamanho do patch (2f + 1 x 2f + 1) -> se f = 3, então patch é 7 x 7
    t: tamanho da janela de busca (2t + 1 x 2t + 1) -> se t = 10, então janela de busca é 21 x 21
    nn: número de vizinhos no grafo KNN

''' 
def GeoNLM(img_noise, h, f, t, nn=10):
    # Dimenssões espaciais da imagem
    m, n = img_noise.shape
    # Cria imagem de saída
    filtrada = np.zeros((m, n))
    # Problema de valor de contorno: replicar bordas
    img_n = np.pad(img_noise, ((f, f), (f, f)), 'symmetric')
    # Loop principal do NLM geodésico
    for i in range(m):
        if i % 10 == 0:
            print(i, end=' ')
            sys.stdout.flush()
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente
            # Obtém o patch ao redor do pixel corrente
            patch_central = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1]
            central = np.reshape(patch_central, [1, patch_central.shape[0]*patch_central.shape[1]])[-1]
            # Calcula as bordas da janela de busca para o pixel corrente
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            # Calcula média ponderada
            NL = 0      # valor do pixel corrente filtrado
            Z = 0       # constante normalizadora
            # Cria dataset com patches da janela de busca como vetores
            num_elem = (rmax - rmin)*(smax - smin)
            tamanho_patch = (2*f + 1)*(2*f + 1)
            dataset = np.zeros((num_elem, tamanho_patch))
            k = 0
            pixels_busca = []
            # Loop para montar o dataset com todos os patches da janela
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    W = img_n[r-f:(r+f)+1, s-f:(s+f)+1] 
                    neighbor = np.reshape(W, [1, W.shape[0]*W.shape[1]])[-1]                    
                    dataset[k, :] = neighbor.copy()
                    if central[0] == neighbor[0]:
                        if (central == neighbor).all():
                            source = k
                    pixels_busca.append(img_n[r, s])
                    k = k + 1
            # Cria grafo knn com patches da janela de busca
            knnGraph = sknn.kneighbors_graph(dataset, n_neighbors=nn, mode='distance')
            A = knnGraph.toarray()
            # Converte matriz de adjacências para grafo
            G = nx.from_numpy_array(A)                      
            # Aplica algoritmo de Dijkstra
            length, path = nx.single_source_dijkstra(G, source)
            points = np.array(list(length.keys()))
            distancias = np.array(list(length.values()))
            # Calcula similaridades
            similaridades = np.exp(-distancias**2/(h**2))
            pixels = np.zeros(len(points))
            pixels_busca = np.array(pixels_busca)
            pixels = pixels_busca[points]
            # Normalização do pixel filtrado
            NL = sum(similaridades*pixels)
            Z = sum(similaridades)
            filtrada[i, j] = NL/Z
    return filtrada


######################################################
# Função auxiliar para paralelizar o GEONLM
######################################################
def process_pixel(i, j, img_n, f, t, h, nn):
    im = i + f
    jn = j + f
    patch_central = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1]
    central = np.reshape(patch_central, [1, patch_central.shape[0]*patch_central.shape[1]])[-1]
    rmin = max(im-t, f)
    rmax = min(im+t, m+f)
    smin = max(jn-t, f)
    smax = min(jn+t, n+f)
    NL, Z = 0, 0
    dataset = np.zeros(((rmax - rmin)*(smax - smin), (2*f + 1)*(2*f + 1)))
    k = 0
    pixels_busca = []
    for r in range(rmin, rmax):
        for s in range(smin, smax):
            W = img_n[r-f:(r+f)+1, s-f:(s+f)+1]
            neighbor = np.reshape(W, [1, W.shape[0]*W.shape[1]])[-1]
            dataset[k, :] = neighbor.copy()
            if central[0] == neighbor[0] and (central == neighbor).all():
                source = k
            pixels_busca.append(img_n[r, s])
            k += 1
    knnGraph = sknn.kneighbors_graph(dataset, n_neighbors=nn, mode='distance')
    A = knnGraph.toarray()
    G = nx.from_numpy_array(A)
    length, path = nx.single_source_dijkstra(G, source)
    points = np.array(list(length.keys()))
    distancias = np.array(list(length.values()))
    similaridades = np.exp(-distancias**2 / (h**2))
    pixels_busca = np.array(pixels_busca)
    pixels = pixels_busca[points]
    NL = sum(similaridades * pixels)
    Z = sum(similaridades)
    return NL / Z

##################################################
# GEONLM paralelo 
##################################################
def Parallel_GEONLM(img_n, f, t, h, nn):
    # Parallelize the loop
    m = img_n.shape[0] - 2*f
    n = img_n.shape[1] - 2*f
    filtrada = Parallel(n_jobs=-1)(delayed(process_pixel)(i, j, img_n, f, t, h, nn) for i in range(m) for j in range(n))
    filtrada_geo = np.array(filtrada).reshape((m, n))
    return filtrada_geo

####################################################################
'''
Função que extrai os patches de cada janela de busca no GeoNLM
Retorna uma matriz 4D (m, n, 2t+1 x 2t+1, 2f+1 x 2f+1)

Usa o JIT (just in time) compiler para acelerar loops

'''
####################################################################
@njit
def Extract_patches(img, f, t):
    # Dimenssões espaciais da imagem
    m, n = img.shape
    # Tamanhos do patch e da janela de busca
    tamanho_patch = (2*f + 1)*(2*f + 1)    
    # Patches para cada janela de busca
    patches = []
    centros = []    
    # Problema de valor de contorno: replicar bordas
    img_n = mirror(img, f)
    # Loop principal do NLM geodésico
    for i in range(m):        
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente
            # Obtém o patch ao redor do pixel corrente
            patch_central = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1].copy()
            central = patch_central.reshape((1, patch_central.shape[0]*patch_central.shape[1]))[-1]
            # Calcula as bordas da janela de busca para o pixel corrente
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            num_elem = (rmax - rmin)*(smax - smin)
            # Cria dataset
            dataset = np.zeros((num_elem, tamanho_patch))
            # Loop para montar o dataset com todos os patches da janela
            k = 0
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    W = img_n[r-f:(r+f)+1, s-f:(s+f)+1].copy() 
                    neighbor = W.reshape((1, W.shape[0]*W.shape[1]))[-1]
                    dataset[k, :] = neighbor.copy()
                    if (central == neighbor).all():
                        source = k
                    k = k + 1
            patches.append(dataset)
            centros.append(source)
    return patches, centros

###################################################################
'''
Função que extrai os patches de cada janela de busca no GeoNLM
Retorna uma lista 
'''
###################################################################
def Geodesic_distances(patches, centros, nn=10):
    distancias_geodesicas = []
    pontos = []
    # Percorre a lista de patches
    for i in range(len(patches)):
    # Cria grafo knn com patches da janela de busca
        knnGraph = sknn.kneighbors_graph(patches[i], n_neighbors=nn, mode='distance')
        A = knnGraph.toarray()        
        G = nx.from_numpy_array(A)      # Converte matriz de adjacências para grafo
        # Aplica algoritmo de Dijkstra
        length, path = nx.single_source_dijkstra(G, centros[i])
        points = np.array(list(length.keys()))
        pontos.append(points)
        geodists = np.array(list(length.values()))        
        distancias_geodesicas.append(geodists)
    return distancias_geodesicas, pontos

##################################################################################################
'''
Non-Local Means geodésico (versão com compilador JIT para acelerar loops)

Parâmetros:

    img: imagem ruidosa de entrada
    h: parâmetro que controla o grau de suavização (quanto maior, mais suaviza)
    f: tamanho do patch (2f + 1 x 2f + 1) -> se f = 3, então patch é 7 x 7
    t: tamanho da janela de busca (2t + 1 x 2t + 1) -> se t = 10, então janela de busca é 21 x 21
    nn: número de vizinhos no grafo KNN

''' 
###################################################################################################
@njit
def GeoNLM_fast(img, h, f, t, distancias_geodesicas, pontos):
    # Dimenssões espaciais da imagem
    m, n = img.shape
    # Cria imagem de saída
    filtrada = np.zeros((m, n))
    # Problema de valor de contorno: replicar bordas
    #img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')
    img_n = mirror(img, f)
    # Loop principal do NLM geodésico
    k = 0
    for i in range(m):
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente    
            # Calcula as bordas da janela de busca para o pixel corrente
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            # Calcula média ponderada
            NL = 0      # valor do pixel corrente filtrado
            Z = 0       # constante normalizadora            
            pixels_busca = []
            # Loop para montar o dataset com todos os patches da janela
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    pixels_busca.append(img_n[r, s])
            # Calcula similaridades
            similaridades = np.exp(-distancias_geodesicas[k]**2/(h**2))
            pixels = np.zeros(len(pontos[k]))
            pixels_busca = np.array(pixels_busca)
            pixels = pixels_busca[pontos[k]]
            # Normalização do pixel filtrado
            NL = sum(similaridades*pixels)
            Z = sum(similaridades)
            filtrada[i, j] = NL/Z
            k = k + 1
    return filtrada

#########################################################################
'''
Realiza a filtragem da imagem com o filtro NLM geodésico 

Usa o compilador JIT para acelerar loops
'''
#########################################################################
def GeoNLM_filter(img_noise, h, f, t, nn=10):
    # Fase 1
    print('Início da extração dos patches')
    inicio = time.time()
    patches, centros = Extract_patches(img_noise, f, t)
    fim = time.time()
    print('Elapsed time: %f ' %(fim - inicio))
    print()
    # Fase 2
    print('Início do cálculo das distâncias')
    inicio = time.time()
    distancias_geodesicas, pontos = Geodesic_distances(patches, centros, nn)
    fim = time.time()
    print('Elapsed time: %f ' %(fim - inicio))
    print()
    # Fase 3
    print('Início da filtragem')
    inicio = time.time()
    filtrada = GeoNLM_fast(img_noise, h, f, t, distancias_geodesicas, pontos)
    fim = time.time()
    print('Elapsed time: %f ' %(fim - inicio))
    return filtrada

# %%
import os
def read_directories(directory, img=None, exclude_json=None):
    # Get a list of filenames in the specified directory
    filenames = []
    for filename in os.listdir(directory):
        if img is not None:
            # If 'img' is provided, filter filenames containing it
            if img in filename:   
                filenames.append(filename)
        elif exclude_json is not None:
            filenames.append(filename.replace('.json',''))     
        else:
            filenames.append(filename)    
    return filenames


import numpy as np

def add_salt_and_pepper_noise(image, salt_prob=0.01, pepper_prob=0.01):   
    """
    Adds salt and pepper noise to an image.

    Parameters:
    - image: input image (numpy array).
    - salt_prob: probability of salt pixels (white).
    - pepper_prob: probability of pepper pixels (black).

    Returns:
    - Image with salt and pepper noise.
    """
    
    row, col = image.shape
    noisy = np.copy(image)

    # Adds salt noise
    salt_pixels = np.random.rand(row, col) < salt_prob
    noisy[salt_pixels] = 255

    # Adds pepper noise
    pepper_pixels = np.random.rand(row, col) < pepper_prob
    noisy[pepper_pixels] = 0

    return noisy.astype(np.uint8)

# %%
from pathlib import Path

sys.path.insert(0, r"c:\Users\adria\Documents\Doutorado\ProjetoDoutorado")
root_dir = Path(r"c:\Users\adria\Documents\Doutorado\ProjetoDoutorado")



dir_images = f'{root_dir}/wvc/images'
dir_out_nlm = f'{root_dir}/wvc/512x512/out_put_NLM_Salt'
dir_out_geonlm = f'{root_dir}/wvc/512x512/out_put_GEONLM_Salt'

array_dir = read_directories(dir_images)

psnrs_nlm = []
ssims_nlm = []

psnrs_geonlm = []
ssims_geonlm = []
array_dicts = []

for file in array_dir:

    file_name = file
    img = skimage.io.imread(f'{dir_images}/{file_name}')
    # Em arquivos de formato GIF precisa desse comando
    img = img[0, :, :]

    # Checa se imagem é monocromática
    if len(img.shape) > 2:
        img = skimage.color.rgb2gray(img)   # valores convertidos ficam entre 0 e 1
        img = 255*img

    # Reescala imagem para (256, 256) - diminuir o tempo de execução
    #img = downscale_local_mean(img, (2, 2))

    img = img.astype(np.uint8)              # Converte para uint8    
    m, n = img.shape

    print('Num. linhas = %d' %m)
    print('Num. colunas = %d' %n)
    print()

    # Cria imagem ruidosa
    ruidosa = add_salt_and_pepper_noise(img)

    # Clipa imagem para intervalo [0, 255]
    ruidosa[np.where(ruidosa > 255)] = 255
    ruidosa[np.where(ruidosa < 0)] = 0
    #ruidosa = ruidosa.astype(np.float32)

    # Listas para métricas


    # Define parâmetros do filtro NLM
    f = 4   # tamanho do patch (2f + 1 x 2f + 1) -> 5 x 5
    t = 7   # tamanho da janela de busca (2t + 1 x 2t + 1) -> 21 x 21
    h_nlm = 110 # parâmetro que controla a suavização no NLM (depende da imagem)
    h_geo = 150 # parâmetro que controla a suavização no GEONLM (depende da imagem)
    nn = 10     # número de vizinhos no grafo k-NN

    # Cria imagem de saída
    filtrada = np.zeros((m, n))

    # Problema de valor de contorno: replicar bordas
    img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')

    ###################################################
    # Filtra com NLM padrão
    ###################################################
    print('***********************************')
    print('*            NLM                  *')
    print('***********************************')
    print()
    inicio = time.time()
    filtrada_padrao = NLM_fast(ruidosa, h_nlm, f, t)
    fim = time.time()    
    # Calcula PSNR
    p1 = peak_signal_noise_ratio(img, filtrada_padrao.astype(np.uint8))
    psnrs_nlm.append(p1)
    print('PSNR (NLM padrão): %f' %p1)
    # Calcula SSIM
    s1 = structural_similarity(img, filtrada_padrao.astype(np.uint8))
    ssims_nlm.append(s1)
    print('SSIM (NLM padrão): %f' %s1)
    print('Elapsed time (NLM): %f s' %(fim - inicio))
    print()
    time_nlm = fim - inicio
    # Salva arquivo
    skimage.io.imsave(f'{dir_out_nlm}/{file_name}', filtrada_padrao.astype(np.uint8))

    ###################################################
    # Filtra com NLM geodésico
    ###################################################
    print('***********************************')
    print('*            GEONLM               *')
    print('***********************************')
    print()
    ini = time.time()

    ##3 Versão com JIT compiler
    #filtrada_geo = GeoNLM_filter(ruidosa, h_geo, f, t, nn)   # versão com JIT compiler (não ficou mais rápido pois o Dijkstra não acelera. Ainda está lento...)

    ### Versão com paralelismo (ficou mais rápida)
    img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')      # para versão paralela, precisa espelhar imagem fora da função
    filtrada_geo = Parallel_GEONLM(img_n, f, t, h_geo, nn)

    end = time.time()
    # Calcula PSNR
    p2 = peak_signal_noise_ratio(img, filtrada_geo.astype(np.uint8))
    psnrs_nlm.append(p2)
    print('\nPSNR (GEO NLM): %f' %p2)
    # Calcula SSIM
    s2 = structural_similarity(img, filtrada_geo.astype(np.uint8))
    ssims_nlm.append(s2)
    print('SSIM (GEO NLM): %f' %s2)
    print('Total Elapsed time (GEONLM): %f s' %(end - ini))

    time_geonlm = end - ini
    print()
    # Salva arquivo    
    skimage.io.imsave(f'{dir_out_geonlm}/{file_name}', filtrada_geo.astype(np.uint8))

    dict = {
        's1': s1,
        'p1': p1,
        's2': s2,
        'p2': p2,
        'time_nlm':time_nlm,
        'time_geonlm':time_geonlm,
        'image': file_name   
    }
    array_dicts.append(dict)
# Out:
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 24.229400
# SSIM (NLM padrão): 0.677594
# Elapsed time (NLM): 16.552339 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.819596
# SSIM (GEO NLM): 0.723107
# Total Elapsed time (GEONLM): 222.709947 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.234718
# SSIM (NLM padrão): 0.722377
# Elapsed time (NLM): 8.221808 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.579397
# SSIM (GEO NLM): 0.760190
# Total Elapsed time (GEONLM): 214.023607 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.023093
# SSIM (NLM padrão): 0.663923
# Elapsed time (NLM): 8.328838 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.482935
# SSIM (GEO NLM): 0.707136
# Total Elapsed time (GEONLM): 216.271218 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 21.535815
# SSIM (NLM padrão): 0.738337
# Elapsed time (NLM): 8.515221 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.333769
# SSIM (GEO NLM): 0.754635
# Total Elapsed time (GEONLM): 215.978454 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.282081
# SSIM (NLM padrão): 0.673112
# Elapsed time (NLM): 8.255101 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.237643
# SSIM (GEO NLM): 0.698747
# Total Elapsed time (GEONLM): 215.289103 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.216972
# SSIM (NLM padrão): 0.692705
# Elapsed time (NLM): 8.223756 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.482170
# SSIM (GEO NLM): 0.730646
# Total Elapsed time (GEONLM): 214.092095 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.582180
# SSIM (NLM padrão): 0.776793
# Elapsed time (NLM): 8.261344 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.937994
# SSIM (GEO NLM): 0.780596
# Total Elapsed time (GEONLM): 213.964836 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.754134
# SSIM (NLM padrão): 0.715161
# Elapsed time (NLM): 8.178456 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.453219
# SSIM (GEO NLM): 0.730543
# Total Elapsed time (GEONLM): 215.629683 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 21.875922
# SSIM (NLM padrão): 0.712708
# Elapsed time (NLM): 8.194106 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.309240
# SSIM (GEO NLM): 0.717244
# Total Elapsed time (GEONLM): 215.511980 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 21.891198
# SSIM (NLM padrão): 0.749649
# Elapsed time (NLM): 8.809779 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.527267
# SSIM (GEO NLM): 0.764026
# Total Elapsed time (GEONLM): 213.896924 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 21.824970
# SSIM (NLM padrão): 0.743528
# Elapsed time (NLM): 8.201317 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.320235
# SSIM (GEO NLM): 0.752905
# Total Elapsed time (GEONLM): 213.824396 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.129970
# SSIM (NLM padrão): 0.699743
# Elapsed time (NLM): 8.273213 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.014048
# SSIM (GEO NLM): 0.725673
# Total Elapsed time (GEONLM): 215.454380 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.656349
# SSIM (NLM padrão): 0.653475
# Elapsed time (NLM): 8.434528 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.045085
# SSIM (GEO NLM): 0.691317
# Total Elapsed time (GEONLM): 215.003209 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.715357
# SSIM (NLM padrão): 0.695584
# Elapsed time (NLM): 8.225948 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.400820
# SSIM (GEO NLM): 0.712923
# Total Elapsed time (GEONLM): 217.621702 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.543700
# SSIM (NLM padrão): 0.646552
# Elapsed time (NLM): 8.192989 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.772502
# SSIM (GEO NLM): 0.683664
# Total Elapsed time (GEONLM): 217.473454 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.968256
# SSIM (NLM padrão): 0.670133
# Elapsed time (NLM): 8.218840 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.027857
# SSIM (GEO NLM): 0.702400
# Total Elapsed time (GEONLM): 221.493847 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.794475
# SSIM (NLM padrão): 0.642265
# Elapsed time (NLM): 8.192787 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.642280
# SSIM (GEO NLM): 0.695407
# Total Elapsed time (GEONLM): 221.894574 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.576385
# SSIM (NLM padrão): 0.642725
# Elapsed time (NLM): 8.223787 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.912224
# SSIM (GEO NLM): 0.683678
# Total Elapsed time (GEONLM): 220.614156 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 24.230528
# SSIM (NLM padrão): 0.649428
# Elapsed time (NLM): 8.233162 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.838245
# SSIM (GEO NLM): 0.700207
# Total Elapsed time (GEONLM): 223.119053 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.984593
# SSIM (NLM padrão): 0.625223
# Elapsed time (NLM): 8.441624 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.427885
# SSIM (GEO NLM): 0.664263
# Total Elapsed time (GEONLM): 217.964447 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.463780
# SSIM (NLM padrão): 0.651994
# Elapsed time (NLM): 8.213945 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.097247
# SSIM (GEO NLM): 0.697566
# Total Elapsed time (GEONLM): 221.309149 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.929051
# SSIM (NLM padrão): 0.644507
# Elapsed time (NLM): 8.189152 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.277138
# SSIM (GEO NLM): 0.685964
# Total Elapsed time (GEONLM): 220.427191 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 21.752669
# SSIM (NLM padrão): 0.717924
# Elapsed time (NLM): 8.264315 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.276806
# SSIM (GEO NLM): 0.725110
# Total Elapsed time (GEONLM): 214.656970 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.040861
# SSIM (NLM padrão): 0.656335
# Elapsed time (NLM): 8.209779 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.333337
# SSIM (GEO NLM): 0.700468
# Total Elapsed time (GEONLM): 219.367330 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.448291
# SSIM (NLM padrão): 0.656976
# Elapsed time (NLM): 8.191429 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.393660
# SSIM (GEO NLM): 0.680187
# Total Elapsed time (GEONLM): 216.501689 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 21.865595
# SSIM (NLM padrão): 0.758491
# Elapsed time (NLM): 8.275418 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.184532
# SSIM (GEO NLM): 0.760383
# Total Elapsed time (GEONLM): 214.878827 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 21.905595
# SSIM (NLM padrão): 0.710428
# Elapsed time (NLM): 8.197751 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.540983
# SSIM (GEO NLM): 0.721003
# Total Elapsed time (GEONLM): 208.058725 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.936654
# SSIM (NLM padrão): 0.648541
# Elapsed time (NLM): 8.177375 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.989703
# SSIM (GEO NLM): 0.678225
# Total Elapsed time (GEONLM): 214.670804 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.184184
# SSIM (NLM padrão): 0.691742
# Elapsed time (NLM): 8.215587 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.003385
# SSIM (GEO NLM): 0.712247
# Total Elapsed time (GEONLM): 213.149628 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.804307
# SSIM (NLM padrão): 0.685770
# Elapsed time (NLM): 8.215044 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.064075
# SSIM (GEO NLM): 0.720044
# Total Elapsed time (GEONLM): 216.467769 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.120149
# SSIM (NLM padrão): 0.706869
# Elapsed time (NLM): 8.187979 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.994132
# SSIM (GEO NLM): 0.733829
# Total Elapsed time (GEONLM): 212.610420 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.102564
# SSIM (NLM padrão): 0.615408
# Elapsed time (NLM): 8.256382 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.161581
# SSIM (GEO NLM): 0.641041
# Total Elapsed time (GEONLM): 217.559596 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.752040
# SSIM (NLM padrão): 0.665476
# Elapsed time (NLM): 8.186017 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.137446
# SSIM (GEO NLM): 0.705621
# Total Elapsed time (GEONLM): 218.066379 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.862379
# SSIM (NLM padrão): 0.654449
# Elapsed time (NLM): 8.180566 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.458459
# SSIM (GEO NLM): 0.699557
# Total Elapsed time (GEONLM): 221.771203 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.415348
# SSIM (NLM padrão): 0.637473
# Elapsed time (NLM): 8.196785 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.778227
# SSIM (GEO NLM): 0.675878
# Total Elapsed time (GEONLM): 217.731155 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 24.841817
# SSIM (NLM padrão): 0.619159
# Elapsed time (NLM): 8.453846 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 26.592804
# SSIM (GEO NLM): 0.661425
# Total Elapsed time (GEONLM): 217.235121 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.642431
# SSIM (NLM padrão): 0.682130
# Elapsed time (NLM): 8.208330 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.858825
# SSIM (GEO NLM): 0.718470
# Total Elapsed time (GEONLM): 212.779932 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.766577
# SSIM (NLM padrão): 0.674282
# Elapsed time (NLM): 8.218409 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.023147
# SSIM (GEO NLM): 0.710365
# Total Elapsed time (GEONLM): 214.523710 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.804153
# SSIM (NLM padrão): 0.696252
# Elapsed time (NLM): 8.179184 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.983240
# SSIM (GEO NLM): 0.731202
# Total Elapsed time (GEONLM): 213.064022 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.348741
# SSIM (NLM padrão): 0.891349
# Elapsed time (NLM): 8.210419 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.376563
# SSIM (GEO NLM): 0.890489
# Total Elapsed time (GEONLM): 209.845949 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.878910
# SSIM (NLM padrão): 0.676823
# Elapsed time (NLM): 8.231445 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.901600
# SSIM (GEO NLM): 0.705174
# Total Elapsed time (GEONLM): 212.666567 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.702457
# SSIM (NLM padrão): 0.732315
# Elapsed time (NLM): 8.207730 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.378803
# SSIM (GEO NLM): 0.746768
# Total Elapsed time (GEONLM): 212.516195 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.980739
# SSIM (NLM padrão): 0.742401
# Elapsed time (NLM): 8.198308 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.585313
# SSIM (GEO NLM): 0.756928
# Total Elapsed time (GEONLM): 211.507717 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.588615
# SSIM (NLM padrão): 0.686881
# Elapsed time (NLM): 8.168113 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.025522
# SSIM (GEO NLM): 0.728503
# Total Elapsed time (GEONLM): 215.100533 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.502111
# SSIM (NLM padrão): 0.767076
# Elapsed time (NLM): 8.207496 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.149210
# SSIM (GEO NLM): 0.791522
# Total Elapsed time (GEONLM): 206.337345 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.323025
# SSIM (NLM padrão): 0.654565
# Elapsed time (NLM): 8.248583 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.709065
# SSIM (GEO NLM): 0.692846
# Total Elapsed time (GEONLM): 218.261993 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.648021
# SSIM (NLM padrão): 0.699098
# Elapsed time (NLM): 8.179736 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.492354
# SSIM (GEO NLM): 0.725030
# Total Elapsed time (GEONLM): 217.001764 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.046230
# SSIM (NLM padrão): 0.741771
# Elapsed time (NLM): 8.204178 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.726426
# SSIM (GEO NLM): 0.756637
# Total Elapsed time (GEONLM): 214.105222 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 21.991502
# SSIM (NLM padrão): 0.641006
# Elapsed time (NLM): 8.169303 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.308295
# SSIM (GEO NLM): 0.676266
# Total Elapsed time (GEONLM): 214.734008 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.280126
# SSIM (NLM padrão): 0.719785
# Elapsed time (NLM): 8.252106 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.249434
# SSIM (GEO NLM): 0.752379
# Total Elapsed time (GEONLM): 217.273337 s

# %%
import pandas as pd
import numpy as np

def salvar_resultados_em_xlsx(lista_dicionarios, caminho_arquivo='resultados.xlsx'):
    # Converte os dicionários para DataFrame
    df = pd.DataFrame(lista_dicionarios)
    
    # Converte todos os np.float64 para float padrão do Python
    df = df.applymap(lambda x: float(x) if isinstance(x, np.float64) else x)
    
    # Salva como arquivo Excel
    df.to_excel(caminho_arquivo, index=False)
    print(f'Arquivo salvo em: {caminho_arquivo}')

# %%
# Suponha que você tenha a lista chamada `resultados`
salvar_resultados_em_xlsx(array_dicts, 'saidaSalt.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Suponha que você tenha a lista chamada `resultados`
# ----> 2 salvar_resultados_em_xlsx(array_dicts, 'saidaSalt.xlsx')
#
# NameError: name 'salvar_resultados_em_xlsx' is not defined
