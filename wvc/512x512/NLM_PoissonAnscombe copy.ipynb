# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Dec 15 11:26:44 2019

Implementação do filtro Non-Local Means geodésico

"""
import sys
import warnings
import time
import skimage
import statistics
import networkx as nx
import matplotlib.pyplot as plt
import skimage.io
import skimage.measure
import numpy as np
import sklearn.neighbors as sknn
from scipy.sparse.csgraph import dijkstra
from numpy.matlib import repmat
from scipy.linalg import eigh
from numpy.linalg import inv
from numpy.linalg import cond
from numpy import eye
from sklearn.decomposition import PCA
from skimage.metrics import peak_signal_noise_ratio
from skimage.metrics import structural_similarity
from skimage.transform import rescale, resize, downscale_local_mean
from numba import njit   # just in time compiler (acelera loops)
from joblib import Parallel, delayed
from bm3d import bm3d, BM3DProfile

# Para evitar warning de divisão por zero
warnings.simplefilter(action='ignore')

'''
Espelhamento das bordas da imagem A de maneira simétrica
A função pad do numpy não é supertada pelo numba!
Substitui a função: img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')
f é o parâmetro (largura das bordas)
'''
@njit
def mirror(A, f):
    n = A.shape[0]
    m = A.shape[1]
    nlin = A.shape[0] + 2*f
    ncol = A.shape[1] + 2*f
    # Matriz de saída
    B = np.zeros((nlin, ncol))
    # Preeenche miolo
    B[f:nlin-f, f:ncol-f] = A
    # Preenche cantos
    B[0:f, 0:f] = np.flip(A[0:f, 0:f])                          # 1o quadrante
    B[0:f, ncol-f:ncol] = np.flip(A[0:f, m-f:m])                # 2o quadrante
    B[nlin-f:nlin, 0:f] = np.flip(A[n-f:n, 0:f])                # 3o quadrante
    B[nlin-f:nlin, ncol-f:ncol] = np.flip(A[n-f:n, m-f:m])      # 4o quadrante
    # Preenche bordas
    B[0:f, f:ncol-f] = np.flipud(A[0:f, :])             # cima
    B[nlin-f:nlin, f:ncol-f] = np.flipud(A[n-f:n, :])   # baixo
    B[f:nlin-f, 0:f] = np.fliplr(A[:, 0:f])             # esquerda
    B[f:nlin-f, ncol-f:ncol] = np.fliplr(A[:, m-f:m])   # direita
    return B

'''
Non-Local Means padrão (versão rápida)

Parâmetros:

    img: imagem ruidosa de entrada
    h: parâmetro que controla o grau de suavização (quanto maior, mais suaviza)
    f: tamanho do patch (2f + 1 x 2f + 1) -> se f = 3, então patch é 7 x 7
    t: tamanho da janela de busca (2t + 1 x 2t + 1) -> se t = 10, então janela de busca é 21 x 21

'''
@njit
def NLM_fast(img, h, f, t):
    # Dimenssões espaciais da imagem
    m, n = img.shape
    # Cria imagem de saída
    filtrada = np.zeros((m, n))
    # Problema de valor de contorno: replicar bordas
    img_n = mirror(img, f)
    # Loop principal do NLM
    for i in range(m):
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente
            # Obtém o patch ao redor do pixel corrente
            W1 = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1]
            # Calcula as bordas da janela de busca para o pixel corrente (se pixel próximo das bordas, janela de busca é menor)
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            # Calcula média ponderada
            NL = 0      # valor do pixel corrente filtrado
            Z = 0       # constante normalizadora
            # Loop para todos os pixels da janela de busca
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    W2 = img_n[r-f:(r+f)+1, s-f:(s+f)+1]
                    # Calcula o quadrado da distância Euclidiana
                    d2 = np.sum((W1 - W2)*(W1 - W2))
                    # Calcula a medida de similaridade
                    sij = np.exp(-d2/(h**2))               
                    # Atualiza Z e NL
                    Z = Z + sij
                    NL = NL + sij*img_n[r, s]
            # Normalização do pixel filtrado
            filtrada[i, j] = NL/Z
    return filtrada


'''
Non-Local Means geodésico (versão básica, sem paralelismo e mais lenta)

Parâmetros:

    img: imagem ruidosa de entrada
    h: parâmetro que controla o grau de suavização (quanto maior, mais suaviza)
    f: tamanho do patch (2f + 1 x 2f + 1) -> se f = 3, então patch é 7 x 7
    t: tamanho da janela de busca (2t + 1 x 2t + 1) -> se t = 10, então janela de busca é 21 x 21
    nn: número de vizinhos no grafo KNN

''' 
def GeoNLM(img_noise, h, f, t, nn=10):
    # Dimenssões espaciais da imagem
    m, n = img_noise.shape
    # Cria imagem de saída
    filtrada = np.zeros((m, n))
    # Problema de valor de contorno: replicar bordas
    img_n = np.pad(img_noise, ((f, f), (f, f)), 'symmetric')
    # Loop principal do NLM geodésico
    for i in range(m):
        if i % 10 == 0:
            print(i, end=' ')
            sys.stdout.flush()
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente
            # Obtém o patch ao redor do pixel corrente
            patch_central = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1]
            central = np.reshape(patch_central, [1, patch_central.shape[0]*patch_central.shape[1]])[-1]
            # Calcula as bordas da janela de busca para o pixel corrente
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            # Calcula média ponderada
            NL = 0      # valor do pixel corrente filtrado
            Z = 0       # constante normalizadora
            # Cria dataset com patches da janela de busca como vetores
            num_elem = (rmax - rmin)*(smax - smin)
            tamanho_patch = (2*f + 1)*(2*f + 1)
            dataset = np.zeros((num_elem, tamanho_patch))
            k = 0
            pixels_busca = []
            # Loop para montar o dataset com todos os patches da janela
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    W = img_n[r-f:(r+f)+1, s-f:(s+f)+1] 
                    neighbor = np.reshape(W, [1, W.shape[0]*W.shape[1]])[-1]                    
                    dataset[k, :] = neighbor.copy()
                    if central[0] == neighbor[0]:
                        if (central == neighbor).all():
                            source = k
                    pixels_busca.append(img_n[r, s])
                    k = k + 1
            # Cria grafo knn com patches da janela de busca
            knnGraph = sknn.kneighbors_graph(dataset, n_neighbors=nn, mode='distance')
            A = knnGraph.toarray()
            # Converte matriz de adjacências para grafo
            G = nx.from_numpy_array(A)                      
            # Aplica algoritmo de Dijkstra
            length, path = nx.single_source_dijkstra(G, source)
            points = np.array(list(length.keys()))
            distancias = np.array(list(length.values()))
            # Calcula similaridades
            similaridades = np.exp(-distancias**2/(h**2))
            pixels = np.zeros(len(points))
            pixels_busca = np.array(pixels_busca)
            pixels = pixels_busca[points]
            # Normalização do pixel filtrado
            NL = sum(similaridades*pixels)
            Z = sum(similaridades)
            filtrada[i, j] = NL/Z
    return filtrada


######################################################
# Função auxiliar para paralelizar o GEONLM
######################################################
def process_pixel(i, j, img_n, f, t, h, nn):
    im = i + f
    jn = j + f
    patch_central = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1]
    central = np.reshape(patch_central, [1, patch_central.shape[0]*patch_central.shape[1]])[-1]
    rmin = max(im-t, f)
    rmax = min(im+t, m+f)
    smin = max(jn-t, f)
    smax = min(jn+t, n+f)
    NL, Z = 0, 0
    dataset = np.zeros(((rmax - rmin)*(smax - smin), (2*f + 1)*(2*f + 1)))
    k = 0
    pixels_busca = []
    for r in range(rmin, rmax):
        for s in range(smin, smax):
            W = img_n[r-f:(r+f)+1, s-f:(s+f)+1]
            neighbor = np.reshape(W, [1, W.shape[0]*W.shape[1]])[-1]
            dataset[k, :] = neighbor.copy()
            if central[0] == neighbor[0] and (central == neighbor).all():
                source = k
            pixels_busca.append(img_n[r, s])
            k += 1
    knnGraph = sknn.kneighbors_graph(dataset, n_neighbors=nn, mode='distance')
    A = knnGraph.toarray()
    G = nx.from_numpy_array(A)
    length, path = nx.single_source_dijkstra(G, source)
    points = np.array(list(length.keys()))
    distancias = np.array(list(length.values()))
    similaridades = np.exp(-distancias**2 / (h**2))
    pixels_busca = np.array(pixels_busca)
    pixels = pixels_busca[points]
    NL = sum(similaridades * pixels)
    Z = sum(similaridades)
    return NL / Z

##################################################
# GEONLM paralelo 
##################################################
def Parallel_GEONLM(img_n, f, t, h, nn):
    # Parallelize the loop
    print(f'img_n.shape: {img_n.shape}')
    m = img_n.shape[0] - 2*f
    print(f'M: {m}')
    n = img_n.shape[1] - 2*f
    print(f'N: {n}')
    filtrada = Parallel(n_jobs=-1)(delayed(process_pixel)(i, j, img_n, f, t, h, nn) for i in range(m) for j in range(n))
    #print(f"filtrada Shape: {filtrada.shape}")
    
    filtrada_geo = np.array(filtrada).reshape((m, n))
    #print(f'filtrada_geo.shape: {filtrada_geo.shape}')
    return filtrada_geo

####################################################################
'''
Função que extrai os patches de cada janela de busca no GeoNLM
Retorna uma matriz 4D (m, n, 2t+1 x 2t+1, 2f+1 x 2f+1)

Usa o JIT (just in time) compiler para acelerar loops

'''
####################################################################
@njit
def Extract_patches(img, f, t):
    # Dimenssões espaciais da imagem
    m, n = img.shape
    # Tamanhos do patch e da janela de busca
    tamanho_patch = (2*f + 1)*(2*f + 1)    
    # Patches para cada janela de busca
    patches = []
    centros = []    
    # Problema de valor de contorno: replicar bordas
    img_n = mirror(img, f)
    # Loop principal do NLM geodésico
    for i in range(m):        
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente
            # Obtém o patch ao redor do pixel corrente
            patch_central = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1].copy()
            central = patch_central.reshape((1, patch_central.shape[0]*patch_central.shape[1]))[-1]
            # Calcula as bordas da janela de busca para o pixel corrente
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            num_elem = (rmax - rmin)*(smax - smin)
            # Cria dataset
            dataset = np.zeros((num_elem, tamanho_patch))
            # Loop para montar o dataset com todos os patches da janela
            k = 0
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    W = img_n[r-f:(r+f)+1, s-f:(s+f)+1].copy() 
                    neighbor = W.reshape((1, W.shape[0]*W.shape[1]))[-1]
                    dataset[k, :] = neighbor.copy()
                    if (central == neighbor).all():
                        source = k
                    k = k + 1
            patches.append(dataset)
            centros.append(source)
    return patches, centros

###################################################################
'''
Função que extrai os patches de cada janela de busca no GeoNLM
Retorna uma lista 
'''
###################################################################
def Geodesic_distances(patches, centros, nn=10):
    distancias_geodesicas = []
    pontos = []
    # Percorre a lista de patches
    for i in range(len(patches)):
    # Cria grafo knn com patches da janela de busca
        knnGraph = sknn.kneighbors_graph(patches[i], n_neighbors=nn, mode='distance')
        A = knnGraph.toarray()        
        G = nx.from_numpy_array(A)      # Converte matriz de adjacências para grafo
        # Aplica algoritmo de Dijkstra
        length, path = nx.single_source_dijkstra(G, centros[i])
        points = np.array(list(length.keys()))
        pontos.append(points)
        geodists = np.array(list(length.values()))        
        distancias_geodesicas.append(geodists)
    return distancias_geodesicas, pontos

##################################################################################################
'''
Non-Local Means geodésico (versão com compilador JIT para acelerar loops)

Parâmetros:

    img: imagem ruidosa de entrada
    h: parâmetro que controla o grau de suavização (quanto maior, mais suaviza)
    f: tamanho do patch (2f + 1 x 2f + 1) -> se f = 3, então patch é 7 x 7
    t: tamanho da janela de busca (2t + 1 x 2t + 1) -> se t = 10, então janela de busca é 21 x 21
    nn: número de vizinhos no grafo KNN

''' 
###################################################################################################
@njit
def GeoNLM_fast(img, h, f, t, distancias_geodesicas, pontos):
    # Dimenssões espaciais da imagem
    m, n = img.shape
    # Cria imagem de saída
    filtrada = np.zeros((m, n))
    # Problema de valor de contorno: replicar bordas
    #img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')
    img_n = mirror(img, f)
    # Loop principal do NLM geodésico
    k = 0
    for i in range(m):
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente    
            # Calcula as bordas da janela de busca para o pixel corrente
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            # Calcula média ponderada
            NL = 0      # valor do pixel corrente filtrado
            Z = 0       # constante normalizadora            
            pixels_busca = []
            # Loop para montar o dataset com todos os patches da janela
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    pixels_busca.append(img_n[r, s])
            # Calcula similaridades
            similaridades = np.exp(-distancias_geodesicas[k]**2/(h**2))
            pixels = np.zeros(len(pontos[k]))
            pixels_busca = np.array(pixels_busca)
            pixels = pixels_busca[pontos[k]]
            # Normalização do pixel filtrado
            NL = sum(similaridades*pixels)
            Z = sum(similaridades)
            filtrada[i, j] = NL/Z
            k = k + 1
    return filtrada

#########################################################################
'''
Realiza a filtragem da imagem com o filtro NLM geodésico 

Usa o compilador JIT para acelerar loops
'''
#########################################################################
def GeoNLM_filter(img_noise, h, f, t, nn=10):
    # Fase 1
    print('Início da extração dos patches')
    inicio = time.time()
    patches, centros = Extract_patches(img_noise, f, t)
    fim = time.time()
    print('Elapsed time: %f ' %(fim - inicio))
    print()
    # Fase 2
    print('Início do cálculo das distâncias')
    inicio = time.time()
    distancias_geodesicas, pontos = Geodesic_distances(patches, centros, nn)
    fim = time.time()
    print('Elapsed time: %f ' %(fim - inicio))
    print()
    # Fase 3
    print('Início da filtragem')
    inicio = time.time()
    filtrada = GeoNLM_fast(img_noise, h, f, t, distancias_geodesicas, pontos)
    fim = time.time()
    print('Elapsed time: %f ' %(fim - inicio))
    return filtrada

# %%
import os
import math

def read_directories(directory, img=None, exclude_json=None):
    # Get a list of filenames in the specified directory
    filenames = []
    for filename in os.listdir(directory):
        if img is not None:
            # If 'img' is provided, filter filenames containing it
            if img in filename:   
                filenames.append(filename)
        elif exclude_json is not None:
            filenames.append(filename.replace('.json',''))     
        else:
            filenames.append(filename)    
    return filenames


def add_poisson_noise(img):
    """
    Aplica ruído de Poisson corretamente sem overflow.

    Parâmetros:
        img (np.ndarray): Imagem com valores em [0,255] ou [0,1].

    Retorna:
        np.ndarray: imagem ruidosa, clipada para [0, 255], dtype uint8.
    """
    # Se estiver em [0, 1], escala para 0-255
    if img.max() <= 1.0:
        img = (img * 255).astype(np.float32)
    else:
        img = img.astype(np.float32)

    # Garante que os valores Poisson não causem overflow
    poisson_img = np.random.poisson(img).astype(np.float32)
    poisson_img = np.clip(poisson_img, 0, 255)

    return poisson_img.astype(np.uint8)

def anscombe_transform(img):
    return 2.0 * np.sqrt(img.astype(np.float32) + 3.0 / 8.0)

def inverse_anscombe(transf_img):
    return np.clip((transf_img / 2.0) ** 2 - 3.0 / 8.0, 0, 255)

def compute_adaptive_q(sigma_est):
    q_nlm = 0.8 + 0.5 * math.tanh(0.3 * (sigma_est - 1))
    q_geo = 1.0 + 0.7 * math.tanh(0.25 * (sigma_est - 1.5))

    q_nlm = np.clip(q_nlm, 0.7, 2.2) * 10
    q_geo = np.clip(q_geo, 0.9, 2.7) * 10

    return q_nlm, q_geo

def add_poisson_gaussian_noise(image, gaussian_sigma=25):
    """
    Adds Poisson noise followed by Gaussian noise to an image.

    Parameters:
        image (np.ndarray): Input image (grayscale or RGB), values in [0, 1] or [0, 255].
        gaussian_sigma (float): Standard deviation of the Gaussian noise (in intensity scale 0–255).

    Returns:
        np.ndarray: Noisy image (clipped to [0, 255] and converted to uint8).
    """
    # Convert to float32 and normalize to [0, 255] if necessary
    if image.dtype != np.float32:
        image = image.astype(np.float32)

    if image.max() <= 1.0:
        image *= 255.0

    # Apply Poisson noise
    poisson_image = np.random.poisson(image).astype(np.float32)

    # Apply Gaussian noise
    gaussian_noise = np.random.normal(loc=0.0, scale=gaussian_sigma, size=image.shape)
    noisy_image = poisson_image + gaussian_noise

    # Clip values and convert to uint8
    noisy_image = np.clip(noisy_image, 0, 255).astype(np.uint8)

    return noisy_image

# %%
from pathlib import Path
from skimage.restoration import estimate_sigma

sys.path.insert(0, r"c:\Users\adria\Documents\Doutorado\ProjetoDoutorado")
root_dir = Path(r"c:\Users\adria\Documents\Doutorado\ProjetoDoutorado")



dir_images = f'{root_dir}/wvc/images'
dir_out_nlm = f'{root_dir}/wvc/512x512/Anscombe/out_put_NLM_Poisson'
dir_out_geonlm = f'{root_dir}/wvc/512x512/Anscombe/out_put_GEONLM_Poisson'
dir_out_bm3d = f'{root_dir}/wvc/512x512/Anscombe/out_put_BM3D_Poisson'

array_dir = read_directories(dir_images)

array_dicts = []

for file in array_dir:

    file_name = file
    img = skimage.io.imread(f'{dir_images}/{file_name}')
    # Em arquivos de formato GIF precisa desse comando
    img = img[0, :, :]

    # Checa se imagem é monocromática
    if len(img.shape) > 2:
        img = skimage.color.rgb2gray(img)   # valores convertidos ficam entre 0 e 1
        img = 255*img

    # Reescala imagem para (256, 256) - diminuir o tempo de execução
    #img = downscale_local_mean(img, (2, 2))

    img = img.astype(np.uint8)              # Converte para uint8    
    m, n = img.shape

    print('Num. linhas = %d' %m)
    print('Num. colunas = %d' %n)
    print()

    # Cria imagem ruidosa
    ruidosa = add_poisson_noise(img)

    # Clipa imagem para intervalo [0, 255]
    ruidosa[np.where(ruidosa > 255)] = 255
    ruidosa[np.where(ruidosa < 0)] = 0
    #ruidosa = ruidosa.astype(np.float32)

    # Listas para métricas


    # Define parâmetros do filtro NLM
    f = 4   # tamanho do patch (2f + 1 x 2f + 1) -> 5 x 5
    t = 7   # tamanho da janela de busca (2t + 1 x 2t + 1) -> 21 x 21
    h_nlm = 16 # parâmetro que controla a suavização no NLM (depende da imagem)
    h_geo = 21 # parâmetro que controla a suavização no GEONLM (depende da imagem)
    nn = 10     # número de vizinhos no grafo k-NN

    # Cria imagem de saída
    filtrada = np.zeros((m, n))

    # Problema de valor de contorno: replicar bordas
    img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')

 
    inicio = time.time()
    #ruidosa_asc = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')      # para versão paralela, precisa espelhar imagem fora da função


    ruidosa_anscombe = anscombe_transform(ruidosa)
    #print(f'ruidosa_asc_nlm.shape: {ruidosa_anscombe.shape}')
    sigma_est = estimate_sigma(ruidosa_anscombe)
    q_nlm, q_geo = compute_adaptive_q(sigma_est)
    h_nlm = q_nlm * sigma_est #* 10
    h_geo = q_geo * sigma_est #* 10

    print('***********************************')
    print('*         Parâmetro H             *')
    print('***********************************')
    print(f"[INFO] σ estimado: {sigma_est:.2f} | q_nlm = {q_nlm:.2f} | h_nlm = {h_nlm:.2f}")
    print(f"[INFO]                 q_geo = {q_geo:.2f} | h_geo = {h_geo:.2f}")
    

    ###################################################
    # Filtra com NLM padrão
    ###################################################
    print('***********************************')
    print('*            NLM                  *')
    print('***********************************')
    print()
    filtrada_asc = NLM_fast(ruidosa_anscombe, h_nlm, f, t)
    print(f'filtrada_asc.shape: {filtrada_asc.shape}')
    filtrada_padrao = inverse_anscombe(filtrada_asc).astype(np.uint8)
    print(f'filtrada_padrao.shape: {filtrada_padrao.shape}')

    fim = time.time()    
    # Calcula PSNR
    p1_nlm = peak_signal_noise_ratio(img, filtrada_padrao.astype(np.uint8))
   
    print('PSNR (NLM padrão): %f' %p1_nlm)
    # Calcula SSIM
    s1_nlm = structural_similarity(img, filtrada_padrao.astype(np.uint8))
  
    print('SSIM (NLM padrão): %f' %s1_nlm)
    print('Elapsed time (NLM): %f s' %(fim - inicio))
    print()
    time_nlm = fim - inicio
    # Salva arquivo
    skimage.io.imsave(f'{dir_out_nlm}/{file_name}', filtrada_padrao.astype(np.uint8))

    ###################################################
    # Filtra com NLM geodésico
    ###################################################
    print('***********************************')
    print('*            GEONLM               *')
    print('***********************************')
    print()
    ini = time.time()

    ##3 Versão com JIT compiler
    #filtrada_geo = GeoNLM_filter(ruidosa, h_geo, f, t, nn)   # versão com JIT compiler (não ficou mais rápido pois o Dijkstra não acelera. Ainda está lento...)

    ### Versão com paralelismo (ficou mais rápida)
    img_n_geo = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')      # para versão paralela, precisa espelhar imagem fora da função

    ruidosa_asc_geo = anscombe_transform(img_n_geo)
    filtrada_geo_asc = Parallel_GEONLM(ruidosa_asc_geo, f, t, h_geo, nn)

    filtrada_geo = inverse_anscombe(filtrada_geo_asc).astype(np.uint8)

    end = time.time()
    # Calcula PSNR
    p2_gnlm = peak_signal_noise_ratio(img, filtrada_geo.astype(np.uint8))    
    print('\nPSNR (GEO NLM): %f' %p2_gnlm)
    # Calcula SSIM
    s2_gnlm = structural_similarity(img, filtrada_geo.astype(np.uint8))
   
    print('SSIM (GEO NLM): %f' %s2_gnlm)
    print('Total Elapsed time (GEONLM): %f s' %(end - ini))

    time_geonlm = end - ini
    print()
    # Salva arquivo    
    skimage.io.imsave(f'{dir_out_geonlm}/{file_name}', filtrada_geo.astype(np.uint8))
    
    print('***********************************')
    print('*            BM3D                 *')
    print('***********************************')
    print()


    ini = time.time()

    # 1. Normaliza a imagem ruidosa para intervalo [0, 1]
    #ruidosa_normalizada = ruidosa.astype(np.float32) / 255.0

    #ruidosa_asc_bm3d = anscombe_transform(ruidosa_normalizada)

    #sigma_est = estimate_sigma(ruidosa_asc_bm3d, channel_axis=None)

    # 3. Define o perfil padrão do BM3D
    perfil_bm3d = BM3DProfile()

    # 4. Aplica o BM3D com os argumentos definidos
    denoised = bm3d(
        ruidosa_anscombe,
        sigma_psd=sigma_est,
        profile=perfil_bm3d
    )
    denoised_sq = np.squeeze(denoised)

    filtrada_bm3d = inverse_anscombe(denoised_sq).astype(np.uint8)

    end = time.time()

    time_bm3d = end - ini

    skimage.io.imsave(f'{dir_out_bm3d}/{file_name}', np.clip(filtrada_bm3d, 0, 255).astype(np.uint8))

    p3_bm3d = peak_signal_noise_ratio(img, filtrada_bm3d.astype(np.uint8))
    print('\nPSNR (BM3D): %f' %p3_bm3d)
    s3_bm3d = structural_similarity(img, filtrada_bm3d.astype(np.uint8))
    print('SSIM (BM3D): %f' %s3_bm3d)
    print('Total Elapsed time (BM3D): %f s' %(time_bm3d))

    dict = {
        's1_NLM': s1_nlm,        
        's2_GNLM': s2_gnlm,
        's3_BM3D': s3_bm3d,
        'p1_NLM': p1_nlm,
        'p2_GLM': p2_gnlm,
        'p3_GLM': p3_bm3d,
        'time_nlm':time_nlm,
        'time_geonlm':time_geonlm,
        'time_bm3d':time_bm3d,
        'h_nlm':h_nlm,
        'h_geo':h_geo,
        'sigma':sigma_est,
        'image': file_name   
    }
    array_dicts.append(dict)
# Out:
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.05 | q_nlm = 8.08 | h_nlm = 8.51
# [INFO]                 q_geo = 9.22 | h_geo = 9.71
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 33.590474
# SSIM (NLM padrão): 0.893960
# Elapsed time (NLM): 17.841224 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 32.593756
# SSIM (GEO NLM): 0.826524
# Total Elapsed time (GEONLM): 251.375274 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 35.575171
# SSIM (BM3D): 0.914873
# Total Elapsed time (BM3D): 2.875102 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.18 | q_nlm = 8.26 | h_nlm = 9.72
# [INFO]                 q_geo = 9.43 | h_geo = 11.09
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 32.135218
# SSIM (NLM padrão): 0.914409
# Elapsed time (NLM): 8.293055 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 32.448333
# SSIM (GEO NLM): 0.902538
# Total Elapsed time (GEONLM): 239.381312 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 34.431515
# SSIM (BM3D): 0.939062
# Total Elapsed time (BM3D): 3.626411 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.03 | q_nlm = 8.04 | h_nlm = 8.25
# [INFO]                 q_geo = 9.17 | h_geo = 9.41
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 31.808589
# SSIM (NLM padrão): 0.884746
# Elapsed time (NLM): 9.426285 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 30.723648
# SSIM (GEO NLM): 0.756186
# Total Elapsed time (GEONLM): 242.543754 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 34.882387
# SSIM (BM3D): 0.926667
# Total Elapsed time (BM3D): 3.188917 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.11 | q_nlm = 8.16 | h_nlm = 9.05
# [INFO]                 q_geo = 9.32 | h_geo = 10.33
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 29.467131
# SSIM (NLM padrão): 0.868232
# Elapsed time (NLM): 8.585805 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 29.752231
# SSIM (GEO NLM): 0.870483
# Total Elapsed time (GEONLM): 239.976298 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.496971
# SSIM (BM3D): 0.891672
# Total Elapsed time (BM3D): 3.308095 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.22 | q_nlm = 8.33 | h_nlm = 10.15
# [INFO]                 q_geo = 9.51 | h_geo = 11.58
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 32.268951
# SSIM (NLM padrão): 0.885924
# Elapsed time (NLM): 8.609964 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 32.651577
# SSIM (GEO NLM): 0.900462
# Total Elapsed time (GEONLM): 238.569510 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.333879
# SSIM (BM3D): 0.900779
# Total Elapsed time (BM3D): 2.520838 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.04 | q_nlm = 8.06 | h_nlm = 8.41
# [INFO]                 q_geo = 9.20 | h_geo = 9.60
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 30.801390
# SSIM (NLM padrão): 0.881452
# Elapsed time (NLM): 8.437762 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 30.413465
# SSIM (GEO NLM): 0.810488
# Total Elapsed time (GEONLM): 237.632626 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.537457
# SSIM (BM3D): 0.928996
# Total Elapsed time (BM3D): 2.587893 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.46 | q_nlm = 8.69 | h_nlm = 12.72
# [INFO]                 q_geo = 9.94 | h_geo = 14.54
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 29.355205
# SSIM (NLM padrão): 0.886166
# Elapsed time (NLM): 8.420402 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 29.865792
# SSIM (GEO NLM): 0.912113
# Total Elapsed time (GEONLM): 240.619934 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 29.786261
# SSIM (BM3D): 0.896397
# Total Elapsed time (BM3D): 2.501943 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.29 | q_nlm = 8.43 | h_nlm = 10.87
# [INFO]                 q_geo = 9.63 | h_geo = 12.42
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 30.697762
# SSIM (NLM padrão): 0.879891
# Elapsed time (NLM): 8.452574 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 31.006581
# SSIM (GEO NLM): 0.898103
# Total Elapsed time (GEONLM): 240.084650 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.537686
# SSIM (BM3D): 0.888773
# Total Elapsed time (BM3D): 2.561634 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 2.07 | q_nlm = 9.55 | h_nlm = 19.76
# [INFO]                 q_geo = 10.99 | h_geo = 22.74
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 26.624152
# SSIM (NLM padrão): 0.700629
# Elapsed time (NLM): 8.426730 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 27.951628
# SSIM (GEO NLM): 0.793357
# Total Elapsed time (GEONLM): 240.506452 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 26.788367
# SSIM (BM3D): 0.742119
# Total Elapsed time (BM3D): 2.548244 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.22 | q_nlm = 8.33 | h_nlm = 10.16
# [INFO]                 q_geo = 9.51 | h_geo = 11.60
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 30.041077
# SSIM (NLM padrão): 0.933035
# Elapsed time (NLM): 8.498775 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 30.338620
# SSIM (GEO NLM): 0.942484
# Total Elapsed time (GEONLM): 234.311979 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.410442
# SSIM (BM3D): 0.942665
# Total Elapsed time (BM3D): 2.834008 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.58 | q_nlm = 8.86 | h_nlm = 14.02
# [INFO]                 q_geo = 10.14 | h_geo = 16.04
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 30.080000
# SSIM (NLM padrão): 0.891334
# Elapsed time (NLM): 8.456552 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 30.556663
# SSIM (GEO NLM): 0.916172
# Total Elapsed time (GEONLM): 239.226899 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 29.941348
# SSIM (BM3D): 0.890282
# Total Elapsed time (BM3D): 2.543765 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.22 | q_nlm = 8.32 | h_nlm = 10.12
# [INFO]                 q_geo = 9.50 | h_geo = 11.55
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 32.523626
# SSIM (NLM padrão): 0.924141
# Elapsed time (NLM): 8.502580 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 32.817487
# SSIM (GEO NLM): 0.924353
# Total Elapsed time (GEONLM): 237.023297 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.416437
# SSIM (BM3D): 0.931728
# Total Elapsed time (BM3D): 2.720200 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.08 | q_nlm = 8.12 | h_nlm = 8.74
# [INFO]                 q_geo = 9.26 | h_geo = 9.98
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 31.741986
# SSIM (NLM padrão): 0.853332
# Elapsed time (NLM): 8.441501 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 31.840535
# SSIM (GEO NLM): 0.852099
# Total Elapsed time (GEONLM): 237.032285 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.440936
# SSIM (BM3D): 0.890000
# Total Elapsed time (BM3D): 4.065989 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.29 | q_nlm = 8.44 | h_nlm = 10.90
# [INFO]                 q_geo = 9.64 | h_geo = 12.44
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 31.393017
# SSIM (NLM padrão): 0.888954
# Elapsed time (NLM): 8.518280 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 31.663048
# SSIM (GEO NLM): 0.892997
# Total Elapsed time (GEONLM): 238.950980 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.074242
# SSIM (BM3D): 0.896268
# Total Elapsed time (BM3D): 2.697640 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.14 | q_nlm = 8.20 | h_nlm = 9.32
# [INFO]                 q_geo = 9.37 | h_geo = 10.64
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 32.455284
# SSIM (NLM padrão): 0.882417
# Elapsed time (NLM): 8.458646 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 32.501330
# SSIM (GEO NLM): 0.867080
# Total Elapsed time (GEONLM): 240.309112 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.429110
# SSIM (BM3D): 0.896099
# Total Elapsed time (BM3D): 2.571596 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.24 | q_nlm = 8.36 | h_nlm = 10.40
# [INFO]                 q_geo = 9.55 | h_geo = 11.87
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 31.240251
# SSIM (NLM padrão): 0.862142
# Elapsed time (NLM): 8.409679 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 31.390848
# SSIM (GEO NLM): 0.861149
# Total Elapsed time (GEONLM): 244.094832 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.110740
# SSIM (BM3D): 0.852478
# Total Elapsed time (BM3D): 2.729152 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.03 | q_nlm = 8.05 | h_nlm = 8.30
# [INFO]                 q_geo = 9.18 | h_geo = 9.47
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 34.789212
# SSIM (NLM padrão): 0.906976
# Elapsed time (NLM): 8.458396 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 34.106959
# SSIM (GEO NLM): 0.853236
# Total Elapsed time (GEONLM): 241.780901 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 37.014667
# SSIM (BM3D): 0.931369
# Total Elapsed time (BM3D): 2.584502 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.10 | q_nlm = 8.15 | h_nlm = 8.95
# [INFO]                 q_geo = 9.30 | h_geo = 10.21
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 33.159683
# SSIM (NLM padrão): 0.887494
# Elapsed time (NLM): 8.431764 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 33.018997
# SSIM (GEO NLM): 0.858092
# Total Elapsed time (GEONLM): 241.335859 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 34.628092
# SSIM (BM3D): 0.908807
# Total Elapsed time (BM3D): 2.756927 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.09 | q_nlm = 8.13 | h_nlm = 8.83
# [INFO]                 q_geo = 9.28 | h_geo = 10.08
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 35.785732
# SSIM (NLM padrão): 0.900867
# Elapsed time (NLM): 8.446239 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 34.915228
# SSIM (GEO NLM): 0.853189
# Total Elapsed time (GEONLM): 241.684889 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 37.289537
# SSIM (BM3D): 0.926474
# Total Elapsed time (BM3D): 2.559685 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.06 | q_nlm = 8.10 | h_nlm = 8.62
# [INFO]                 q_geo = 9.24 | h_geo = 9.83
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 32.851080
# SSIM (NLM padrão): 0.855110
# Elapsed time (NLM): 8.436719 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 32.845358
# SSIM (GEO NLM): 0.854269
# Total Elapsed time (GEONLM): 239.583680 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 34.385786
# SSIM (BM3D): 0.892890
# Total Elapsed time (BM3D): 2.513084 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.05 | q_nlm = 8.07 | h_nlm = 8.44
# [INFO]                 q_geo = 9.21 | h_geo = 9.63
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 34.612076
# SSIM (NLM padrão): 0.913237
# Elapsed time (NLM): 8.486051 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 34.038931
# SSIM (GEO NLM): 0.868116
# Total Elapsed time (GEONLM): 241.924997 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 36.195922
# SSIM (BM3D): 0.926014
# Total Elapsed time (BM3D): 2.929983 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.14 | q_nlm = 8.21 | h_nlm = 9.37
# [INFO]                 q_geo = 9.37 | h_geo = 10.70
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 33.412848
# SSIM (NLM padrão): 0.871501
# Elapsed time (NLM): 8.408432 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 33.234524
# SSIM (GEO NLM): 0.851109
# Total Elapsed time (GEONLM): 239.612523 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 34.239131
# SSIM (BM3D): 0.888693
# Total Elapsed time (BM3D): 2.552573 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 2.03 | q_nlm = 9.49 | h_nlm = 19.24
# [INFO]                 q_geo = 10.92 | h_geo = 22.12
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 25.763777
# SSIM (NLM padrão): 0.706416
# Elapsed time (NLM): 8.441473 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 28.168200
# SSIM (GEO NLM): 0.843192
# Total Elapsed time (GEONLM): 241.921690 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 27.313628
# SSIM (BM3D): 0.797408
# Total Elapsed time (BM3D): 2.531037 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.12 | q_nlm = 8.17 | h_nlm = 9.13
# [INFO]                 q_geo = 9.33 | h_geo = 10.42
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 33.448664
# SSIM (NLM padrão): 0.905306
# Elapsed time (NLM): 8.441398 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 33.581105
# SSIM (GEO NLM): 0.893381
# Total Elapsed time (GEONLM): 240.441809 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 34.812437
# SSIM (BM3D): 0.926912
# Total Elapsed time (BM3D): 2.825238 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.20 | q_nlm = 8.30 | h_nlm = 9.94
# [INFO]                 q_geo = 9.47 | h_geo = 11.34
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 31.078459
# SSIM (NLM padrão): 0.851859
# Elapsed time (NLM): 8.474802 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 31.656970
# SSIM (GEO NLM): 0.884177
# Total Elapsed time (GEONLM): 240.088537 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.131919
# SSIM (BM3D): 0.875469
# Total Elapsed time (BM3D): 2.541903 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 2.36 | q_nlm = 9.93 | h_nlm = 23.40
# [INFO]                 q_geo = 11.48 | h_geo = 27.05
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 25.446129
# SSIM (NLM padrão): 0.736848
# Elapsed time (NLM): 8.451276 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 26.747182
# SSIM (GEO NLM): 0.824545
# Total Elapsed time (GEONLM): 242.156746 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 25.624799
# SSIM (BM3D): 0.778195
# Total Elapsed time (BM3D): 2.510575 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.08 | q_nlm = 8.12 | h_nlm = 8.78
# [INFO]                 q_geo = 9.27 | h_geo = 10.02
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 30.232689
# SSIM (NLM padrão): 0.884972
# Elapsed time (NLM): 8.406742 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 30.391529
# SSIM (GEO NLM): 0.899196
# Total Elapsed time (GEONLM): 229.121667 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.469171
# SSIM (BM3D): 0.892533
# Total Elapsed time (BM3D): 3.687682 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.21 | q_nlm = 8.31 | h_nlm = 10.06
# [INFO]                 q_geo = 9.49 | h_geo = 11.49
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 30.934511
# SSIM (NLM padrão): 0.839427
# Elapsed time (NLM): 8.480170 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 31.640100
# SSIM (GEO NLM): 0.878958
# Total Elapsed time (GEONLM): 238.881693 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.797184
# SSIM (BM3D): 0.871347
# Total Elapsed time (BM3D): 2.560192 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.30 | q_nlm = 8.44 | h_nlm = 10.94
# [INFO]                 q_geo = 9.64 | h_geo = 12.49
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 30.478840
# SSIM (NLM padrão): 0.879119
# Elapsed time (NLM): 8.436836 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 31.242850
# SSIM (GEO NLM): 0.909364
# Total Elapsed time (GEONLM): 237.629935 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 30.904794
# SSIM (BM3D): 0.890190
# Total Elapsed time (BM3D): 2.584901 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.14 | q_nlm = 8.21 | h_nlm = 9.33
# [INFO]                 q_geo = 9.37 | h_geo = 10.65
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 31.702019
# SSIM (NLM padrão): 0.869177
# Elapsed time (NLM): 8.412652 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 31.706049
# SSIM (GEO NLM): 0.860395
# Total Elapsed time (GEONLM): 239.351166 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.877981
# SSIM (BM3D): 0.881153
# Total Elapsed time (BM3D): 2.562677 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.26 | q_nlm = 8.39 | h_nlm = 10.58
# [INFO]                 q_geo = 9.58 | h_geo = 12.08
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 31.799574
# SSIM (NLM padrão): 0.921056
# Elapsed time (NLM): 8.400630 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 32.291201
# SSIM (GEO NLM): 0.929002
# Total Elapsed time (GEONLM): 234.396568 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.271168
# SSIM (BM3D): 0.923275
# Total Elapsed time (BM3D): 2.573213 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.19 | q_nlm = 8.28 | h_nlm = 9.84
# [INFO]                 q_geo = 9.46 | h_geo = 11.24
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 30.713748
# SSIM (NLM padrão): 0.807526
# Elapsed time (NLM): 8.382949 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 31.341208
# SSIM (GEO NLM): 0.854577
# Total Elapsed time (GEONLM): 241.240409 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.366675
# SSIM (BM3D): 0.829434
# Total Elapsed time (BM3D): 3.087703 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.05 | q_nlm = 8.07 | h_nlm = 8.47
# [INFO]                 q_geo = 9.21 | h_geo = 9.67
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 32.087341
# SSIM (NLM padrão): 0.883355
# Elapsed time (NLM): 8.428440 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 31.854224
# SSIM (GEO NLM): 0.839314
# Total Elapsed time (GEONLM): 239.104078 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 34.249645
# SSIM (BM3D): 0.913066
# Total Elapsed time (BM3D): 2.823946 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.05 | q_nlm = 8.07 | h_nlm = 8.46
# [INFO]                 q_geo = 9.21 | h_geo = 9.66
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 34.118537
# SSIM (NLM padrão): 0.909691
# Elapsed time (NLM): 8.442499 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 33.020891
# SSIM (GEO NLM): 0.832040
# Total Elapsed time (GEONLM): 242.517625 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 35.613026
# SSIM (BM3D): 0.926983
# Total Elapsed time (BM3D): 2.635987 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.08 | q_nlm = 8.12 | h_nlm = 8.79
# [INFO]                 q_geo = 9.27 | h_geo = 10.03
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 32.295314
# SSIM (NLM padrão): 0.870926
# Elapsed time (NLM): 8.405605 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 32.449289
# SSIM (GEO NLM): 0.867474
# Total Elapsed time (GEONLM): 240.555385 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 34.106043
# SSIM (BM3D): 0.900655
# Total Elapsed time (BM3D): 2.552402 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.02 | q_nlm = 8.02 | h_nlm = 8.16
# [INFO]                 q_geo = 9.16 | h_geo = 9.31
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 32.715025
# SSIM (NLM padrão): 0.830115
# Elapsed time (NLM): 8.439868 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 31.994171
# SSIM (GEO NLM): 0.792718
# Total Elapsed time (GEONLM): 241.193207 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 34.620199
# SSIM (BM3D): 0.879676
# Total Elapsed time (BM3D): 2.934734 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.07 | q_nlm = 8.11 | h_nlm = 8.70
# [INFO]                 q_geo = 9.26 | h_geo = 9.93
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 31.254566
# SSIM (NLM padrão): 0.857390
# Elapsed time (NLM): 8.444214 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 31.391851
# SSIM (GEO NLM): 0.855430
# Total Elapsed time (GEONLM): 236.802499 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.565488
# SSIM (BM3D): 0.902261
# Total Elapsed time (BM3D): 2.531698 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.20 | q_nlm = 8.30 | h_nlm = 9.98
# [INFO]                 q_geo = 9.48 | h_geo = 11.40
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 31.529576
# SSIM (NLM padrão): 0.850714
# Elapsed time (NLM): 8.436353 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 31.914466
# SSIM (GEO NLM): 0.867159
# Total Elapsed time (GEONLM): 240.560359 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.572103
# SSIM (BM3D): 0.873596
# Total Elapsed time (BM3D): 2.656802 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.03 | q_nlm = 8.04 | h_nlm = 8.29
# [INFO]                 q_geo = 9.18 | h_geo = 9.46
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 31.365097
# SSIM (NLM padrão): 0.909417
# Elapsed time (NLM): 8.457755 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 31.690726
# SSIM (GEO NLM): 0.899914
# Total Elapsed time (GEONLM): 238.667352 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 34.511957
# SSIM (BM3D): 0.951151
# Total Elapsed time (BM3D): 2.539794 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 2.17 | q_nlm = 9.69 | h_nlm = 21.03
# [INFO]                 q_geo = 11.16 | h_geo = 24.24
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 21.406143
# SSIM (NLM padrão): 0.666853
# Elapsed time (NLM): 8.428237 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 23.717670
# SSIM (GEO NLM): 0.850196
# Total Elapsed time (GEONLM): 239.457148 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 22.897657
# SSIM (BM3D): 0.818726
# Total Elapsed time (BM3D): 3.025977 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.15 | q_nlm = 8.22 | h_nlm = 9.42
# [INFO]                 q_geo = 9.38 | h_geo = 10.75
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 31.284923
# SSIM (NLM padrão): 0.871269
# Elapsed time (NLM): 8.412675 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 31.264705
# SSIM (GEO NLM): 0.845328
# Total Elapsed time (GEONLM): 238.800094 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.781210
# SSIM (BM3D): 0.884747
# Total Elapsed time (BM3D): 3.795248 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.24 | q_nlm = 8.36 | h_nlm = 10.36
# [INFO]                 q_geo = 9.54 | h_geo = 11.83
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 29.547598
# SSIM (NLM padrão): 0.871165
# Elapsed time (NLM): 8.698222 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 30.169782
# SSIM (GEO NLM): 0.902045
# Total Elapsed time (GEONLM): 237.014791 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 30.372347
# SSIM (BM3D): 0.898201
# Total Elapsed time (BM3D): 2.487684 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.39 | q_nlm = 8.58 | h_nlm = 11.89
# [INFO]                 q_geo = 9.80 | h_geo = 13.59
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 28.562615
# SSIM (NLM padrão): 0.822119
# Elapsed time (NLM): 8.400983 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 29.461965
# SSIM (GEO NLM): 0.879002
# Total Elapsed time (GEONLM): 238.950030 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 29.252575
# SSIM (BM3D): 0.860245
# Total Elapsed time (BM3D): 2.567414 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.05 | q_nlm = 8.08 | h_nlm = 8.48
# [INFO]                 q_geo = 9.22 | h_geo = 9.68
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 31.739288
# SSIM (NLM padrão): 0.885679
# Elapsed time (NLM): 8.419824 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 31.430463
# SSIM (GEO NLM): 0.829098
# Total Elapsed time (GEONLM): 239.764480 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 34.380285
# SSIM (BM3D): 0.925093
# Total Elapsed time (BM3D): 2.944258 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.03 | q_nlm = 8.04 | h_nlm = 8.27
# [INFO]                 q_geo = 9.18 | h_geo = 9.44
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 30.015041
# SSIM (NLM padrão): 0.929320
# Elapsed time (NLM): 8.436948 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 29.765207
# SSIM (GEO NLM): 0.875403
# Total Elapsed time (GEONLM): 243.311943 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 32.009656
# SSIM (BM3D): 0.969074
# Total Elapsed time (BM3D): 2.480150 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.08 | q_nlm = 8.12 | h_nlm = 8.78
# [INFO]                 q_geo = 9.27 | h_geo = 10.02
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 31.863143
# SSIM (NLM padrão): 0.876620
# Elapsed time (NLM): 8.387116 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 32.221455
# SSIM (GEO NLM): 0.882079
# Total Elapsed time (GEONLM): 237.013948 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.998598
# SSIM (BM3D): 0.915077
# Total Elapsed time (BM3D): 2.540822 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.18 | q_nlm = 8.28 | h_nlm = 9.79
# [INFO]                 q_geo = 9.45 | h_geo = 11.18
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 32.521069
# SSIM (NLM padrão): 0.918302
# Elapsed time (NLM): 8.409138 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 32.665873
# SSIM (GEO NLM): 0.907870
# Total Elapsed time (GEONLM): 239.055243 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.869346
# SSIM (BM3D): 0.930780
# Total Elapsed time (BM3D): 2.565607 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.26 | q_nlm = 8.39 | h_nlm = 10.57
# [INFO]                 q_geo = 9.58 | h_geo = 12.07
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 29.035204
# SSIM (NLM padrão): 0.839606
# Elapsed time (NLM): 8.474519 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 29.584159
# SSIM (GEO NLM): 0.863654
# Total Elapsed time (GEONLM): 237.981388 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 30.392599
# SSIM (BM3D): 0.860852
# Total Elapsed time (BM3D): 2.530284 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.09 | q_nlm = 8.13 | h_nlm = 8.82
# [INFO]                 q_geo = 9.28 | h_geo = 10.07
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 32.100361
# SSIM (NLM padrão): 0.911028
# Elapsed time (NLM): 8.423984 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 32.440791
# SSIM (GEO NLM): 0.913903
# Total Elapsed time (GEONLM): 241.159157 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 33.681105
# SSIM (BM3D): 0.931542
# Total Elapsed time (BM3D): 2.561496 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 1.15 | q_nlm = 8.22 | h_nlm = 9.43
# [INFO]                 q_geo = 9.38 | h_geo = 10.76
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 30.531486
# SSIM (NLM padrão): 0.908773
# Elapsed time (NLM): 8.457858 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 30.851891
# SSIM (GEO NLM): 0.898602
# Total Elapsed time (GEONLM): 239.994157 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.534180
# SSIM (BM3D): 0.924444
# Total Elapsed time (BM3D): 2.582826 s

# %%
import pandas as pd
import numpy as np

def salvar_resultados_em_xlsx(lista_dicionarios, caminho_arquivo='resultados.xlsx'):
    # Converte os dicionários para DataFrame
    df = pd.DataFrame(lista_dicionarios)
    
    # Converte todos os np.float64 para float padrão do Python
    df = df.applymap(lambda x: float(x) if isinstance(x, np.float64) else x)
    
    # Salva como arquivo Excel
    df.to_excel(caminho_arquivo, index=False)
    print(f'Arquivo salvo em: {caminho_arquivo}')

# %%
# Suponha que você tenha a lista chamada `resultados`
salvar_resultados_em_xlsx(array_dicts, 'saidaPoissonAnscombe.xlsx')
# Out:
# Arquivo salvo em: saidaPoissonAnscombe.xlsx
