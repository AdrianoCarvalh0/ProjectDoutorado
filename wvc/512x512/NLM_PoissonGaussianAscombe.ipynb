# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Dec 15 11:26:44 2019

Implementação do filtro Non-Local Means geodésico

"""
import sys
import warnings
import time
import skimage
import statistics
import networkx as nx
import matplotlib.pyplot as plt
import skimage.io
import skimage.measure
import numpy as np
import sklearn.neighbors as sknn
from scipy.sparse.csgraph import dijkstra
from numpy.matlib import repmat
from scipy.linalg import eigh
from numpy.linalg import inv
from numpy.linalg import cond
from numpy import eye
from sklearn.decomposition import PCA
from skimage.metrics import peak_signal_noise_ratio
from skimage.metrics import structural_similarity
from skimage.transform import rescale, resize, downscale_local_mean
from numba import njit   # just in time compiler (acelera loops)
from joblib import Parallel, delayed
from bm3d import bm3d, BM3DProfile

# Para evitar warning de divisão por zero
warnings.simplefilter(action='ignore')

'''
Espelhamento das bordas da imagem A de maneira simétrica
A função pad do numpy não é supertada pelo numba!
Substitui a função: img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')
f é o parâmetro (largura das bordas)
'''
@njit
def mirror(A, f):
    n = A.shape[0]
    m = A.shape[1]
    nlin = A.shape[0] + 2*f
    ncol = A.shape[1] + 2*f
    # Matriz de saída
    B = np.zeros((nlin, ncol))
    # Preeenche miolo
    B[f:nlin-f, f:ncol-f] = A
    # Preenche cantos
    B[0:f, 0:f] = np.flip(A[0:f, 0:f])                          # 1o quadrante
    B[0:f, ncol-f:ncol] = np.flip(A[0:f, m-f:m])                # 2o quadrante
    B[nlin-f:nlin, 0:f] = np.flip(A[n-f:n, 0:f])                # 3o quadrante
    B[nlin-f:nlin, ncol-f:ncol] = np.flip(A[n-f:n, m-f:m])      # 4o quadrante
    # Preenche bordas
    B[0:f, f:ncol-f] = np.flipud(A[0:f, :])             # cima
    B[nlin-f:nlin, f:ncol-f] = np.flipud(A[n-f:n, :])   # baixo
    B[f:nlin-f, 0:f] = np.fliplr(A[:, 0:f])             # esquerda
    B[f:nlin-f, ncol-f:ncol] = np.fliplr(A[:, m-f:m])   # direita
    return B

'''
Non-Local Means padrão (versão rápida)

Parâmetros:

    img: imagem ruidosa de entrada
    h: parâmetro que controla o grau de suavização (quanto maior, mais suaviza)
    f: tamanho do patch (2f + 1 x 2f + 1) -> se f = 3, então patch é 7 x 7
    t: tamanho da janela de busca (2t + 1 x 2t + 1) -> se t = 10, então janela de busca é 21 x 21

'''
@njit
def NLM_fast(img, h, f, t):
    # Dimenssões espaciais da imagem
    m, n = img.shape
    # Cria imagem de saída
    filtrada = np.zeros((m, n))
    # Problema de valor de contorno: replicar bordas
    img_n = mirror(img, f)
    # Loop principal do NLM
    for i in range(m):
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente
            # Obtém o patch ao redor do pixel corrente
            W1 = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1]
            # Calcula as bordas da janela de busca para o pixel corrente (se pixel próximo das bordas, janela de busca é menor)
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            # Calcula média ponderada
            NL = 0      # valor do pixel corrente filtrado
            Z = 0       # constante normalizadora
            # Loop para todos os pixels da janela de busca
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    W2 = img_n[r-f:(r+f)+1, s-f:(s+f)+1]
                    # Calcula o quadrado da distância Euclidiana
                    d2 = np.sum((W1 - W2)*(W1 - W2))
                    # Calcula a medida de similaridade
                    sij = np.exp(-d2/(h**2))               
                    # Atualiza Z e NL
                    Z = Z + sij
                    NL = NL + sij*img_n[r, s]
            # Normalização do pixel filtrado
            filtrada[i, j] = NL/Z
    return filtrada


'''
Non-Local Means geodésico (versão básica, sem paralelismo e mais lenta)

Parâmetros:

    img: imagem ruidosa de entrada
    h: parâmetro que controla o grau de suavização (quanto maior, mais suaviza)
    f: tamanho do patch (2f + 1 x 2f + 1) -> se f = 3, então patch é 7 x 7
    t: tamanho da janela de busca (2t + 1 x 2t + 1) -> se t = 10, então janela de busca é 21 x 21
    nn: número de vizinhos no grafo KNN

''' 
def GeoNLM(img_noise, h, f, t, nn=10):
    # Dimenssões espaciais da imagem
    m, n = img_noise.shape
    # Cria imagem de saída
    filtrada = np.zeros((m, n))
    # Problema de valor de contorno: replicar bordas
    img_n = np.pad(img_noise, ((f, f), (f, f)), 'symmetric')
    # Loop principal do NLM geodésico
    for i in range(m):
        if i % 10 == 0:
            print(i, end=' ')
            sys.stdout.flush()
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente
            # Obtém o patch ao redor do pixel corrente
            patch_central = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1]
            central = np.reshape(patch_central, [1, patch_central.shape[0]*patch_central.shape[1]])[-1]
            # Calcula as bordas da janela de busca para o pixel corrente
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            # Calcula média ponderada
            NL = 0      # valor do pixel corrente filtrado
            Z = 0       # constante normalizadora
            # Cria dataset com patches da janela de busca como vetores
            num_elem = (rmax - rmin)*(smax - smin)
            tamanho_patch = (2*f + 1)*(2*f + 1)
            dataset = np.zeros((num_elem, tamanho_patch))
            k = 0
            pixels_busca = []
            # Loop para montar o dataset com todos os patches da janela
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    W = img_n[r-f:(r+f)+1, s-f:(s+f)+1] 
                    neighbor = np.reshape(W, [1, W.shape[0]*W.shape[1]])[-1]                    
                    dataset[k, :] = neighbor.copy()
                    if central[0] == neighbor[0]:
                        if (central == neighbor).all():
                            source = k
                    pixels_busca.append(img_n[r, s])
                    k = k + 1
            # Cria grafo knn com patches da janela de busca
            knnGraph = sknn.kneighbors_graph(dataset, n_neighbors=nn, mode='distance')
            A = knnGraph.toarray()
            # Converte matriz de adjacências para grafo
            G = nx.from_numpy_array(A)                      
            # Aplica algoritmo de Dijkstra
            length, path = nx.single_source_dijkstra(G, source)
            points = np.array(list(length.keys()))
            distancias = np.array(list(length.values()))
            # Calcula similaridades
            similaridades = np.exp(-distancias**2/(h**2))
            pixels = np.zeros(len(points))
            pixels_busca = np.array(pixels_busca)
            pixels = pixels_busca[points]
            # Normalização do pixel filtrado
            NL = sum(similaridades*pixels)
            Z = sum(similaridades)
            filtrada[i, j] = NL/Z
    return filtrada


######################################################
# Função auxiliar para paralelizar o GEONLM
######################################################
def process_pixel(i, j, img_n, f, t, h, nn):
    im = i + f
    jn = j + f
    patch_central = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1]
    central = np.reshape(patch_central, [1, patch_central.shape[0]*patch_central.shape[1]])[-1]
    rmin = max(im-t, f)
    rmax = min(im+t, m+f)
    smin = max(jn-t, f)
    smax = min(jn+t, n+f)
    NL, Z = 0, 0
    dataset = np.zeros(((rmax - rmin)*(smax - smin), (2*f + 1)*(2*f + 1)))
    k = 0
    pixels_busca = []
    for r in range(rmin, rmax):
        for s in range(smin, smax):
            W = img_n[r-f:(r+f)+1, s-f:(s+f)+1]
            neighbor = np.reshape(W, [1, W.shape[0]*W.shape[1]])[-1]
            dataset[k, :] = neighbor.copy()
            if central[0] == neighbor[0] and (central == neighbor).all():
                source = k
            pixels_busca.append(img_n[r, s])
            k += 1
    knnGraph = sknn.kneighbors_graph(dataset, n_neighbors=nn, mode='distance')
    A = knnGraph.toarray()
    G = nx.from_numpy_array(A)
    length, path = nx.single_source_dijkstra(G, source)
    points = np.array(list(length.keys()))
    distancias = np.array(list(length.values()))
    similaridades = np.exp(-distancias**2 / (h**2))
    pixels_busca = np.array(pixels_busca)
    pixels = pixels_busca[points]
    NL = sum(similaridades * pixels)
    Z = sum(similaridades)
    return NL / Z

##################################################
# GEONLM paralelo 
##################################################
def Parallel_GEONLM(img_n, f, t, h, nn):
    # Parallelize the loop
    print(f'img_n.shape: {img_n.shape}')
    m = img_n.shape[0] - 2*f
    print(f'M: {m}')
    n = img_n.shape[1] - 2*f
    print(f'N: {n}')
    filtrada = Parallel(n_jobs=-1)(delayed(process_pixel)(i, j, img_n, f, t, h, nn) for i in range(m) for j in range(n))
    #print(f"filtrada Shape: {filtrada.shape}")
    
    filtrada_geo = np.array(filtrada).reshape((m, n))
    #print(f'filtrada_geo.shape: {filtrada_geo.shape}')
    return filtrada_geo

####################################################################
'''
Função que extrai os patches de cada janela de busca no GeoNLM
Retorna uma matriz 4D (m, n, 2t+1 x 2t+1, 2f+1 x 2f+1)

Usa o JIT (just in time) compiler para acelerar loops

'''
####################################################################
@njit
def Extract_patches(img, f, t):
    # Dimenssões espaciais da imagem
    m, n = img.shape
    # Tamanhos do patch e da janela de busca
    tamanho_patch = (2*f + 1)*(2*f + 1)    
    # Patches para cada janela de busca
    patches = []
    centros = []    
    # Problema de valor de contorno: replicar bordas
    img_n = mirror(img, f)
    # Loop principal do NLM geodésico
    for i in range(m):        
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente
            # Obtém o patch ao redor do pixel corrente
            patch_central = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1].copy()
            central = patch_central.reshape((1, patch_central.shape[0]*patch_central.shape[1]))[-1]
            # Calcula as bordas da janela de busca para o pixel corrente
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            num_elem = (rmax - rmin)*(smax - smin)
            # Cria dataset
            dataset = np.zeros((num_elem, tamanho_patch))
            # Loop para montar o dataset com todos os patches da janela
            k = 0
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    W = img_n[r-f:(r+f)+1, s-f:(s+f)+1].copy() 
                    neighbor = W.reshape((1, W.shape[0]*W.shape[1]))[-1]
                    dataset[k, :] = neighbor.copy()
                    if (central == neighbor).all():
                        source = k
                    k = k + 1
            patches.append(dataset)
            centros.append(source)
    return patches, centros

###################################################################
'''
Função que extrai os patches de cada janela de busca no GeoNLM
Retorna uma lista 
'''
###################################################################
def Geodesic_distances(patches, centros, nn=10):
    distancias_geodesicas = []
    pontos = []
    # Percorre a lista de patches
    for i in range(len(patches)):
    # Cria grafo knn com patches da janela de busca
        knnGraph = sknn.kneighbors_graph(patches[i], n_neighbors=nn, mode='distance')
        A = knnGraph.toarray()        
        G = nx.from_numpy_array(A)      # Converte matriz de adjacências para grafo
        # Aplica algoritmo de Dijkstra
        length, path = nx.single_source_dijkstra(G, centros[i])
        points = np.array(list(length.keys()))
        pontos.append(points)
        geodists = np.array(list(length.values()))        
        distancias_geodesicas.append(geodists)
    return distancias_geodesicas, pontos

##################################################################################################
'''
Non-Local Means geodésico (versão com compilador JIT para acelerar loops)

Parâmetros:

    img: imagem ruidosa de entrada
    h: parâmetro que controla o grau de suavização (quanto maior, mais suaviza)
    f: tamanho do patch (2f + 1 x 2f + 1) -> se f = 3, então patch é 7 x 7
    t: tamanho da janela de busca (2t + 1 x 2t + 1) -> se t = 10, então janela de busca é 21 x 21
    nn: número de vizinhos no grafo KNN

''' 
###################################################################################################
@njit
def GeoNLM_fast(img, h, f, t, distancias_geodesicas, pontos):
    # Dimenssões espaciais da imagem
    m, n = img.shape
    # Cria imagem de saída
    filtrada = np.zeros((m, n))
    # Problema de valor de contorno: replicar bordas
    #img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')
    img_n = mirror(img, f)
    # Loop principal do NLM geodésico
    k = 0
    for i in range(m):
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente    
            # Calcula as bordas da janela de busca para o pixel corrente
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            # Calcula média ponderada
            NL = 0      # valor do pixel corrente filtrado
            Z = 0       # constante normalizadora            
            pixels_busca = []
            # Loop para montar o dataset com todos os patches da janela
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    pixels_busca.append(img_n[r, s])
            # Calcula similaridades
            similaridades = np.exp(-distancias_geodesicas[k]**2/(h**2))
            pixels = np.zeros(len(pontos[k]))
            pixels_busca = np.array(pixels_busca)
            pixels = pixels_busca[pontos[k]]
            # Normalização do pixel filtrado
            NL = sum(similaridades*pixels)
            Z = sum(similaridades)
            filtrada[i, j] = NL/Z
            k = k + 1
    return filtrada

#########################################################################
'''
Realiza a filtragem da imagem com o filtro NLM geodésico 

Usa o compilador JIT para acelerar loops
'''
#########################################################################
def GeoNLM_filter(img_noise, h, f, t, nn=10):
    # Fase 1
    print('Início da extração dos patches')
    inicio = time.time()
    patches, centros = Extract_patches(img_noise, f, t)
    fim = time.time()
    print('Elapsed time: %f ' %(fim - inicio))
    print()
    # Fase 2
    print('Início do cálculo das distâncias')
    inicio = time.time()
    distancias_geodesicas, pontos = Geodesic_distances(patches, centros, nn)
    fim = time.time()
    print('Elapsed time: %f ' %(fim - inicio))
    print()
    # Fase 3
    print('Início da filtragem')
    inicio = time.time()
    filtrada = GeoNLM_fast(img_noise, h, f, t, distancias_geodesicas, pontos)
    fim = time.time()
    print('Elapsed time: %f ' %(fim - inicio))
    return filtrada

# %%
import os
import math

def read_directories(directory, img=None, exclude_json=None):
    # Get a list of filenames in the specified directory
    filenames = []
    for filename in os.listdir(directory):
        if img is not None:
            # If 'img' is provided, filter filenames containing it
            if img in filename:   
                filenames.append(filename)
        elif exclude_json is not None:
            filenames.append(filename.replace('.json',''))     
        else:
            filenames.append(filename)    
    return filenames


def add_poisson_noise(img):
    """
    Aplica ruído de Poisson corretamente sem overflow.

    Parâmetros:
        img (np.ndarray): Imagem com valores em [0,255] ou [0,1].

    Retorna:
        np.ndarray: imagem ruidosa, clipada para [0, 255], dtype uint8.
    """
    # Se estiver em [0, 1], escala para 0-255
    if img.max() <= 1.0:
        img = (img * 255).astype(np.float32)
    else:
        img = img.astype(np.float32)

    # Garante que os valores Poisson não causem overflow
    poisson_img = np.random.poisson(img).astype(np.float32)
    poisson_img = np.clip(poisson_img, 0, 255)

    return poisson_img.astype(np.uint8)

def anscombe_transform(img):
    return 2.0 * np.sqrt(img.astype(np.float32) + 3.0 / 8.0)

def inverse_anscombe(transf_img):
    return np.clip((transf_img / 2.0) ** 2 - 3.0 / 8.0, 0, 255)

def compute_adaptive_q(sigma_est):
    q_nlm = 0.8 + 0.5 * math.tanh(0.3 * (sigma_est - 1))
    q_geo = 1.0 + 0.7 * math.tanh(0.25 * (sigma_est - 1.5))

    q_nlm = np.clip(q_nlm, 0.7, 2.2) * 10
    q_geo = np.clip(q_geo, 0.9, 2.7) * 10

    return q_nlm, q_geo

def add_poisson_gaussian_noise(image, gaussian_sigma=25):
    """
    Adds Poisson noise followed by Gaussian noise to an image.

    Parameters:
        image (np.ndarray): Input image (grayscale or RGB), values in [0, 1] or [0, 255].
        gaussian_sigma (float): Standard deviation of the Gaussian noise (in intensity scale 0–255).

    Returns:
        np.ndarray: Noisy image (clipped to [0, 255] and converted to uint8).
    """
    # Convert to float32 and normalize to [0, 255] if necessary
    if image.dtype != np.float32:
        image = image.astype(np.float32)

    if image.max() <= 1.0:
        image *= 255.0

    # Apply Poisson noise
    poisson_image = np.random.poisson(image).astype(np.float32)

    # Apply Gaussian noise
    gaussian_noise = np.random.normal(loc=0.0, scale=gaussian_sigma, size=image.shape)
    noisy_image = poisson_image + gaussian_noise

    # Clip values and convert to uint8
    noisy_image = np.clip(noisy_image, 0, 255).astype(np.uint8)

    return noisy_image

# %%
from pathlib import Path
from skimage.restoration import estimate_sigma

sys.path.insert(0, r"c:\Users\adria\Documents\Doutorado\ProjetoDoutorado")
root_dir = Path(r"c:\Users\adria\Documents\Doutorado\ProjetoDoutorado")



dir_images = f'{root_dir}/wvc/images'
dir_out_nlm = f'{root_dir}/wvc/512x512/Anscombe/out_put_NLM_PoissonGaussian'
dir_out_geonlm = f'{root_dir}/wvc/512x512/Anscombe/out_put_GEONLM_PoissonGaussian'
dir_out_bm3d = f'{root_dir}/wvc/512x512/Anscombe/out_put_BM3D_PoissonGaussian'

array_dir = read_directories(dir_images)

array_dicts = []

for file in array_dir:

    file_name = file
    img = skimage.io.imread(f'{dir_images}/{file_name}')
    # Em arquivos de formato GIF precisa desse comando
    img = img[0, :, :]

    # Checa se imagem é monocromática
    if len(img.shape) > 2:
        img = skimage.color.rgb2gray(img)   # valores convertidos ficam entre 0 e 1
        img = 255*img

    # Reescala imagem para (256, 256) - diminuir o tempo de execução
    #img = downscale_local_mean(img, (2, 2))

    img = img.astype(np.uint8)              # Converte para uint8    
    m, n = img.shape

    print('Num. linhas = %d' %m)
    print('Num. colunas = %d' %n)
    print()

    # Cria imagem ruidosa
    ruidosa = add_poisson_gaussian_noise(img)

    # Clipa imagem para intervalo [0, 255]
    ruidosa[np.where(ruidosa > 255)] = 255
    ruidosa[np.where(ruidosa < 0)] = 0
    #ruidosa = ruidosa.astype(np.float32)

    # Listas para métricas


    # Define parâmetros do filtro NLM
    f = 4   # tamanho do patch (2f + 1 x 2f + 1) -> 5 x 5
    t = 7   # tamanho da janela de busca (2t + 1 x 2t + 1) -> 21 x 21
    h_nlm = 16 # parâmetro que controla a suavização no NLM (depende da imagem)
    h_geo = 21 # parâmetro que controla a suavização no GEONLM (depende da imagem)
    nn = 10     # número de vizinhos no grafo k-NN

    # Cria imagem de saída
    filtrada = np.zeros((m, n))

    # Problema de valor de contorno: replicar bordas
    img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')

 
    inicio = time.time()
    #ruidosa_asc = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')      # para versão paralela, precisa espelhar imagem fora da função


    ruidosa_anscombe = anscombe_transform(ruidosa)
    #print(f'ruidosa_asc_nlm.shape: {ruidosa_anscombe.shape}')
    sigma_est = estimate_sigma(ruidosa_anscombe)
    q_nlm, q_geo = compute_adaptive_q(sigma_est)
    h_nlm = q_nlm * sigma_est #* 10
    h_geo = q_geo * sigma_est #* 10

    print('***********************************')
    print('*         Parâmetro H             *')
    print('***********************************')
    print(f"[INFO] σ estimado: {sigma_est:.2f} | q_nlm = {q_nlm:.2f} | h_nlm = {h_nlm:.2f}")
    print(f"[INFO]                 q_geo = {q_geo:.2f} | h_geo = {h_geo:.2f}")
    

    ###################################################
    # Filtra com NLM padrão
    ###################################################
    print('***********************************')
    print('*            NLM                  *')
    print('***********************************')
    print()
    filtrada_asc = NLM_fast(ruidosa_anscombe, h_nlm, f, t)
    print(f'filtrada_asc.shape: {filtrada_asc.shape}')
    filtrada_padrao = inverse_anscombe(filtrada_asc).astype(np.uint8)
    print(f'filtrada_padrao.shape: {filtrada_padrao.shape}')

    fim = time.time()    
    # Calcula PSNR
    p1_nlm = peak_signal_noise_ratio(img, filtrada_padrao.astype(np.uint8))
   
    print('PSNR (NLM padrão): %f' %p1_nlm)
    # Calcula SSIM
    s1_nlm = structural_similarity(img, filtrada_padrao.astype(np.uint8))
  
    print('SSIM (NLM padrão): %f' %s1_nlm)
    print('Elapsed time (NLM): %f s' %(fim - inicio))
    print()
    time_nlm = fim - inicio
    # Salva arquivo
    skimage.io.imsave(f'{dir_out_nlm}/{file_name}', filtrada_padrao.astype(np.uint8))

    ###################################################
    # Filtra com NLM geodésico
    ###################################################
    print('***********************************')
    print('*            GEONLM               *')
    print('***********************************')
    print()
    ini = time.time()

    ##3 Versão com JIT compiler
    #filtrada_geo = GeoNLM_filter(ruidosa, h_geo, f, t, nn)   # versão com JIT compiler (não ficou mais rápido pois o Dijkstra não acelera. Ainda está lento...)

    ### Versão com paralelismo (ficou mais rápida)
    img_n_geo = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')      # para versão paralela, precisa espelhar imagem fora da função

    ruidosa_asc_geo = anscombe_transform(img_n_geo)
    filtrada_geo_asc = Parallel_GEONLM(ruidosa_asc_geo, f, t, h_geo, nn)

    filtrada_geo = inverse_anscombe(filtrada_geo_asc).astype(np.uint8)

    end = time.time()
    # Calcula PSNR
    p2_gnlm = peak_signal_noise_ratio(img, filtrada_geo.astype(np.uint8))    
    print('\nPSNR (GEO NLM): %f' %p2_gnlm)
    # Calcula SSIM
    s2_gnlm = structural_similarity(img, filtrada_geo.astype(np.uint8))
   
    print('SSIM (GEO NLM): %f' %s2_gnlm)
    print('Total Elapsed time (GEONLM): %f s' %(end - ini))

    time_geonlm = end - ini
    print()
    # Salva arquivo    
    skimage.io.imsave(f'{dir_out_geonlm}/{file_name}', filtrada_geo.astype(np.uint8))
    
    print('***********************************')
    print('*            BM3D                 *')
    print('***********************************')
    print()


    ini = time.time()

    # 1. Normaliza a imagem ruidosa para intervalo [0, 1]
    #ruidosa_normalizada = ruidosa.astype(np.float32) / 255.0

    #ruidosa_asc_bm3d = anscombe_transform(ruidosa_normalizada)

    #sigma_est = estimate_sigma(ruidosa_asc_bm3d, channel_axis=None)

    # 3. Define o perfil padrão do BM3D
    perfil_bm3d = BM3DProfile()

    # 4. Aplica o BM3D com os argumentos definidos
    denoised = bm3d(
        ruidosa_anscombe,
        sigma_psd=sigma_est,
        profile=perfil_bm3d
    )
    denoised_sq = np.squeeze(denoised)

    filtrada_bm3d = inverse_anscombe(denoised_sq).astype(np.uint8)

    end = time.time()

    time_bm3d = end - ini

    skimage.io.imsave(f'{dir_out_bm3d}/{file_name}', np.clip(filtrada_bm3d, 0, 255).astype(np.uint8))

    p3_bm3d = peak_signal_noise_ratio(img, filtrada_bm3d.astype(np.uint8))
    print('\nPSNR (BM3D): %f' %p3_bm3d)
    s3_bm3d = structural_similarity(img, filtrada_bm3d.astype(np.uint8))
    print('SSIM (BM3D): %f' %s3_bm3d)
    print('Total Elapsed time (BM3D): %f s' %(time_bm3d))

    dict = {
        's1_NLM': s1_nlm,        
        's2_GNLM': s2_gnlm,
        's3_BM3D': s3_bm3d,
        'p1_NLM': p1_nlm,
        'p2_GLM': p2_gnlm,
        'p3_GLM': p3_bm3d,
        'time_nlm':time_nlm,
        'time_geonlm':time_geonlm,
        'time_bm3d':time_bm3d,
        'h_nlm':h_nlm,
        'h_geo':h_geo,
        'sigma':sigma_est,
        'image': file_name   
    }
    array_dicts.append(dict)
# Out:
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 2.60 | q_nlm = 10.23 | h_nlm = 26.55
# [INFO]                 q_geo = 11.87 | h_geo = 30.82
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 28.462626
# SSIM (NLM padrão): 0.781450
# Elapsed time (NLM): 18.212591 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 27.317934
# SSIM (GEO NLM): 0.665333
# Total Elapsed time (GEONLM): 260.100140 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 29.208339
# SSIM (BM3D): 0.808469
# Total Elapsed time (BM3D): 3.212235 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 2.80 | q_nlm = 10.47 | h_nlm = 29.36
# [INFO]                 q_geo = 12.20 | h_geo = 34.22
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 26.028075
# SSIM (NLM padrão): 0.728526
# Elapsed time (NLM): 8.486670 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 26.851770
# SSIM (GEO NLM): 0.728140
# Total Elapsed time (GEONLM): 258.480680 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 27.978637
# SSIM (BM3D): 0.797560
# Total Elapsed time (BM3D): 3.040815 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 2.12 | q_nlm = 9.62 | h_nlm = 20.36
# [INFO]                 q_geo = 11.07 | h_geo = 23.44
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 27.681199
# SSIM (NLM padrão): 0.807225
# Elapsed time (NLM): 8.941109 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 26.776042
# SSIM (GEO NLM): 0.629032
# Total Elapsed time (GEONLM): 262.024104 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 29.723470
# SSIM (BM3D): 0.860963
# Total Elapsed time (BM3D): 2.662448 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 2.02 | q_nlm = 9.48 | h_nlm = 19.13
# [INFO]                 q_geo = 10.90 | h_geo = 22.00
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 23.584497
# SSIM (NLM padrão): 0.760603
# Elapsed time (NLM): 8.390580 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 23.826194
# SSIM (GEO NLM): 0.746487
# Total Elapsed time (GEONLM): 239.653264 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 25.429534
# SSIM (BM3D): 0.812661
# Total Elapsed time (BM3D): 2.316262 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 3.32 | q_nlm = 11.01 | h_nlm = 36.57
# [INFO]                 q_geo = 12.98 | h_geo = 43.12
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 25.417595
# SSIM (NLM padrão): 0.645404
# Elapsed time (NLM): 8.128903 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 26.575350
# SSIM (GEO NLM): 0.679769
# Total Elapsed time (GEONLM): 241.578341 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 27.266473
# SSIM (BM3D): 0.730320
# Total Elapsed time (BM3D): 2.340662 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 2.29 | q_nlm = 9.84 | h_nlm = 22.51
# [INFO]                 q_geo = 11.36 | h_geo = 25.99
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 25.889733
# SSIM (NLM padrão): 0.730426
# Elapsed time (NLM): 8.100972 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 26.046982
# SSIM (GEO NLM): 0.673878
# Total Elapsed time (GEONLM): 239.532109 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 28.038134
# SSIM (BM3D): 0.831470
# Total Elapsed time (BM3D): 2.414331 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 3.26 | q_nlm = 10.95 | h_nlm = 35.75
# [INFO]                 q_geo = 12.90 | h_geo = 42.10
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 21.173761
# SSIM (NLM padrão): 0.507026
# Elapsed time (NLM): 8.084202 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 22.864501
# SSIM (GEO NLM): 0.680409
# Total Elapsed time (GEONLM): 266.647541 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 23.493300
# SSIM (BM3D): 0.719603
# Total Elapsed time (BM3D): 4.084874 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 3.38 | q_nlm = 11.07 | h_nlm = 37.44
# [INFO]                 q_geo = 13.07 | h_geo = 44.21
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 22.471064
# SSIM (NLM padrão): 0.547571
# Elapsed time (NLM): 9.628042 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 24.270658
# SSIM (GEO NLM): 0.641095
# Total Elapsed time (GEONLM): 252.175611 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 25.104485
# SSIM (BM3D): 0.723621
# Total Elapsed time (BM3D): 3.464904 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 3.60 | q_nlm = 11.26 | h_nlm = 40.49
# [INFO]                 q_geo = 13.37 | h_geo = 48.06
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 21.615106
# SSIM (NLM padrão): 0.422283
# Elapsed time (NLM): 9.003698 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 23.240996
# SSIM (GEO NLM): 0.600845
# Total Elapsed time (GEONLM): 250.697190 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 23.705279
# SSIM (BM3D): 0.625487
# Total Elapsed time (BM3D): 4.990737 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 3.48 | q_nlm = 11.16 | h_nlm = 38.88
# [INFO]                 q_geo = 13.21 | h_geo = 46.03
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 21.356699
# SSIM (NLM padrão): 0.553153
# Elapsed time (NLM): 9.203587 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 23.819086
# SSIM (GEO NLM): 0.681474
# Total Elapsed time (GEONLM): 247.672700 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 24.792835
# SSIM (BM3D): 0.736648
# Total Elapsed time (BM3D): 3.070498 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 3.83 | q_nlm = 11.45 | h_nlm = 43.79
# [INFO]                 q_geo = 13.67 | h_geo = 52.27
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 20.741375
# SSIM (NLM padrão): 0.532963
# Elapsed time (NLM): 8.512225 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 22.750069
# SSIM (GEO NLM): 0.666144
# Total Elapsed time (GEONLM): 247.611091 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 23.765485
# SSIM (BM3D): 0.731375
# Total Elapsed time (BM3D): 3.305934 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 3.68 | q_nlm = 11.33 | h_nlm = 41.65
# [INFO]                 q_geo = 13.47 | h_geo = 49.54
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 24.334047
# SSIM (NLM padrão): 0.657745
# Elapsed time (NLM): 8.730335 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 26.493236
# SSIM (GEO NLM): 0.719265
# Total Elapsed time (GEONLM): 244.583893 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 27.531798
# SSIM (BM3D): 0.784557
# Total Elapsed time (BM3D): 3.181028 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 2.75 | q_nlm = 10.41 | h_nlm = 28.63
# [INFO]                 q_geo = 12.12 | h_geo = 33.34
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 26.337373
# SSIM (NLM padrão): 0.624184
# Elapsed time (NLM): 8.518792 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 26.471507
# SSIM (GEO NLM): 0.635089
# Total Elapsed time (GEONLM): 247.202288 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 27.951906
# SSIM (BM3D): 0.728408
# Total Elapsed time (BM3D): 2.810887 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 3.27 | q_nlm = 10.96 | h_nlm = 35.89
# [INFO]                 q_geo = 12.92 | h_geo = 42.28
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 24.012039
# SSIM (NLM padrão): 0.568586
# Elapsed time (NLM): 8.405906 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 25.175676
# SSIM (GEO NLM): 0.678415
# Total Elapsed time (GEONLM): 246.446369 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 25.876748
# SSIM (BM3D): 0.731856
# Total Elapsed time (BM3D): 2.914586 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 3.17 | q_nlm = 10.86 | h_nlm = 34.47
# [INFO]                 q_geo = 12.77 | h_geo = 40.50
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 26.159032
# SSIM (NLM padrão): 0.654331
# Elapsed time (NLM): 8.433568 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 26.613410
# SSIM (GEO NLM): 0.610324
# Total Elapsed time (GEONLM): 247.316410 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 28.012350
# SSIM (BM3D): 0.719963
# Total Elapsed time (BM3D): 2.680841 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 2.94 | q_nlm = 10.62 | h_nlm = 31.24
# [INFO]                 q_geo = 12.42 | h_geo = 36.52
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 23.778205
# SSIM (NLM padrão): 0.643313
# Elapsed time (NLM): 8.452136 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 24.958467
# SSIM (GEO NLM): 0.628563
# Total Elapsed time (GEONLM): 248.340099 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 25.616739
# SSIM (BM3D): 0.721379
# Total Elapsed time (BM3D): 3.047457 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 3.26 | q_nlm = 10.95 | h_nlm = 35.71
# [INFO]                 q_geo = 12.90 | h_geo = 42.05
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 28.143548
# SSIM (NLM padrão): 0.766473
# Elapsed time (NLM): 8.398959 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 28.205276
# SSIM (GEO NLM): 0.608302
# Total Elapsed time (GEONLM): 247.951454 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 30.663530
# SSIM (BM3D): 0.795082
# Total Elapsed time (BM3D): 3.076031 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 3.13 | q_nlm = 10.82 | h_nlm = 33.83
# [INFO]                 q_geo = 12.70 | h_geo = 39.72
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 27.408567
# SSIM (NLM padrão): 0.699945
# Elapsed time (NLM): 8.392411 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 27.730245
# SSIM (GEO NLM): 0.647227
# Total Elapsed time (GEONLM): 247.492501 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 28.913374
# SSIM (BM3D): 0.766483
# Total Elapsed time (BM3D): 3.082419 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 3.18 | q_nlm = 10.88 | h_nlm = 34.64
# [INFO]                 q_geo = 12.79 | h_geo = 40.72
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 29.426790
# SSIM (NLM padrão): 0.762320
# Elapsed time (NLM): 8.397652 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 29.098071
# SSIM (GEO NLM): 0.661914
# Total Elapsed time (GEONLM): 248.933339 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 31.252175
# SSIM (BM3D): 0.828494
# Total Elapsed time (BM3D): 2.721366 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 3.05 | q_nlm = 10.74 | h_nlm = 32.78
# [INFO]                 q_geo = 12.59 | h_geo = 38.42
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 27.477457
# SSIM (NLM padrão): 0.662579
# Elapsed time (NLM): 8.490184 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 27.462647
# SSIM (GEO NLM): 0.617237
# Total Elapsed time (GEONLM): 248.373185 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 29.064144
# SSIM (BM3D): 0.748446
# Total Elapsed time (BM3D): 3.022263 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 3.46 | q_nlm = 11.14 | h_nlm = 38.59
# [INFO]                 q_geo = 13.18 | h_geo = 45.66
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 27.645191
# SSIM (NLM padrão): 0.786787
# Elapsed time (NLM): 8.626115 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 27.892398
# SSIM (GEO NLM): 0.645222
# Total Elapsed time (GEONLM): 247.653615 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 29.521878
# SSIM (BM3D): 0.770870
# Total Elapsed time (BM3D): 2.780799 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 3.05 | q_nlm = 10.73 | h_nlm = 32.70
# [INFO]                 q_geo = 12.58 | h_geo = 38.32
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 27.479205
# SSIM (NLM padrão): 0.694742
# Elapsed time (NLM): 8.630286 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 27.204797
# SSIM (GEO NLM): 0.647628
# Total Elapsed time (GEONLM): 248.431016 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 28.484579
# SSIM (BM3D): 0.749428
# Total Elapsed time (BM3D): 2.711315 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 3.80 | q_nlm = 11.43 | h_nlm = 43.43
# [INFO]                 q_geo = 13.63 | h_geo = 51.81
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 21.381165
# SSIM (NLM padrão): 0.377536
# Elapsed time (NLM): 8.388165 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 23.580203
# SSIM (GEO NLM): 0.602395
# Total Elapsed time (GEONLM): 245.647904 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 24.231586
# SSIM (BM3D): 0.645502
# Total Elapsed time (BM3D): 3.851619 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 3.47 | q_nlm = 11.15 | h_nlm = 38.75
# [INFO]                 q_geo = 13.20 | h_geo = 45.86
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 26.143490
# SSIM (NLM padrão): 0.690319
# Elapsed time (NLM): 8.540814 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 27.400295
# SSIM (GEO NLM): 0.676647
# Total Elapsed time (GEONLM): 247.571114 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 28.824833
# SSIM (BM3D): 0.790233
# Total Elapsed time (BM3D): 2.488689 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 3.35 | q_nlm = 11.04 | h_nlm = 37.03
# [INFO]                 q_geo = 13.03 | h_geo = 43.71
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 24.018934
# SSIM (NLM padrão): 0.553500
# Elapsed time (NLM): 8.426751 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 25.604876
# SSIM (GEO NLM): 0.616104
# Total Elapsed time (GEONLM): 246.114809 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 26.466844
# SSIM (BM3D): 0.675715
# Total Elapsed time (BM3D): 2.535003 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 4.19 | q_nlm = 11.72 | h_nlm = 49.13
# [INFO]                 q_geo = 14.11 | h_geo = 59.17
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 18.983925
# SSIM (NLM padrão): 0.398659
# Elapsed time (NLM): 8.386408 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 21.098769
# SSIM (GEO NLM): 0.596692
# Total Elapsed time (GEONLM): 245.988216 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 21.629730
# SSIM (BM3D): 0.625771
# Total Elapsed time (BM3D): 3.018438 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 3.11 | q_nlm = 10.80 | h_nlm = 33.58
# [INFO]                 q_geo = 12.67 | h_geo = 39.40
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 24.599126
# SSIM (NLM padrão): 0.555819
# Elapsed time (NLM): 8.416582 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 25.622241
# SSIM (GEO NLM): 0.619674
# Total Elapsed time (GEONLM): 246.016629 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 26.028040
# SSIM (BM3D): 0.634449
# Total Elapsed time (BM3D): 2.803707 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 3.14 | q_nlm = 10.83 | h_nlm = 33.96
# [INFO]                 q_geo = 12.71 | h_geo = 39.88
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 24.843996
# SSIM (NLM padrão): 0.570275
# Elapsed time (NLM): 8.410448 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 25.852861
# SSIM (GEO NLM): 0.604252
# Total Elapsed time (GEONLM): 246.583482 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 26.765770
# SSIM (BM3D): 0.684088
# Total Elapsed time (BM3D): 2.481519 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 3.32 | q_nlm = 11.01 | h_nlm = 36.50
# [INFO]                 q_geo = 12.98 | h_geo = 43.04
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 23.504870
# SSIM (NLM padrão): 0.540598
# Elapsed time (NLM): 8.375283 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 25.025244
# SSIM (GEO NLM): 0.652085
# Total Elapsed time (GEONLM): 245.047767 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 25.823068
# SSIM (BM3D): 0.707241
# Total Elapsed time (BM3D): 2.720937 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 2.71 | q_nlm = 10.36 | h_nlm = 28.12
# [INFO]                 q_geo = 12.06 | h_geo = 32.72
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 26.855186
# SSIM (NLM padrão): 0.728403
# Elapsed time (NLM): 8.403496 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 26.931961
# SSIM (GEO NLM): 0.675605
# Total Elapsed time (GEONLM): 246.443166 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 28.531417
# SSIM (BM3D): 0.783411
# Total Elapsed time (BM3D): 2.476908 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 3.67 | q_nlm = 11.32 | h_nlm = 41.53
# [INFO]                 q_geo = 13.46 | h_geo = 49.38
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 23.062400
# SSIM (NLM padrão): 0.549572
# Elapsed time (NLM): 8.387722 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 25.611822
# SSIM (GEO NLM): 0.703529
# Total Elapsed time (GEONLM): 243.932244 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 26.540424
# SSIM (BM3D): 0.767030
# Total Elapsed time (BM3D): 2.470587 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 3.21 | q_nlm = 10.90 | h_nlm = 34.95
# [INFO]                 q_geo = 12.82 | h_geo = 41.10
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 25.202774
# SSIM (NLM padrão): 0.482436
# Elapsed time (NLM): 8.388721 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 25.747580
# SSIM (GEO NLM): 0.551368
# Total Elapsed time (GEONLM): 247.844470 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 26.508658
# SSIM (BM3D): 0.605571
# Total Elapsed time (BM3D): 2.879797 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 2.81 | q_nlm = 10.47 | h_nlm = 29.40
# [INFO]                 q_geo = 12.21 | h_geo = 34.28
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 26.756090
# SSIM (NLM padrão): 0.679294
# Elapsed time (NLM): 8.427110 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 26.757904
# SSIM (GEO NLM): 0.660867
# Total Elapsed time (GEONLM): 246.588609 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 28.233867
# SSIM (BM3D): 0.772019
# Total Elapsed time (BM3D): 2.650958 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 2.87 | q_nlm = 10.55 | h_nlm = 30.31
# [INFO]                 q_geo = 12.31 | h_geo = 35.38
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 28.772116
# SSIM (NLM padrão): 0.765040
# Elapsed time (NLM): 8.422798 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 27.383624
# SSIM (GEO NLM): 0.631944
# Total Elapsed time (GEONLM): 247.950255 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 29.291073
# SSIM (BM3D): 0.763982
# Total Elapsed time (BM3D): 2.696712 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 3.13 | q_nlm = 10.82 | h_nlm = 33.87
# [INFO]                 q_geo = 12.70 | h_geo = 39.77
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 26.181578
# SSIM (NLM padrão): 0.601771
# Elapsed time (NLM): 8.387764 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512
#
# PSNR (GEO NLM): 26.822718
# SSIM (GEO NLM): 0.620056
# Total Elapsed time (GEONLM): 248.085551 s
#
# ***********************************
# *            BM3D                 *
# ***********************************
#
#
# PSNR (BM3D): 28.220000
# SSIM (BM3D): 0.735266
# Total Elapsed time (BM3D): 2.848673 s
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *         Parâmetro H             *
# ***********************************
# [INFO] σ estimado: 2.51 | q_nlm = 10.12 | h_nlm = 25.43
# [INFO]                 q_geo = 11.73 | h_geo = 29.48
# ***********************************
# *            NLM                  *
# ***********************************
#
# filtrada_asc.shape: (512, 512)
# filtrada_padrao.shape: (512, 512)
# PSNR (NLM padrão): 28.603181
# SSIM (NLM padrão): 0.678951
# Elapsed time (NLM): 8.365900 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
# img_n.shape: (520, 520)
# M: 512
# N: 512

# %%
import pandas as pd
import numpy as np

def salvar_resultados_em_xlsx(lista_dicionarios, caminho_arquivo='resultados.xlsx'):
    # Converte os dicionários para DataFrame
    df = pd.DataFrame(lista_dicionarios)
    
    # Converte todos os np.float64 para float padrão do Python
    df = df.applymap(lambda x: float(x) if isinstance(x, np.float64) else x)
    
    # Salva como arquivo Excel
    df.to_excel(caminho_arquivo, index=False)
    print(f'Arquivo salvo em: {caminho_arquivo}')

# %%
# Suponha que você tenha a lista chamada `resultados`
salvar_resultados_em_xlsx(array_dicts, 'saidaPoissonGaussianAnscombe.xlsx')
# Out:
# Arquivo salvo em: saidaPoissonGaussianAnscombe.xlsx
