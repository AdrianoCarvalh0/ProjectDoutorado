# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Dec 15 11:26:44 2019

Implementação do filtro Non-Local Means geodésico

"""
import sys
import warnings
import time
import skimage
import statistics
import networkx as nx
import matplotlib.pyplot as plt
import skimage.io
import skimage.measure
import numpy as np
import sklearn.neighbors as sknn
from scipy.sparse.csgraph import dijkstra
from numpy.matlib import repmat
from scipy.linalg import eigh
from numpy.linalg import inv
from numpy.linalg import cond
from numpy import eye
from sklearn.decomposition import PCA
from skimage.metrics import peak_signal_noise_ratio
from skimage.metrics import structural_similarity
from skimage.transform import rescale, resize, downscale_local_mean
from numba import njit   # just in time compiler (acelera loops)
from joblib import Parallel, delayed

# Para evitar warning de divisão por zero
warnings.simplefilter(action='ignore')

'''
Espelhamento das bordas da imagem A de maneira simétrica
A função pad do numpy não é supertada pelo numba!
Substitui a função: img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')
f é o parâmetro (largura das bordas)
'''
@njit
def mirror(A, f):
    n = A.shape[0]
    m = A.shape[1]
    nlin = A.shape[0] + 2*f
    ncol = A.shape[1] + 2*f
    # Matriz de saída
    B = np.zeros((nlin, ncol))
    # Preeenche miolo
    B[f:nlin-f, f:ncol-f] = A
    # Preenche cantos
    B[0:f, 0:f] = np.flip(A[0:f, 0:f])                          # 1o quadrante
    B[0:f, ncol-f:ncol] = np.flip(A[0:f, m-f:m])                # 2o quadrante
    B[nlin-f:nlin, 0:f] = np.flip(A[n-f:n, 0:f])                # 3o quadrante
    B[nlin-f:nlin, ncol-f:ncol] = np.flip(A[n-f:n, m-f:m])      # 4o quadrante
    # Preenche bordas
    B[0:f, f:ncol-f] = np.flipud(A[0:f, :])             # cima
    B[nlin-f:nlin, f:ncol-f] = np.flipud(A[n-f:n, :])   # baixo
    B[f:nlin-f, 0:f] = np.fliplr(A[:, 0:f])             # esquerda
    B[f:nlin-f, ncol-f:ncol] = np.fliplr(A[:, m-f:m])   # direita
    return B

'''
Non-Local Means padrão (versão rápida)

Parâmetros:

    img: imagem ruidosa de entrada
    h: parâmetro que controla o grau de suavização (quanto maior, mais suaviza)
    f: tamanho do patch (2f + 1 x 2f + 1) -> se f = 3, então patch é 7 x 7
    t: tamanho da janela de busca (2t + 1 x 2t + 1) -> se t = 10, então janela de busca é 21 x 21

'''
@njit
def NLM_fast(img, h, f, t):
    # Dimenssões espaciais da imagem
    m, n = img.shape
    # Cria imagem de saída
    filtrada = np.zeros((m, n))
    # Problema de valor de contorno: replicar bordas
    img_n = mirror(img, f)
    # Loop principal do NLM
    for i in range(m):
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente
            # Obtém o patch ao redor do pixel corrente
            W1 = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1]
            # Calcula as bordas da janela de busca para o pixel corrente (se pixel próximo das bordas, janela de busca é menor)
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            # Calcula média ponderada
            NL = 0      # valor do pixel corrente filtrado
            Z = 0       # constante normalizadora
            # Loop para todos os pixels da janela de busca
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    W2 = img_n[r-f:(r+f)+1, s-f:(s+f)+1]
                    # Calcula o quadrado da distância Euclidiana
                    d2 = np.sum((W1 - W2)*(W1 - W2))
                    # Calcula a medida de similaridade
                    sij = np.exp(-d2/(h**2))               
                    # Atualiza Z e NL
                    Z = Z + sij
                    NL = NL + sij*img_n[r, s]
            # Normalização do pixel filtrado
            filtrada[i, j] = NL/Z
    return filtrada


'''
Non-Local Means geodésico (versão básica, sem paralelismo e mais lenta)

Parâmetros:

    img: imagem ruidosa de entrada
    h: parâmetro que controla o grau de suavização (quanto maior, mais suaviza)
    f: tamanho do patch (2f + 1 x 2f + 1) -> se f = 3, então patch é 7 x 7
    t: tamanho da janela de busca (2t + 1 x 2t + 1) -> se t = 10, então janela de busca é 21 x 21
    nn: número de vizinhos no grafo KNN

''' 
def GeoNLM(img_noise, h, f, t, nn=10):
    # Dimenssões espaciais da imagem
    m, n = img_noise.shape
    # Cria imagem de saída
    filtrada = np.zeros((m, n))
    # Problema de valor de contorno: replicar bordas
    img_n = np.pad(img_noise, ((f, f), (f, f)), 'symmetric')
    # Loop principal do NLM geodésico
    for i in range(m):
        if i % 10 == 0:
            print(i, end=' ')
            sys.stdout.flush()
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente
            # Obtém o patch ao redor do pixel corrente
            patch_central = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1]
            central = np.reshape(patch_central, [1, patch_central.shape[0]*patch_central.shape[1]])[-1]
            # Calcula as bordas da janela de busca para o pixel corrente
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            # Calcula média ponderada
            NL = 0      # valor do pixel corrente filtrado
            Z = 0       # constante normalizadora
            # Cria dataset com patches da janela de busca como vetores
            num_elem = (rmax - rmin)*(smax - smin)
            tamanho_patch = (2*f + 1)*(2*f + 1)
            dataset = np.zeros((num_elem, tamanho_patch))
            k = 0
            pixels_busca = []
            # Loop para montar o dataset com todos os patches da janela
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    W = img_n[r-f:(r+f)+1, s-f:(s+f)+1] 
                    neighbor = np.reshape(W, [1, W.shape[0]*W.shape[1]])[-1]                    
                    dataset[k, :] = neighbor.copy()
                    if central[0] == neighbor[0]:
                        if (central == neighbor).all():
                            source = k
                    pixels_busca.append(img_n[r, s])
                    k = k + 1
            # Cria grafo knn com patches da janela de busca
            knnGraph = sknn.kneighbors_graph(dataset, n_neighbors=nn, mode='distance')
            A = knnGraph.toarray()
            # Converte matriz de adjacências para grafo
            G = nx.from_numpy_array(A)                      
            # Aplica algoritmo de Dijkstra
            length, path = nx.single_source_dijkstra(G, source)
            points = np.array(list(length.keys()))
            distancias = np.array(list(length.values()))
            # Calcula similaridades
            similaridades = np.exp(-distancias**2/(h**2))
            pixels = np.zeros(len(points))
            pixels_busca = np.array(pixels_busca)
            pixels = pixels_busca[points]
            # Normalização do pixel filtrado
            NL = sum(similaridades*pixels)
            Z = sum(similaridades)
            filtrada[i, j] = NL/Z
    return filtrada


######################################################
# Função auxiliar para paralelizar o GEONLM
######################################################
def process_pixel(i, j, img_n, f, t, h, nn):
    im = i + f
    jn = j + f
    patch_central = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1]
    central = np.reshape(patch_central, [1, patch_central.shape[0]*patch_central.shape[1]])[-1]
    rmin = max(im-t, f)
    rmax = min(im+t, m+f)
    smin = max(jn-t, f)
    smax = min(jn+t, n+f)
    NL, Z = 0, 0
    dataset = np.zeros(((rmax - rmin)*(smax - smin), (2*f + 1)*(2*f + 1)))
    k = 0
    pixels_busca = []
    for r in range(rmin, rmax):
        for s in range(smin, smax):
            W = img_n[r-f:(r+f)+1, s-f:(s+f)+1]
            neighbor = np.reshape(W, [1, W.shape[0]*W.shape[1]])[-1]
            dataset[k, :] = neighbor.copy()
            if central[0] == neighbor[0] and (central == neighbor).all():
                source = k
            pixels_busca.append(img_n[r, s])
            k += 1
    knnGraph = sknn.kneighbors_graph(dataset, n_neighbors=nn, mode='distance')
    A = knnGraph.toarray()
    G = nx.from_numpy_array(A)
    length, path = nx.single_source_dijkstra(G, source)
    points = np.array(list(length.keys()))
    distancias = np.array(list(length.values()))
    similaridades = np.exp(-distancias**2 / (h**2))
    pixels_busca = np.array(pixels_busca)
    pixels = pixels_busca[points]
    NL = sum(similaridades * pixels)
    Z = sum(similaridades)
    return NL / Z

##################################################
# GEONLM paralelo 
##################################################
def Parallel_GEONLM(img_n, f, t, h, nn):
    # Parallelize the loop
    m = img_n.shape[0] - 2*f
    n = img_n.shape[1] - 2*f
    filtrada = Parallel(n_jobs=-1)(delayed(process_pixel)(i, j, img_n, f, t, h, nn) for i in range(m) for j in range(n))
    filtrada_geo = np.array(filtrada).reshape((m, n))
    return filtrada_geo

####################################################################
'''
Função que extrai os patches de cada janela de busca no GeoNLM
Retorna uma matriz 4D (m, n, 2t+1 x 2t+1, 2f+1 x 2f+1)

Usa o JIT (just in time) compiler para acelerar loops

'''
####################################################################
@njit
def Extract_patches(img, f, t):
    # Dimenssões espaciais da imagem
    m, n = img.shape
    # Tamanhos do patch e da janela de busca
    tamanho_patch = (2*f + 1)*(2*f + 1)    
    # Patches para cada janela de busca
    patches = []
    centros = []    
    # Problema de valor de contorno: replicar bordas
    img_n = mirror(img, f)
    # Loop principal do NLM geodésico
    for i in range(m):        
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente
            # Obtém o patch ao redor do pixel corrente
            patch_central = img_n[im-f:(im+f)+1, jn-f:(jn+f)+1].copy()
            central = patch_central.reshape((1, patch_central.shape[0]*patch_central.shape[1]))[-1]
            # Calcula as bordas da janela de busca para o pixel corrente
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            num_elem = (rmax - rmin)*(smax - smin)
            # Cria dataset
            dataset = np.zeros((num_elem, tamanho_patch))
            # Loop para montar o dataset com todos os patches da janela
            k = 0
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    W = img_n[r-f:(r+f)+1, s-f:(s+f)+1].copy() 
                    neighbor = W.reshape((1, W.shape[0]*W.shape[1]))[-1]
                    dataset[k, :] = neighbor.copy()
                    if (central == neighbor).all():
                        source = k
                    k = k + 1
            patches.append(dataset)
            centros.append(source)
    return patches, centros

###################################################################
'''
Função que extrai os patches de cada janela de busca no GeoNLM
Retorna uma lista 
'''
###################################################################
def Geodesic_distances(patches, centros, nn=10):
    distancias_geodesicas = []
    pontos = []
    # Percorre a lista de patches
    for i in range(len(patches)):
    # Cria grafo knn com patches da janela de busca
        knnGraph = sknn.kneighbors_graph(patches[i], n_neighbors=nn, mode='distance')
        A = knnGraph.toarray()        
        G = nx.from_numpy_array(A)      # Converte matriz de adjacências para grafo
        # Aplica algoritmo de Dijkstra
        length, path = nx.single_source_dijkstra(G, centros[i])
        points = np.array(list(length.keys()))
        pontos.append(points)
        geodists = np.array(list(length.values()))        
        distancias_geodesicas.append(geodists)
    return distancias_geodesicas, pontos

##################################################################################################
'''
Non-Local Means geodésico (versão com compilador JIT para acelerar loops)

Parâmetros:

    img: imagem ruidosa de entrada
    h: parâmetro que controla o grau de suavização (quanto maior, mais suaviza)
    f: tamanho do patch (2f + 1 x 2f + 1) -> se f = 3, então patch é 7 x 7
    t: tamanho da janela de busca (2t + 1 x 2t + 1) -> se t = 10, então janela de busca é 21 x 21
    nn: número de vizinhos no grafo KNN

''' 
###################################################################################################
@njit
def GeoNLM_fast(img, h, f, t, distancias_geodesicas, pontos):
    # Dimenssões espaciais da imagem
    m, n = img.shape
    # Cria imagem de saída
    filtrada = np.zeros((m, n))
    # Problema de valor de contorno: replicar bordas
    #img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')
    img_n = mirror(img, f)
    # Loop principal do NLM geodésico
    k = 0
    for i in range(m):
        for j in range(n):
            im = i + f;   # compensar a borda adicionada artificialmente
            jn = j + f;   # compensar a borda adicionada artificialmente    
            # Calcula as bordas da janela de busca para o pixel corrente
            rmin = max(im-t, f);  # linha inicial
            rmax = min(im+t, m+f);  # linha final
            smin = max(jn-t, f);  # coluna inicial
            smax = min(jn+t, n+f);  # coluna final
            # Calcula média ponderada
            NL = 0      # valor do pixel corrente filtrado
            Z = 0       # constante normalizadora            
            pixels_busca = []
            # Loop para montar o dataset com todos os patches da janela
            for r in range(rmin, rmax):
                for s in range(smin, smax):
                    # Obtém o patch ao redor do pixel a ser comparado
                    pixels_busca.append(img_n[r, s])
            # Calcula similaridades
            similaridades = np.exp(-distancias_geodesicas[k]**2/(h**2))
            pixels = np.zeros(len(pontos[k]))
            pixels_busca = np.array(pixels_busca)
            pixels = pixels_busca[pontos[k]]
            # Normalização do pixel filtrado
            NL = sum(similaridades*pixels)
            Z = sum(similaridades)
            filtrada[i, j] = NL/Z
            k = k + 1
    return filtrada

#########################################################################
'''
Realiza a filtragem da imagem com o filtro NLM geodésico 

Usa o compilador JIT para acelerar loops
'''
#########################################################################
def GeoNLM_filter(img_noise, h, f, t, nn=10):
    # Fase 1
    print('Início da extração dos patches')
    inicio = time.time()
    patches, centros = Extract_patches(img_noise, f, t)
    fim = time.time()
    print('Elapsed time: %f ' %(fim - inicio))
    print()
    # Fase 2
    print('Início do cálculo das distâncias')
    inicio = time.time()
    distancias_geodesicas, pontos = Geodesic_distances(patches, centros, nn)
    fim = time.time()
    print('Elapsed time: %f ' %(fim - inicio))
    print()
    # Fase 3
    print('Início da filtragem')
    inicio = time.time()
    filtrada = GeoNLM_fast(img_noise, h, f, t, distancias_geodesicas, pontos)
    fim = time.time()
    print('Elapsed time: %f ' %(fim - inicio))
    return filtrada

# %%
import os
def read_directories(directory, img=None, exclude_json=None):
    # Get a list of filenames in the specified directory
    filenames = []
    for filename in os.listdir(directory):
        if img is not None:
            # If 'img' is provided, filter filenames containing it
            if img in filename:   
                filenames.append(filename)
        elif exclude_json is not None:
            filenames.append(filename.replace('.json',''))     
        else:
            filenames.append(filename)    
    return filenames


import numpy as np


def add_poisson_noise(img):
    """
    Aplica ruído de Poisson a uma imagem.

    Parâmetros:
        imagem (np.ndarray): imagem original (grayscale ou RGB), valores normalizados entre 0 e 1 ou em 0-255.

    Retorna:
        np.ndarray: imagem com ruído de Poisson.
    """
    # Se estiver em [0, 1], escala para 0-255
    if img.max() <= 1.0:
        img = (img * 255).astype(np.uint8)
    
    # Aplica o ruído de Poisson
    img_noise = np.random.poisson(img).astype(np.uint8)

    return img_noise

# %%
from pathlib import Path

sys.path.insert(0, r"c:\Users\adria\Documents\Doutorado\ProjetoDoutorado")
root_dir = Path(r"c:\Users\adria\Documents\Doutorado\ProjetoDoutorado")



dir_images = f'{root_dir}/wvc/images'
dir_out_nlm = f'{root_dir}/wvc/512x512/out_put_NLM_Poisson'
dir_out_geonlm = f'{root_dir}/wvc/512x512/out_put_GEONLM_Poisson'

array_dir = read_directories(dir_images)

psnrs_nlm = []
ssims_nlm = []

psnrs_geonlm = []
ssims_geonlm = []
array_dicts = []

for file in array_dir:

    file_name = file
    img = skimage.io.imread(f'{dir_images}/{file_name}')
    # Em arquivos de formato GIF precisa desse comando
    img = img[0, :, :]

    # Checa se imagem é monocromática
    if len(img.shape) > 2:
        img = skimage.color.rgb2gray(img)   # valores convertidos ficam entre 0 e 1
        img = 255*img

    # Reescala imagem para (256, 256) - diminuir o tempo de execução
    #img = downscale_local_mean(img, (2, 2))

    img = img.astype(np.uint8)              # Converte para uint8    
    m, n = img.shape

    print('Num. linhas = %d' %m)
    print('Num. colunas = %d' %n)
    print()

    # Cria imagem ruidosa
    ruidosa = add_poisson_noise(img)

    # Clipa imagem para intervalo [0, 255]
    ruidosa[np.where(ruidosa > 255)] = 255
    ruidosa[np.where(ruidosa < 0)] = 0
    #ruidosa = ruidosa.astype(np.float32)

    # Listas para métricas


    # Define parâmetros do filtro NLM
    f = 4   # tamanho do patch (2f + 1 x 2f + 1) -> 5 x 5
    t = 7   # tamanho da janela de busca (2t + 1 x 2t + 1) -> 21 x 21
    h_nlm = 110 # parâmetro que controla a suavização no NLM (depende da imagem)
    h_geo = 150 # parâmetro que controla a suavização no GEONLM (depende da imagem)
    nn = 10     # número de vizinhos no grafo k-NN

    # Cria imagem de saída
    filtrada = np.zeros((m, n))

    # Problema de valor de contorno: replicar bordas
    img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')

    ###################################################
    # Filtra com NLM padrão
    ###################################################
    print('***********************************')
    print('*            NLM                  *')
    print('***********************************')
    print()
    inicio = time.time()
    filtrada_padrao = NLM_fast(ruidosa, h_nlm, f, t)
    fim = time.time()    
    # Calcula PSNR
    p1 = peak_signal_noise_ratio(img, filtrada_padrao.astype(np.uint8))
    psnrs_nlm.append(p1)
    print('PSNR (NLM padrão): %f' %p1)
    # Calcula SSIM
    s1 = structural_similarity(img, filtrada_padrao.astype(np.uint8))
    ssims_nlm.append(s1)
    print('SSIM (NLM padrão): %f' %s1)
    print('Elapsed time (NLM): %f s' %(fim - inicio))
    print()
    time_nlm = fim - inicio
    # Salva arquivo
    skimage.io.imsave(f'{dir_out_nlm}/{file_name}', filtrada_padrao.astype(np.uint8))

    ###################################################
    # Filtra com NLM geodésico
    ###################################################
    print('***********************************')
    print('*            GEONLM               *')
    print('***********************************')
    print()
    ini = time.time()

    ##3 Versão com JIT compiler
    #filtrada_geo = GeoNLM_filter(ruidosa, h_geo, f, t, nn)   # versão com JIT compiler (não ficou mais rápido pois o Dijkstra não acelera. Ainda está lento...)

    ### Versão com paralelismo (ficou mais rápida)
    img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')      # para versão paralela, precisa espelhar imagem fora da função
    filtrada_geo = Parallel_GEONLM(img_n, f, t, h_geo, nn)

    end = time.time()
    # Calcula PSNR
    p2 = peak_signal_noise_ratio(img, filtrada_geo.astype(np.uint8))
    psnrs_nlm.append(p2)
    print('\nPSNR (GEO NLM): %f' %p2)
    # Calcula SSIM
    s2 = structural_similarity(img, filtrada_geo.astype(np.uint8))
    ssims_nlm.append(s2)
    print('SSIM (GEO NLM): %f' %s2)
    print('Total Elapsed time (GEONLM): %f s' %(end - ini))

    time_geonlm = end - ini
    print()
    # Salva arquivo    
    skimage.io.imsave(f'{dir_out_geonlm}/{file_name}', filtrada_geo.astype(np.uint8))

    dict = {
        's1': s1,
        'p1': p1,
        's2': s2,
        'p2': p2,
        'time_nlm':time_nlm,
        'time_geonlm':time_geonlm,
        'image': file_name   
    }
    array_dicts.append(dict)
# Out:
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 32.579728
# SSIM (NLM padrão): 0.872954
# Elapsed time (NLM): 16.516656 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 32.954114
# SSIM (GEO NLM): 0.861519
# Total Elapsed time (GEONLM): 214.852133 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 28.978431
# SSIM (NLM padrão): 0.890525
# Elapsed time (NLM): 8.661101 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 29.608423
# SSIM (GEO NLM): 0.893187
# Total Elapsed time (GEONLM): 213.859767 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 27.811058
# SSIM (NLM padrão): 0.803189
# Elapsed time (NLM): 8.648418 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 28.577046
# SSIM (GEO NLM): 0.754909
# Total Elapsed time (GEONLM): 203.698671 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 9.893109
# SSIM (NLM padrão): 0.474428
# Elapsed time (NLM): 8.080225 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 9.899747
# SSIM (GEO NLM): 0.479585
# Total Elapsed time (GEONLM): 202.191121 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 30.881230
# SSIM (NLM padrão): 0.831647
# Elapsed time (NLM): 8.077168 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 31.620912
# SSIM (GEO NLM): 0.863653
# Total Elapsed time (GEONLM): 199.810994 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 27.984878
# SSIM (NLM padrão): 0.842313
# Elapsed time (NLM): 8.113061 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 28.597793
# SSIM (GEO NLM): 0.817415
# Total Elapsed time (GEONLM): 198.430923 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 25.717941
# SSIM (NLM padrão): 0.879025
# Elapsed time (NLM): 8.388897 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.735416
# SSIM (GEO NLM): 0.880974
# Total Elapsed time (GEONLM): 202.382876 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 30.534524
# SSIM (NLM padrão): 0.866287
# Elapsed time (NLM): 8.013339 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 30.712752
# SSIM (GEO NLM): 0.876830
# Total Elapsed time (GEONLM): 219.187773 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 21.891342
# SSIM (NLM padrão): 0.784760
# Elapsed time (NLM): 8.007728 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 21.905293
# SSIM (GEO NLM): 0.799167
# Total Elapsed time (GEONLM): 200.910885 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 24.327745
# SSIM (NLM padrão): 0.846394
# Elapsed time (NLM): 7.993713 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 24.538175
# SSIM (GEO NLM): 0.877236
# Total Elapsed time (GEONLM): 195.307822 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 17.091980
# SSIM (NLM padrão): 0.779287
# Elapsed time (NLM): 7.993779 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 17.095934
# SSIM (GEO NLM): 0.796637
# Total Elapsed time (GEONLM): 199.878083 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 31.248076
# SSIM (NLM padrão): 0.861376
# Elapsed time (NLM): 8.000407 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 31.780590
# SSIM (GEO NLM): 0.887837
# Total Elapsed time (GEONLM): 197.389623 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 25.961264
# SSIM (NLM padrão): 0.765377
# Elapsed time (NLM): 7.981506 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 26.356360
# SSIM (GEO NLM): 0.813652
# Total Elapsed time (GEONLM): 197.993351 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 30.242176
# SSIM (NLM padrão): 0.836306
# Elapsed time (NLM): 7.977282 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 30.497960
# SSIM (GEO NLM): 0.850577
# Total Elapsed time (GEONLM): 198.864904 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 31.217031
# SSIM (NLM padrão): 0.820402
# Elapsed time (NLM): 8.096237 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 31.852932
# SSIM (GEO NLM): 0.853904
# Total Elapsed time (GEONLM): 200.479320 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.583046
# SSIM (NLM padrão): 0.783518
# Elapsed time (NLM): 7.965213 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.636257
# SSIM (GEO NLM): 0.799508
# Total Elapsed time (GEONLM): 204.556926 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 34.128345
# SSIM (NLM padrão): 0.879647
# Elapsed time (NLM): 7.969097 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 35.559125
# SSIM (GEO NLM): 0.906268
# Total Elapsed time (GEONLM): 201.458638 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 32.240606
# SSIM (NLM padrão): 0.837827
# Elapsed time (NLM): 8.025538 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 33.053103
# SSIM (GEO NLM): 0.869461
# Total Elapsed time (GEONLM): 200.139433 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 34.348428
# SSIM (NLM padrão): 0.866367
# Elapsed time (NLM): 7.976220 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 35.364782
# SSIM (GEO NLM): 0.890910
# Total Elapsed time (GEONLM): 201.080878 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 31.851136
# SSIM (NLM padrão): 0.794438
# Elapsed time (NLM): 7.969274 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 33.324474
# SSIM (GEO NLM): 0.856035
# Total Elapsed time (GEONLM): 198.882239 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 20.958457
# SSIM (NLM padrão): 0.866027
# Elapsed time (NLM): 7.993368 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 20.989803
# SSIM (GEO NLM): 0.878538
# Total Elapsed time (GEONLM): 201.482916 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 32.366343
# SSIM (NLM padrão): 0.825627
# Elapsed time (NLM): 7.996473 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 32.996378
# SSIM (GEO NLM): 0.851842
# Total Elapsed time (GEONLM): 199.347194 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 28.538037
# SSIM (NLM padrão): 0.812523
# Elapsed time (NLM): 7.966191 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 29.106212
# SSIM (GEO NLM): 0.844848
# Total Elapsed time (GEONLM): 199.307919 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 25.305429
# SSIM (NLM padrão): 0.836082
# Elapsed time (NLM): 8.104858 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.491887
# SSIM (GEO NLM): 0.880329
# Total Elapsed time (GEONLM): 199.349348 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 23.017073
# SSIM (NLM padrão): 0.762781
# Elapsed time (NLM): 7.974055 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 23.149174
# SSIM (GEO NLM): 0.806310
# Total Elapsed time (GEONLM): 200.110101 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 26.020922
# SSIM (NLM padrão): 0.846357
# Elapsed time (NLM): 7.987495 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.975358
# SSIM (GEO NLM): 0.852811
# Total Elapsed time (GEONLM): 202.691934 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 29.305106
# SSIM (NLM padrão): 0.859051
# Elapsed time (NLM): 7.973296 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 29.721966
# SSIM (GEO NLM): 0.872892
# Total Elapsed time (GEONLM): 187.988207 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 24.931338
# SSIM (NLM padrão): 0.758764
# Elapsed time (NLM): 8.007945 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 25.241786
# SSIM (GEO NLM): 0.821127
# Total Elapsed time (GEONLM): 199.323062 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 27.012226
# SSIM (NLM padrão): 0.814481
# Elapsed time (NLM): 7.968716 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 27.439723
# SSIM (GEO NLM): 0.853441
# Total Elapsed time (GEONLM): 197.546905 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 31.423845
# SSIM (NLM padrão): 0.855365
# Elapsed time (NLM): 8.037360 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 32.125434
# SSIM (GEO NLM): 0.868038
# Total Elapsed time (GEONLM): 198.985927 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 30.286767
# SSIM (NLM padrão): 0.854025
# Elapsed time (NLM): 7.987009 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 30.980257
# SSIM (GEO NLM): 0.891597
# Total Elapsed time (GEONLM): 193.871589 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 29.346878
# SSIM (NLM padrão): 0.716284
# Elapsed time (NLM): 7.956078 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 30.291700
# SSIM (GEO NLM): 0.792028
# Total Elapsed time (GEONLM): 200.784602 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 32.095432
# SSIM (NLM padrão): 0.852956
# Elapsed time (NLM): 7.964950 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 32.784762
# SSIM (GEO NLM): 0.867222
# Total Elapsed time (GEONLM): 198.517672 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 32.893565
# SSIM (NLM padrão): 0.870864
# Elapsed time (NLM): 7.997577 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 33.131644
# SSIM (GEO NLM): 0.860615
# Total Elapsed time (GEONLM): 202.200278 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 31.404610
# SSIM (NLM padrão): 0.804764
# Elapsed time (NLM): 7.981873 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 32.660714
# SSIM (GEO NLM): 0.859501
# Total Elapsed time (GEONLM): 199.475749 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 32.464168
# SSIM (NLM padrão): 0.805191
# Elapsed time (NLM): 7.965306 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 33.428559
# SSIM (GEO NLM): 0.837381
# Total Elapsed time (GEONLM): 200.800004 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 29.923658
# SSIM (NLM padrão): 0.838037
# Elapsed time (NLM): 7.984606 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 30.693170
# SSIM (GEO NLM): 0.867494
# Total Elapsed time (GEONLM): 196.688255 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.433432
# SSIM (NLM padrão): 0.804394
# Elapsed time (NLM): 7.979471 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.533062
# SSIM (GEO NLM): 0.835973
# Total Elapsed time (GEONLM): 200.785323 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 20.989676
# SSIM (NLM padrão): 0.858808
# Elapsed time (NLM): 7.962190 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 21.090642
# SSIM (GEO NLM): 0.892144
# Total Elapsed time (GEONLM): 198.865888 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 15.806588
# SSIM (NLM padrão): 0.767305
# Elapsed time (NLM): 7.971836 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 15.811428
# SSIM (GEO NLM): 0.766389
# Total Elapsed time (GEONLM): 204.985585 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 27.673312
# SSIM (NLM padrão): 0.794035
# Elapsed time (NLM): 8.118690 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 28.257896
# SSIM (GEO NLM): 0.793754
# Total Elapsed time (GEONLM): 199.703163 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 22.328450
# SSIM (NLM padrão): 0.809220
# Elapsed time (NLM): 8.159422 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 22.463282
# SSIM (GEO NLM): 0.834761
# Total Elapsed time (GEONLM): 198.318654 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 28.783830
# SSIM (NLM padrão): 0.856693
# Elapsed time (NLM): 7.987238 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 29.331249
# SSIM (GEO NLM): 0.873811
# Total Elapsed time (GEONLM): 198.067276 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 31.689949
# SSIM (NLM padrão): 0.879512
# Elapsed time (NLM): 7.978843 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 32.378848
# SSIM (GEO NLM): 0.866892
# Total Elapsed time (GEONLM): 199.444332 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 9.840244
# SSIM (NLM padrão): 0.685295
# Elapsed time (NLM): 7.975004 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 9.843304
# SSIM (GEO NLM): 0.675734
# Total Elapsed time (GEONLM): 200.663388 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 31.443002
# SSIM (NLM padrão): 0.844813
# Elapsed time (NLM): 8.028351 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 32.814395
# SSIM (GEO NLM): 0.887963
# Total Elapsed time (GEONLM): 196.940782 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 31.911969
# SSIM (NLM padrão): 0.888428
# Elapsed time (NLM): 7.968248 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 32.128103
# SSIM (GEO NLM): 0.900495
# Total Elapsed time (GEONLM): 199.275991 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 15.230737
# SSIM (NLM padrão): 0.609852
# Elapsed time (NLM): 7.964781 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 15.270873
# SSIM (GEO NLM): 0.618165
# Total Elapsed time (GEONLM): 202.535129 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 28.819654
# SSIM (NLM padrão): 0.841550
# Elapsed time (NLM): 7.992474 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 29.508242
# SSIM (GEO NLM): 0.884712
# Total Elapsed time (GEONLM): 201.038220 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 18.766686
# SSIM (NLM padrão): 0.818869
# Elapsed time (NLM): 7.963271 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 18.806499
# SSIM (GEO NLM): 0.838222
# Total Elapsed time (GEONLM): 201.045277 s

# %%
import pandas as pd
import numpy as np

def salvar_resultados_em_xlsx(lista_dicionarios, caminho_arquivo='resultados.xlsx'):
    # Converte os dicionários para DataFrame
    df = pd.DataFrame(lista_dicionarios)
    
    # Converte todos os np.float64 para float padrão do Python
    df = df.applymap(lambda x: float(x) if isinstance(x, np.float64) else x)
    
    # Salva como arquivo Excel
    df.to_excel(caminho_arquivo, index=False)
    print(f'Arquivo salvo em: {caminho_arquivo}')

# %%
# Suponha que você tenha a lista chamada `resultados`
salvar_resultados_em_xlsx(array_dicts, 'saidaPoisson.xlsx')
# Out:
# Arquivo salvo em: saidaPoisson.xlsx

# %%
from pathlib import Path

sys.path.insert(0, r"c:\Users\adria\Documents\Doutorado\ProjetoDoutorado")
root_dir = Path(r"c:\Users\adria\Documents\Doutorado\ProjetoDoutorado")



dir_images = f'{root_dir}/wvc/images'
dir_out_nlm = f'{root_dir}/wvc/512x512/out_put_NLM'
dir_out_geonlm = f'{root_dir}/wvc/512x512/out_put_GEONLM'

array_dir = read_directories(dir_images)

psnrs_nlm = []
ssims_nlm = []

psnrs_geonlm = []
ssims_geonlm = []
array_dicts_NLM = []

for file in array_dir:

    file_name = file
    img = skimage.io.imread(f'{dir_images}/{file_name}')
    # Em arquivos de formato GIF precisa desse comando
    img = img[0, :, :]

    # Checa se imagem é monocromática
    if len(img.shape) > 2:
        img = skimage.color.rgb2gray(img)   # valores convertidos ficam entre 0 e 1
        img = 255*img

    # Reescala imagem para (256, 256) - diminuir o tempo de execução
    #img = downscale_local_mean(img, (2, 2))

    img = img.astype(np.uint8)              # Converte para uint8    
    m, n = img.shape

    print('Num. linhas = %d' %m)
    print('Num. colunas = %d' %n)
    print()

    # Cria imagem ruidosa
    sigma = 10
    ruido = np.random.normal(0, sigma, (m, n))

    # Cria imagem ruidosa
    ruidosa = img + ruido

    # Clipa imagem para intervalo [0, 255]
    ruidosa[np.where(ruidosa > 255)] = 255
    ruidosa[np.where(ruidosa < 0)] = 0
    #ruidosa = ruidosa.astype(np.float32)

    # Listas para métricas


    # Define parâmetros do filtro NLM
    f = 4   # tamanho do patch (2f + 1 x 2f + 1) -> 5 x 5
    t = 7   # tamanho da janela de busca (2t + 1 x 2t + 1) -> 21 x 21
    h_nlm = 110 # parâmetro que controla a suavização no NLM (depende da imagem)
    h_geo = 150 # parâmetro que controla a suavização no GEONLM (depende da imagem)
    nn = 10     # número de vizinhos no grafo k-NN

    # Cria imagem de saída
    filtrada = np.zeros((m, n))

    # Problema de valor de contorno: replicar bordas
    img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')

    ###################################################
    # Filtra com NLM padrão
    ###################################################
    print('***********************************')
    print('*            NLM                  *')
    print('***********************************')
    print()
    inicio = time.time()
    filtrada_padrao = NLM_fast(ruidosa, h_nlm, f, t)
    fim = time.time()    
    # Calcula PSNR
    p1 = peak_signal_noise_ratio(img, filtrada_padrao.astype(np.uint8))
    psnrs_nlm.append(p1)
    print('PSNR (NLM padrão): %f' %p1)
    # Calcula SSIM
    s1 = structural_similarity(img, filtrada_padrao.astype(np.uint8))
    ssims_nlm.append(s1)
    print('SSIM (NLM padrão): %f' %s1)
    print('Elapsed time (NLM): %f s' %(fim - inicio))
    print()
    time_nlm = fim - inicio
    # Salva arquivo
    skimage.io.imsave(f'{dir_out_nlm}/{file_name}', filtrada_padrao.astype(np.uint8))

    ###################################################
    # Filtra com NLM geodésico
    ###################################################
    print('***********************************')
    print('*            GEONLM               *')
    print('***********************************')
    print()
    ini = time.time()

    ##3 Versão com JIT compiler
    #filtrada_geo = GeoNLM_filter(ruidosa, h_geo, f, t, nn)   # versão com JIT compiler (não ficou mais rápido pois o Dijkstra não acelera. Ainda está lento...)

    ### Versão com paralelismo (ficou mais rápida)
    img_n = np.pad(ruidosa, ((f, f), (f, f)), 'symmetric')      # para versão paralela, precisa espelhar imagem fora da função
    filtrada_geo = Parallel_GEONLM(img_n, f, t, h_geo, nn)

    end = time.time()
    # Calcula PSNR
    p2 = peak_signal_noise_ratio(img, filtrada_geo.astype(np.uint8))
    psnrs_nlm.append(p2)
    print('\nPSNR (GEO NLM): %f' %p2)
    # Calcula SSIM
    s2 = structural_similarity(img, filtrada_geo.astype(np.uint8))
    ssims_nlm.append(s2)
    print('SSIM (GEO NLM): %f' %s2)
    print('Total Elapsed time (GEONLM): %f s' %(end - ini))

    time_geonlm = end - ini
    print()
    # Salva arquivo    
    skimage.io.imsave(f'{dir_out_geonlm}/{file_name}', filtrada_geo.astype(np.uint8))

    dict = {
        's1': s1,
        'p1': p1,
        's2': s2,
        'p2': p2,
        'time_nlm':time_nlm,
        'time_geonlm':time_geonlm,
        'image': file_name   
    }
    array_dicts_NLM.append(dict)
# Out:
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 34.170205
# SSIM (NLM padrão): 0.886117
# Elapsed time (NLM): 15.873044 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 34.932032
# SSIM (GEO NLM): 0.899599
# Total Elapsed time (GEONLM): 232.278178 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 33.015420
# SSIM (NLM padrão): 0.916177
# Elapsed time (NLM): 8.003339 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 33.942552
# SSIM (GEO NLM): 0.927443
# Total Elapsed time (GEONLM): 230.483577 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 33.655034
# SSIM (NLM padrão): 0.902434
# Elapsed time (NLM): 8.001451 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 34.547711
# SSIM (GEO NLM): 0.909599
# Total Elapsed time (GEONLM): 232.452130 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 31.325110
# SSIM (NLM padrão): 0.887163
# Elapsed time (NLM): 8.058780 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 31.899455
# SSIM (GEO NLM): 0.901575
# Total Elapsed time (GEONLM): 230.081002 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 31.075678
# SSIM (NLM padrão): 0.816693
# Elapsed time (NLM): 8.080158 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 31.913559
# SSIM (GEO NLM): 0.853073
# Total Elapsed time (GEONLM): 233.034038 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 32.187366
# SSIM (NLM padrão): 0.892182
# Elapsed time (NLM): 7.987625 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 33.191453
# SSIM (GEO NLM): 0.913137
# Total Elapsed time (GEONLM): 230.656708 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 28.975530
# SSIM (NLM padrão): 0.889348
# Elapsed time (NLM): 8.022082 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 29.276867
# SSIM (GEO NLM): 0.896288
# Total Elapsed time (GEONLM): 234.139470 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 30.018205
# SSIM (NLM padrão): 0.862254
# Elapsed time (NLM): 8.141217 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 30.457507
# SSIM (GEO NLM): 0.874341
# Total Elapsed time (GEONLM): 233.300381 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 28.659389
# SSIM (NLM padrão): 0.820222
# Elapsed time (NLM): 8.191258 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 28.791251
# SSIM (GEO NLM): 0.840704
# Total Elapsed time (GEONLM): 233.144052 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 29.604089
# SSIM (NLM padrão): 0.842010
# Elapsed time (NLM): 8.010554 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 30.371758
# SSIM (GEO NLM): 0.872559
# Total Elapsed time (GEONLM): 231.002913 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 29.543405
# SSIM (NLM padrão): 0.863209
# Elapsed time (NLM): 8.009150 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 29.768820
# SSIM (GEO NLM): 0.878969
# Total Elapsed time (GEONLM): 231.884214 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 31.055835
# SSIM (NLM padrão): 0.858592
# Elapsed time (NLM): 8.156912 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 31.725345
# SSIM (GEO NLM): 0.886244
# Total Elapsed time (GEONLM): 231.360207 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 31.521275
# SSIM (NLM padrão): 0.811973
# Elapsed time (NLM): 8.187459 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 32.638866
# SSIM (GEO NLM): 0.863978
# Total Elapsed time (GEONLM): 230.589851 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 30.097422
# SSIM (NLM padrão): 0.842817
# Elapsed time (NLM): 8.011556 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 30.515963
# SSIM (GEO NLM): 0.861390
# Total Elapsed time (GEONLM): 232.273481 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 31.502063
# SSIM (NLM padrão): 0.825424
# Elapsed time (NLM): 7.997746 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 32.199306
# SSIM (GEO NLM): 0.858372
# Total Elapsed time (GEONLM): 233.204361 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 30.894942
# SSIM (NLM padrão): 0.829230
# Elapsed time (NLM): 8.058388 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 31.276276
# SSIM (GEO NLM): 0.848291
# Total Elapsed time (GEONLM): 236.446299 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 34.655525
# SSIM (NLM padrão): 0.883839
# Elapsed time (NLM): 8.029120 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 35.709831
# SSIM (GEO NLM): 0.900128
# Total Elapsed time (GEONLM): 233.687891 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 32.345579
# SSIM (NLM padrão): 0.839946
# Elapsed time (NLM): 8.000216 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 33.184360
# SSIM (GEO NLM): 0.868324
# Total Elapsed time (GEONLM): 233.158824 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 34.263367
# SSIM (NLM padrão): 0.865526
# Elapsed time (NLM): 8.025230 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 35.115038
# SSIM (GEO NLM): 0.882828
# Total Elapsed time (GEONLM): 233.884207 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 32.010235
# SSIM (NLM padrão): 0.798776
# Elapsed time (NLM): 7.989810 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 33.267071
# SSIM (GEO NLM): 0.852756
# Total Elapsed time (GEONLM): 232.036268 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 34.590053
# SSIM (NLM padrão): 0.896200
# Elapsed time (NLM): 8.187415 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 35.081558
# SSIM (GEO NLM): 0.898239
# Total Elapsed time (GEONLM): 234.264651 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 32.432342
# SSIM (NLM padrão): 0.829861
# Elapsed time (NLM): 8.118601 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 33.223796
# SSIM (GEO NLM): 0.862435
# Total Elapsed time (GEONLM): 232.374654 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 28.693762
# SSIM (NLM padrão): 0.820615
# Elapsed time (NLM): 7.993441 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 29.197981
# SSIM (GEO NLM): 0.847920
# Total Elapsed time (GEONLM): 232.524401 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 32.240008
# SSIM (NLM padrão): 0.844248
# Elapsed time (NLM): 7.968434 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 33.244620
# SSIM (GEO NLM): 0.881790
# Total Elapsed time (GEONLM): 232.628311 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 30.572592
# SSIM (NLM padrão): 0.803600
# Elapsed time (NLM): 8.242790 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 31.310780
# SSIM (GEO NLM): 0.847788
# Total Elapsed time (GEONLM): 232.156272 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 28.857148
# SSIM (NLM padrão): 0.856897
# Elapsed time (NLM): 8.589111 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 29.002727
# SSIM (GEO NLM): 0.867211
# Total Elapsed time (GEONLM): 234.791580 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 30.093666
# SSIM (NLM padrão): 0.772146
# Elapsed time (NLM): 7.970598 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 30.638084
# SSIM (GEO NLM): 0.797513
# Total Elapsed time (GEONLM): 233.282732 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 30.494285
# SSIM (NLM padrão): 0.783162
# Elapsed time (NLM): 7.961889 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 31.369261
# SSIM (GEO NLM): 0.838244
# Total Elapsed time (GEONLM): 231.285649 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 30.057975
# SSIM (NLM padrão): 0.841742
# Elapsed time (NLM): 8.424492 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 30.696689
# SSIM (GEO NLM): 0.873710
# Total Elapsed time (GEONLM): 230.086733 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 32.210753
# SSIM (NLM padrão): 0.862404
# Elapsed time (NLM): 7.979469 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 32.782504
# SSIM (GEO NLM): 0.880234
# Total Elapsed time (GEONLM): 231.199808 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 30.567606
# SSIM (NLM padrão): 0.861157
# Elapsed time (NLM): 7.986482 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 31.288931
# SSIM (GEO NLM): 0.894660
# Total Elapsed time (GEONLM): 227.267613 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 29.639095
# SSIM (NLM padrão): 0.726658
# Elapsed time (NLM): 7.973519 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 30.559013
# SSIM (GEO NLM): 0.797181
# Total Elapsed time (GEONLM): 233.538428 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 32.123787
# SSIM (NLM padrão): 0.855057
# Elapsed time (NLM): 8.074137 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 32.937318
# SSIM (GEO NLM): 0.881976
# Total Elapsed time (GEONLM): 231.650677 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 33.524018
# SSIM (NLM padrão): 0.881142
# Elapsed time (NLM): 7.987284 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 33.993886
# SSIM (GEO NLM): 0.888462
# Total Elapsed time (GEONLM): 234.170924 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 31.491485
# SSIM (NLM padrão): 0.810362
# Elapsed time (NLM): 7.968946 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 32.620210
# SSIM (GEO NLM): 0.859029
# Total Elapsed time (GEONLM): 232.229497 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 32.573309
# SSIM (NLM padrão): 0.802288
# Elapsed time (NLM): 8.002221 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 33.996786
# SSIM (GEO NLM): 0.853604
# Total Elapsed time (GEONLM): 233.494883 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 31.846715
# SSIM (NLM padrão): 0.846583
# Elapsed time (NLM): 8.761769 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 32.954355
# SSIM (GEO NLM): 0.887301
# Total Elapsed time (GEONLM): 231.255220 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 31.666453
# SSIM (NLM padrão): 0.839272
# Elapsed time (NLM): 8.347167 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 32.499905
# SSIM (GEO NLM): 0.873153
# Total Elapsed time (GEONLM): 232.401112 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 32.298905
# SSIM (NLM padrão): 0.897254
# Elapsed time (NLM): 8.037748 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 33.543658
# SSIM (GEO NLM): 0.920973
# Total Elapsed time (GEONLM): 231.363905 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 28.253225
# SSIM (NLM padrão): 0.962958
# Elapsed time (NLM): 7.983099 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 28.422249
# SSIM (GEO NLM): 0.962809
# Total Elapsed time (GEONLM): 232.262373 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 31.432520
# SSIM (NLM padrão): 0.850360
# Elapsed time (NLM): 8.066931 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 32.201922
# SSIM (GEO NLM): 0.869780
# Total Elapsed time (GEONLM): 231.536799 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 29.708718
# SSIM (NLM padrão): 0.862439
# Elapsed time (NLM): 8.052849 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 30.360465
# SSIM (GEO NLM): 0.891188
# Total Elapsed time (GEONLM): 229.773615 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 29.355807
# SSIM (NLM padrão): 0.858200
# Elapsed time (NLM): 7.969985 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 30.009672
# SSIM (GEO NLM): 0.887258
# Total Elapsed time (GEONLM): 231.029310 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 32.743839
# SSIM (NLM padrão): 0.888209
# Elapsed time (NLM): 7.960805 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 33.856127
# SSIM (GEO NLM): 0.911205
# Total Elapsed time (GEONLM): 231.820510 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 31.429563
# SSIM (NLM padrão): 0.939010
# Elapsed time (NLM): 7.980819 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 31.740071
# SSIM (GEO NLM): 0.948346
# Total Elapsed time (GEONLM): 234.398692 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 31.811070
# SSIM (NLM padrão): 0.846741
# Elapsed time (NLM): 7.997151 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 33.200615
# SSIM (GEO NLM): 0.891060
# Total Elapsed time (GEONLM): 229.867925 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 31.348215
# SSIM (NLM padrão): 0.880521
# Elapsed time (NLM): 7.955165 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 31.861136
# SSIM (GEO NLM): 0.891220
# Total Elapsed time (GEONLM): 232.198157 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 30.368663
# SSIM (NLM padrão): 0.867872
# Elapsed time (NLM): 7.967689 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 30.990930
# SSIM (GEO NLM): 0.888179
# Total Elapsed time (GEONLM): 230.238493 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 31.507774
# SSIM (NLM padrão): 0.854139
# Elapsed time (NLM): 7.981758 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 32.540866
# SSIM (GEO NLM): 0.889632
# Total Elapsed time (GEONLM): 232.681439 s
#
# Num. linhas = 512
# Num. colunas = 512
#
# ***********************************
# *            NLM                  *
# ***********************************
#
# PSNR (NLM padrão): 31.246603
# SSIM (NLM padrão): 0.894521
# Elapsed time (NLM): 7.969155 s
#
# ***********************************
# *            GEONLM               *
# ***********************************
#
#
# PSNR (GEO NLM): 31.752578
# SSIM (GEO NLM): 0.906928
# Total Elapsed time (GEONLM): 232.158174 s

# %%
salvar_resultados_em_xlsx(array_dicts_NLM, 'saidaNLM.xlsx')
# Out:
# Arquivo salvo em: saidaNLM.xlsx
