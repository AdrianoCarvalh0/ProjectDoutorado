# %% [markdown]
# # 🧠 Super-Resolução 2× com Real-ESRGAN (modo fiel)
# Este notebook aplica **Real-ESRGAN** à imagem `Lenna_(test_image).png`, gerando uma versão 2× em alta resolução (TIFF).

# %%
# 🔧 Instala o Real-ESRGAN!pip install -q realesrgan# 📂 Faz upload da imagem (envie sua Lenna)from google.colab import filesuploaded = files.upload()# 🧠 Executa Real-ESRGAN (modo fiel, 2×)!realesrgan-ncnn-vulkan -i "Lenna_(test_image).png" -o "Lenna_2x_ESRGAN.tiff" -s 2# 💾 Faz download da imagem processadafiles.download("Lenna_2x_ESRGAN.tiff")
